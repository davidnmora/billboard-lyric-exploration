# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from IPython.display import display, Markdown

import pandas as pd
import numpy as np

import json

np.__version__
# Out:
# /var/folders/b7/c67wpzpn25q0h072y9mmz_th0000gn/T/ipykernel_12775/2341679603.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# '1.26.3'

# %% [markdown]
# # 0. Import & prep data

# %%
PERFORMER_SPLIT_FILE = "./data/22.4-OUTPUT-performer_list_str-with-multi-name-artists-merged.csv"

_all_performers_df = pd.read_csv(PERFORMER_SPLIT_FILE)
_all_performers_df

GENDER_LOOKUP_TABLE_PATH = './data/22.5-OUTPUT-1-gender-lookup-table.csv'
existing_gender_table = pd.read_csv(GENDER_LOOKUP_TABLE_PATH)
existing_gender_table

# get df of any performers in _all_performers_df that are not in existing_gender_table
new_performers_df = _all_performers_df[~_all_performers_df['performer'].isin(existing_gender_table['performer'])]
new_performers_df

raw_performers_df = new_performers_df.copy()
raw_performers_df
# Out:
#                                               performer  \
# 13                        Bill Medley & Jennifer Warnes
# 29                                Daryl Hall John Oates
# 35                          Dawn Featuring Tony Orlando
# 45                   Elvis Presley With The Jordanaires
# 46                         Erykah Badu Featuring Common
# ...                                                 ...
# 2558                                           Tom Clay
# 2559                                 Bill Black's Combo
# 2560                                                 CJ
# 2561                        The Kid LAROI & Miley Cyrus
# 2562  Olivia Newton-John And The Electric Light Orch...
#
#                                    performers_list_str
# 13                        Bill Medley|Jennifer Warnes|
# 29                              Daryl Hall|John Oates|
# 35                                  Dawn|Tony Orlando|
# 45                      Elvis Presley|The Jordanaires|
# 46                                 Erykah Badu|Common|
# ...                                                ...
# 2558                                         Tom Clay|
# 2559                               Bill Black's Combo|
# 2560                                               CJ|
# 2561                        The Kid LAROI|Miley Cyrus|
# 2562  Olivia Newton-John|The Electric Light Orchestra|
#
# [781 rows x 2 columns]

# %%
performers_list = np.unique(
    np.concatenate(raw_performers_df['performers_list_str'].str.split("|").apply(lambda x: [i for i in x if i]).values)
)
len(performers_list)
# Out:
# 904

# %%
# But, everything should END with "|" (this was a bug I caught)
assert(len(raw_performers_df[~raw_performers_df.performers_list_str.str.contains("|", regex=False)]) == 0)

# %% [markdown]
# # Setup GPT4 call

# %%
import os
from openai import OpenAI

# First, activate the './.env' file which sets the OPENAI_API_KEY environment variable using python-dotenv
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    # This is the default and can be omitted
    api_key=os.getenv("OPENAI_API_KEY"),
)

# %%
LOVE_SONG_LABELING_PROMPT = """
You are a pop music expert, familiar with the songs and their performers featured in the US Billboard Top 10 hits.

You are also an expert in the gender identities of these performers, including those who have updated their genders, eg Sam Smith who is now non-binary.

Your task is, given a performer, label them with:
- "individual" or "group"
- their most recent gender identity, or, in the case of a group, the gender identity mix of the the group: "male", "female", "non-binary", "mixed gender group"
- If a performer is unclear or simply appears to be a mistake, label them as "unknown"

Here's an example input:

```json
[
	"Sam Smith",
    "Demi Lovato",
    "Adele",
    "SZA",
    "John Legend",
    "The Beatles",
    "Black Eyed Peas",
    "The Carpenters",
    "The Supremes",
    "Destiny's Child",
    "The Rolling Stones",
    "One Direction",
    "His Twangy Guitar",
    "asdf ghjkl"
]
```

Here's the sample corresponding output:

```json
{"output": [
	["Sam Smith", "individual", "non-binary"],
    ["Demi Lovato", "individual", "non-binary"],
    ["Adele", "individual", "female"],
    ["SZA", "individual", "female"],
    ["John Legend", "individual", "male"],
    ["The Beatles", "group", "male"],
    ["Black Eyed Peas", "group", "mixed gender group"],
    ["The Carpenters", "group", "mixed gender group"]
    ["The Supremes", "group", "female"],
    ["Destiny's Child", "group", "female"],
    ["The Rolling Stones", "group", "male"],
    ["One Direction", "group", "male"],
    ["His Twangy Guitar", "unknown", "unknown"],
    ["asdf ghjkl", "unknown", "unknown"]
]}
```

Ok, now generate the output for this input:
"""

# %%
import ast

def eval_this_str(s):
    return ast.literal_eval(s)

# %%
def get_love_song_labels_for_rows(row_subset_str):
    try: 
        completion = client.chat.completions.create(
          model="gpt-4o",
          response_format={'type': "json_object"},
          messages=[
            {"role": "user", "content": LOVE_SONG_LABELING_PROMPT},
            {"role": "user", "content": row_subset_str},
          ]
        )
        content = completion.choices[0].message.content
        # return content
        response_content = eval_this_str(content)['output']
        # print(f"Response contains {completion['usage']['completion_tokens']} tokens out of 4096 maximum allowed tokens.")
        return response_content
    except Exception as e:
        print('ERROR FETCHING', e)
        return []

# %% [markdown]
# ### Setup API call batching code

# %%
def fetch_all_data_in_batches(performers_list, increment=50):
    gpt_labeled_result = []
    for i in range(101):
        subset = performers_list[i*increment : (i+1)*increment]
        if len(subset):
            print([i*increment, (i+1)*increment])
            print(subset)
            subset_as_json_string = json.dumps(subset.tolist())
            print(subset_as_json_string, '\n')
            # fetched_and_formatted_res = [['David Mora', 'individual', 'male']]
            fetched_and_formatted_res = get_love_song_labels_for_rows(subset_as_json_string)
            print(fetched_and_formatted_res)
            gpt_labeled_result = [*gpt_labeled_result, *fetched_and_formatted_res]
    return gpt_labeled_result

def get_file_path(postfix):
    return f'./data/22.5-TEMP-gpt4-label-gender-{postfix}.csv'

def save_to_temp_csv(gpt_labeled_result, run_num):
    first_label_pass_df = pd.DataFrame(
        gpt_labeled_result, 
        columns=['performer', 'type', 'gender']
    )
    first_label_pass_df.to_csv(get_file_path(run_num), index=False)

# %% [markdown]
# # (run a test call to be sure things look ok)
# For 100 rows at once:
# For GPT4 turbo: 3min, about 3400 tokens out of 4096 maximum allowed tokens

# %%
# Out:
# array(['the Blackhearts', 'the Curls', 'the Delons', 'will.i.am'],
#       dtype='<U33')

# %%
TEST_POSTFIX = 'JUST A TEST, DELETE ME'
save_to_temp_csv(
    fetch_all_data_in_batches(
        # just get first 4:
        performers_list[900:950]
    ), 
    TEST_POSTFIX
)
# Out:
# [0, 50]
# ['the Blackhearts' 'the Curls' 'the Delons' 'will.i.am']
# ["the Blackhearts", "the Curls", "the Delons", "will.i.am"]
#
# [['the Blackhearts', 'group', 'mixed gender group'], ['the Curls', 'unknown', 'unknown'], ['the Delons', 'unknown', 'unknown'], ['will.i.am', 'individual', 'male']]

# %%
pd.read_csv(get_file_path(TEST_POSTFIX))
# Out:
#      performer     type   gender
# 0  "The Sting"  unknown  unknown
# 1      'N Sync    group     male
# 2    100 Proof  unknown  unknown
# 3          112    group     male

# %% [markdown]
# # Execute calls (in batched batches in case of failure)

# %%
len(performers_list)
# Out:
# 904

# %%
DATA_FILE_KEY_1 = 'thru-sep-2023-update'
# save_to_temp_csv(
#     fetch_all_data_in_batches(
#         performers_list[0:1000]
#     ), 
#     DATA_FILE_KEY_1
# )
# Out:
# [0, 50]
# ['"The Sting"' "'N Sync" '100 Proof' '112' '2 Chainz' '21 Savage'
#  '24kGoldn' '2Pac' '3OH!3' '42 Dugg' '50 Cent' '6LACK' '6ix9ine'
#  '98 Degrees' '?' 'A Great Big World' 'A$AP Rocky' 'Aaron Neville'
#  'Adam Clayton' 'Adam Levine' 'Adassa' 'Afrojack' 'Aged in Soul' 'Akon'
#  'Al Green' 'Al Hirt' 'Alessia Cara' 'Alex Band' 'Ali' 'Alice Bowie'
#  'Alicia Keys' 'Allison Moorer' 'Allure' 'Amanda Reifer' 'Amy Grant'
#  'Andrew Seeley' 'Angie Mar' 'Ann Wilson' 'Anne-Marie' 'Annette'
#  'Annie Lennox' 'Apollo' 'April Stevens' 'Aqua' 'Archie Bell'
#  'Aretha Franklin' 'Ariana Grande' 'Ashanti' 'Astrud Gilberto'
#  'Athena Cage']
# ["\"The Sting\"", "'N Sync", "100 Proof", "112", "2 Chainz", "21 Savage", "24kGoldn", "2Pac", "3OH!3", "42 Dugg", "50 Cent", "6LACK", "6ix9ine", "98 Degrees", "?", "A Great Big World", "A$AP Rocky", "Aaron Neville", "Adam Clayton", "Adam Levine", "Adassa", "Afrojack", "Aged in Soul", "Akon", "Al Green", "Al Hirt", "Alessia Cara", "Alex Band", "Ali", "Alice Bowie", "Alicia Keys", "Allison Moorer", "Allure", "Amanda Reifer", "Amy Grant", "Andrew Seeley", "Angie Mar", "Ann Wilson", "Anne-Marie", "Annette", "Annie Lennox", "Apollo", "April Stevens", "Aqua", "Archie Bell", "Aretha Franklin", "Ariana Grande", "Ashanti", "Astrud Gilberto", "Athena Cage"]
#
# [['"The Sting"', 'unknown', 'unknown'], ["'N Sync", 'group', 'male'], ['100 Proof', 'unknown', 'unknown'], ['112', 'group', 'male'], ['2 Chainz', 'individual', 'male'], ['21 Savage', 'individual', 'male'], ['24kGoldn', 'individual', 'male'], ['2Pac', 'individual', 'male'], ['3OH!3', 'group', 'male'], ['42 Dugg', 'individual', 'male'], ['50 Cent', 'individual', 'male'], ['6LACK', 'individual', 'male'], ['6ix9ine', 'individual', 'male'], ['98 Degrees', 'group', 'male'], ['?', 'unknown', 'unknown'], ['A Great Big World', 'group', 'male'], ['A$AP Rocky', 'individual', 'male'], ['Aaron Neville', 'individual', 'male'], ['Adam Clayton', 'individual', 'male'], ['Adam Levine', 'individual', 'male'], ['Adassa', 'individual', 'female'], ['Afrojack', 'individual', 'male'], ['Aged in Soul', 'group', 'mixed gender group'], ['Akon', 'individual', 'male'], ['Al Green', 'individual', 'male'], ['Al Hirt', 'individual', 'male'], ['Alessia Cara', 'individual', 'female'], ['Alex Band', 'individual', 'male'], ['Ali', 'individual', 'male'], ['Alice Bowie', 'unknown', 'unknown'], ['Alicia Keys', 'individual', 'female'], ['Allison Moorer', 'individual', 'female'], ['Allure', 'group', 'female'], ['Amanda Reifer', 'individual', 'female'], ['Amy Grant', 'individual', 'female'], ['Andrew Seeley', 'individual', 'male'], ['Angie Mar', 'unknown', 'unknown'], ['Ann Wilson', 'individual', 'female'], ['Anne-Marie', 'individual', 'female'], ['Annette', 'unknown', 'unknown'], ['Annie Lennox', 'individual', 'female'], ['Apollo', 'unknown', 'unknown'], ['April Stevens', 'individual', 'female'], ['Aqua', 'group', 'mixed gender group'], ['Archie Bell', 'individual', 'male'], ['Aretha Franklin', 'individual', 'female'], ['Ariana Grande', 'individual', 'female'], ['Ashanti', 'individual', 'female'], ['Astrud Gilberto', 'individual', 'female'], ['Athena Cage', 'individual', 'female']]
# [50, 100]
# ['Az Yet' 'B.J. Thomas' 'B.o.B' 'B2K' 'BBD' 'BLACKstreet' 'BTS'
#  'Baby Bash' 'Baby Cortez' 'Babyface' 'Bad Bunny' 'Bad Meets Evil'
#  'Bailey Zimmerman' 'Barbra Streisand' 'Barry DeVorzon' 'Barry Gibb'
#  'Bastille' 'Bebe Rexha' 'Bent Fabric' 'Bert Kaempfert' 'Betty Everett'
#  'Betty Wright' 'Beyonce' 'Big Sean' 'Bill "Smokey" Robinson'
#  "Bill Black's Combo" 'Bill Medley' 'Bill Pursell' 'Bill Withers'
#  'Billy Davis, Jr.' 'Billy J. Kramer' 'Billy Joe' 'Billy Preston'
#  'Billy Ray Cyrus' 'Billy Vera' 'Bizarrap' 'BlocBoy JB' 'Blxst'
#  'Bobby Brown' 'Bobby Hart' 'Bobby Valentino' 'Bon Iver'
#  'Bone Thugs-N-Harmony' 'Bounty Killer' 'Bow Legged Lou' 'Bow Wow'
#  'Boyz II Men' 'Bradley Cooper' 'Brandy' 'Brenda Russell']
# ["Az Yet", "B.J. Thomas", "B.o.B", "B2K", "BBD", "BLACKstreet", "BTS", "Baby Bash", "Baby Cortez", "Babyface", "Bad Bunny", "Bad Meets Evil", "Bailey Zimmerman", "Barbra Streisand", "Barry DeVorzon", "Barry Gibb", "Bastille", "Bebe Rexha", "Bent Fabric", "Bert Kaempfert", "Betty Everett", "Betty Wright", "Beyonce", "Big Sean", "Bill \"Smokey\" Robinson", "Bill Black's Combo", "Bill Medley", "Bill Pursell", "Bill Withers", "Billy Davis, Jr.", "Billy J. Kramer", "Billy Joe", "Billy Preston", "Billy Ray Cyrus", "Billy Vera", "Bizarrap", "BlocBoy JB", "Blxst", "Bobby Brown", "Bobby Hart", "Bobby Valentino", "Bon Iver", "Bone Thugs-N-Harmony", "Bounty Killer", "Bow Legged Lou", "Bow Wow", "Boyz II Men", "Bradley Cooper", "Brandy", "Brenda Russell"]
#
# [['Az Yet', 'group', 'male'], ['B.J. Thomas', 'individual', 'male'], ['B.o.B', 'individual', 'male'], ['B2K', 'group', 'male'], ['BBD', 'group', 'male'], ['BLACKstreet', 'group', 'male'], ['BTS', 'group', 'male'], ['Baby Bash', 'individual', 'male'], ['Baby Cortez', 'individual', 'male'], ['Babyface', 'individual', 'male'], ['Bad Bunny', 'individual', 'male'], ['Bad Meets Evil', 'group', 'male'], ['Bailey Zimmerman', 'individual', 'male'], ['Barbra Streisand', 'individual', 'female'], ['Barry DeVorzon', 'individual', 'male'], ['Barry Gibb', 'individual', 'male'], ['Bastille', 'group', 'male'], ['Bebe Rexha', 'individual', 'female'], ['Bent Fabric', 'individual', 'male'], ['Bert Kaempfert', 'individual', 'male'], ['Betty Everett', 'individual', 'female'], ['Betty Wright', 'individual', 'female'], ['Beyonce', 'individual', 'female'], ['Big Sean', 'individual', 'male'], ['Bill "Smokey" Robinson', 'individual', 'male'], ["Bill Black's Combo", 'group', 'male'], ['Bill Medley', 'individual', 'male'], ['Bill Pursell', 'individual', 'male'], ['Bill Withers', 'individual', 'male'], ['Billy Davis, Jr.', 'individual', 'male'], ['Billy J. Kramer', 'individual', 'male'], ['Billy Joe', 'unknown', 'unknown'], ['Billy Preston', 'individual', 'male'], ['Billy Ray Cyrus', 'individual', 'male'], ['Billy Vera', 'individual', 'male'], ['Bizarrap', 'individual', 'male'], ['BlocBoy JB', 'individual', 'male'], ['Blxst', 'individual', 'male'], ['Bobby Brown', 'individual', 'male'], ['Bobby Hart', 'individual', 'male'], ['Bobby Valentino', 'individual', 'male'], ['Bon Iver', 'group', 'male'], ['Bone Thugs-N-Harmony', 'group', 'male'], ['Bounty Killer', 'individual', 'male'], ['Bow Legged Lou', 'individual', 'male'], ['Bow Wow', 'individual', 'male'], ['Boyz II Men', 'group', 'male'], ['Bradley Cooper', 'individual', 'male'], ['Brandy', 'individual', 'female'], ['Brenda Russell', 'individual', 'female']]
# [100, 150]
# ['Brendon Urie' 'Brian & Brandon Casey' 'Brian McKnight' 'Britney Spears'
#  'Brook Benton' 'Brooklyn Dreams' 'Brother Love' 'Bruno Mars'
#  'Bryan Adams' 'Bryson Tiller' 'Bubba Sparxxx' 'Buffalo Springfield'
#  'Busta Rhymes' 'C+C Music Factory' 'CJ' 'Calvin Harris' "Cam'Ron" 'Cameo'
#  'Camila Cabello' 'Cardi B' 'Carl Anderson' 'Carly Rae Jepsen'
#  'Carly Simon' 'Carolina Gaitan' 'Carolyn Willis' 'Carrie Underwood'
#  'Case' 'Cassidy' 'Cast' 'Cataracs' 'Cathy Dennis' 'CeCe Winans'
#  'Cedric Gervais' 'CeeLo Green' 'Celine Dion' 'Chad Kroeger' 'Chaka Khan'
#  'Chamillionaire' 'Chance The Rapper' "Chantay's" 'Charlay'
#  'Charli Baltimore' 'Charli XCX' 'Charlie Foxx' 'Charlie Puth'
#  'Cheech & Chong' 'Chencho Corleone' 'Cher' 'Chill' 'Chingy']
# ["Brendon Urie", "Brian & Brandon Casey", "Brian McKnight", "Britney Spears", "Brook Benton", "Brooklyn Dreams", "Brother Love", "Bruno Mars", "Bryan Adams", "Bryson Tiller", "Bubba Sparxxx", "Buffalo Springfield", "Busta Rhymes", "C+C Music Factory", "CJ", "Calvin Harris", "Cam'Ron", "Cameo", "Camila Cabello", "Cardi B", "Carl Anderson", "Carly Rae Jepsen", "Carly Simon", "Carolina Gaitan", "Carolyn Willis", "Carrie Underwood", "Case", "Cassidy", "Cast", "Cataracs", "Cathy Dennis", "CeCe Winans", "Cedric Gervais", "CeeLo Green", "Celine Dion", "Chad Kroeger", "Chaka Khan", "Chamillionaire", "Chance The Rapper", "Chantay's", "Charlay", "Charli Baltimore", "Charli XCX", "Charlie Foxx", "Charlie Puth", "Cheech & Chong", "Chencho Corleone", "Cher", "Chill", "Chingy"]
#
# [['Brendon Urie', 'individual', 'male'], ['Brian & Brandon Casey', 'group', 'male'], ['Brian McKnight', 'individual', 'male'], ['Britney Spears', 'individual', 'female'], ['Brook Benton', 'individual', 'male'], ['Brooklyn Dreams', 'group', 'male'], ['Brother Love', 'unknown', 'unknown'], ['Bruno Mars', 'individual', 'male'], ['Bryan Adams', 'individual', 'male'], ['Bryson Tiller', 'individual', 'male'], ['Bubba Sparxxx', 'individual', 'male'], ['Buffalo Springfield', 'group', 'male'], ['Busta Rhymes', 'individual', 'male'], ['C+C Music Factory', 'group', 'mixed gender group'], ['CJ', 'individual', 'male'], ['Calvin Harris', 'individual', 'male'], ["Cam'Ron", 'individual', 'male'], ['Cameo', 'group', 'male'], ['Camila Cabello', 'individual', 'female'], ['Cardi B', 'individual', 'female'], ['Carl Anderson', 'individual', 'male'], ['Carly Rae Jepsen', 'individual', 'female'], ['Carly Simon', 'individual', 'female'], ['Carolina Gaitan', 'individual', 'female'], ['Carolyn Willis', 'individual', 'female'], ['Carrie Underwood', 'individual', 'female'], ['Case', 'individual', 'male'], ['Cassidy', 'individual', 'male'], ['Cast', 'group', 'male'], ['Cataracs', 'group', 'male'], ['Cathy Dennis', 'individual', 'female'], ['CeCe Winans', 'individual', 'female'], ['Cedric Gervais', 'individual', 'male'], ['CeeLo Green', 'individual', 'male'], ['Celine Dion', 'individual', 'female'], ['Chad Kroeger', 'individual', 'male'], ['Chaka Khan', 'individual', 'female'], ['Chamillionaire', 'individual', 'male'], ['Chance The Rapper', 'individual', 'male'], ["Chantay's", 'group', 'male'], ['Charlay', 'unknown', 'unknown'], ['Charli Baltimore', 'individual', 'female'], ['Charli XCX', 'individual', 'female'], ['Charlie Foxx', 'individual', 'male'], ['Charlie Puth', 'individual', 'male'], ['Cheech & Chong', 'group', 'male'], ['Chencho Corleone', 'individual', 'male'], ['Cher', 'individual', 'female'], ['Chill', 'unknown', 'unknown'], ['Chingy', 'individual', 'male']]
# [150, 200]
# ['Chris Brown' 'Chris Norman' 'Chris Stapleton' 'Christina Aguilera'
#  'Chubby Checker' 'Chuck Mangione' 'Ciara' 'City Spud' 'Classics IV'
#  'Clean Bandit' 'Cliff Nobles & Co.' 'Cobra Starship' 'Coi Leray'
#  "Colby O'Donis" 'Coldplay' 'Common' 'Connie Stevens' 'Coolio' 'Cory Gunz'
#  'Crystal Gayle' 'D-Mob' 'D.J. Jazzy Jeff' 'D.R.A.M.' 'DJ Frank E'
#  'DJ Khaled' 'DJ Sammy' 'DJ Snake' 'DNA' 'Da Brat' 'DaBaby' 'Daddy Yankee'
#  'Daft Punk' 'Dan' 'Dan Hill' 'Daniel Caesar' 'Daryl Hall'
#  'Dave "Baby" Cortez' 'David Bowie' 'David Cassidy' 'David Guetta'
#  'David Seville' 'Dawn' 'Daya' 'Deborah Cox' 'Dee Dee Sharp' 'Deliverance'
#  'Dem Franchize Boyz' 'Demi Lovato' 'Deniece Williams' 'Dennis Coffey']
# ["Chris Brown", "Chris Norman", "Chris Stapleton", "Christina Aguilera", "Chubby Checker", "Chuck Mangione", "Ciara", "City Spud", "Classics IV", "Clean Bandit", "Cliff Nobles & Co.", "Cobra Starship", "Coi Leray", "Colby O'Donis", "Coldplay", "Common", "Connie Stevens", "Coolio", "Cory Gunz", "Crystal Gayle", "D-Mob", "D.J. Jazzy Jeff", "D.R.A.M.", "DJ Frank E", "DJ Khaled", "DJ Sammy", "DJ Snake", "DNA", "Da Brat", "DaBaby", "Daddy Yankee", "Daft Punk", "Dan", "Dan Hill", "Daniel Caesar", "Daryl Hall", "Dave \"Baby\" Cortez", "David Bowie", "David Cassidy", "David Guetta", "David Seville", "Dawn", "Daya", "Deborah Cox", "Dee Dee Sharp", "Deliverance", "Dem Franchize Boyz", "Demi Lovato", "Deniece Williams", "Dennis Coffey"]
#
# [['Chris Brown', 'individual', 'male'], ['Chris Norman', 'individual', 'male'], ['Chris Stapleton', 'individual', 'male'], ['Christina Aguilera', 'individual', 'female'], ['Chubby Checker', 'individual', 'male'], ['Chuck Mangione', 'individual', 'male'], ['Ciara', 'individual', 'female'], ['City Spud', 'individual', 'male'], ['Classics IV', 'group', 'male'], ['Clean Bandit', 'group', 'mixed gender group'], ['Cliff Nobles & Co.', 'group', 'male'], ['Cobra Starship', 'group', 'mixed gender group'], ['Coi Leray', 'individual', 'female'], ["Colby O'Donis", 'individual', 'male'], ['Coldplay', 'group', 'male'], ['Common', 'individual', 'male'], ['Connie Stevens', 'individual', 'female'], ['Coolio', 'individual', 'male'], ['Cory Gunz', 'individual', 'male'], ['Crystal Gayle', 'individual', 'female'], ['D-Mob', 'group', 'male'], ['D.J. Jazzy Jeff', 'individual', 'male'], ['D.R.A.M.', 'individual', 'male'], ['DJ Frank E', 'individual', 'male'], ['DJ Khaled', 'individual', 'male'], ['DJ Sammy', 'individual', 'male'], ['DJ Snake', 'individual', 'male'], ['DNA', 'group', 'male'], ['Da Brat', 'individual', 'female'], ['DaBaby', 'individual', 'male'], ['Daddy Yankee', 'individual', 'male'], ['Daft Punk', 'group', 'male'], ['Dan', 'unknown', 'unknown'], ['Dan Hill', 'individual', 'male'], ['Daniel Caesar', 'individual', 'male'], ['Daryl Hall', 'individual', 'male'], ['Dave "Baby" Cortez', 'individual', 'male'], ['David Bowie', 'individual', 'male'], ['David Cassidy', 'individual', 'male'], ['David Guetta', 'individual', 'male'], ['David Seville', 'individual', 'male'], ['Dawn', 'group', 'female'], ['Daya', 'individual', 'female'], ['Deborah Cox', 'individual', 'female'], ['Dee Dee Sharp', 'individual', 'female'], ['Deliverance', 'group', 'male'], ['Dem Franchize Boyz', 'group', 'male'], ['Demi Lovato', 'individual', 'non-binary'], ['Deniece Williams', 'individual', 'female'], ['Dennis Coffey', 'individual', 'male']]
# [200, 250]
# ['Dennis Yost' 'Deon Estus' 'Derek' 'Desmond Dekker' "Destiny's Child"
#  'Dev' 'Dexys Midnight Runners' 'Diana Ross' 'Diane Guerrero' 'Diddy'
#  'Dinah Washington' 'Dion' 'Dion DiMucci' 'Dionne & Friends'
#  'Dionne Warwick' 'Disclosure' 'Disco Tex' 'Do' 'Dobie Gray' 'Doja Cat'
#  'Dolly Parton' 'Don Henley' 'Don Toliver' 'Donna Summer' 'Donny Hathaway'
#  'Donny Osmond' 'Dorothy Combs Morrison' 'Dr. Dre' 'Dr. Hook' 'Drake'
#  'Dru Hill' 'Dua Lipa' 'Duane Eddy' 'Dusty Springfield' 'E-40'
#  'Earth, Wind & Fire' 'Ed Sheeran' 'Eddie Rabbitt' 'Edgar Winter Group'
#  'Edward Byrnes' 'Electric Light Orchestra' 'Elton John' 'Elvis Presley'
#  'Eminem' 'En Vogue' 'Encanto Cast' 'Enrique Iglesias' 'Enya' 'Eric B.'
#  'Eric Weissberg']
# ["Dennis Yost", "Deon Estus", "Derek", "Desmond Dekker", "Destiny's Child", "Dev", "Dexys Midnight Runners", "Diana Ross", "Diane Guerrero", "Diddy", "Dinah Washington", "Dion", "Dion DiMucci", "Dionne & Friends", "Dionne Warwick", "Disclosure", "Disco Tex", "Do", "Dobie Gray", "Doja Cat", "Dolly Parton", "Don Henley", "Don Toliver", "Donna Summer", "Donny Hathaway", "Donny Osmond", "Dorothy Combs Morrison", "Dr. Dre", "Dr. Hook", "Drake", "Dru Hill", "Dua Lipa", "Duane Eddy", "Dusty Springfield", "E-40", "Earth, Wind & Fire", "Ed Sheeran", "Eddie Rabbitt", "Edgar Winter Group", "Edward Byrnes", "Electric Light Orchestra", "Elton John", "Elvis Presley", "Eminem", "En Vogue", "Encanto Cast", "Enrique Iglesias", "Enya", "Eric B.", "Eric Weissberg"]
#
# [['Dennis Yost', 'individual', 'male'], ['Deon Estus', 'individual', 'male'], ['Derek', 'individual', 'male'], ['Desmond Dekker', 'individual', 'male'], ["Destiny's Child", 'group', 'female'], ['Dev', 'individual', 'female'], ['Dexys Midnight Runners', 'group', 'male'], ['Diana Ross', 'individual', 'female'], ['Diane Guerrero', 'individual', 'female'], ['Diddy', 'individual', 'male'], ['Dinah Washington', 'individual', 'female'], ['Dion', 'individual', 'male'], ['Dion DiMucci', 'individual', 'male'], ['Dionne & Friends', 'group', 'mixed gender group'], ['Dionne Warwick', 'individual', 'female'], ['Disclosure', 'group', 'male'], ['Disco Tex', 'individual', 'unknown'], ['Do', 'individual', 'unknown'], ['Dobie Gray', 'individual', 'male'], ['Doja Cat', 'individual', 'female'], ['Dolly Parton', 'individual', 'female'], ['Don Henley', 'individual', 'male'], ['Don Toliver', 'individual', 'male'], ['Donna Summer', 'individual', 'female'], ['Donny Hathaway', 'individual', 'male'], ['Donny Osmond', 'individual', 'male'], ['Dorothy Combs Morrison', 'individual', 'female'], ['Dr. Dre', 'individual', 'male'], ['Dr. Hook', 'group', 'male'], ['Drake', 'individual', 'male'], ['Dru Hill', 'group', 'male'], ['Dua Lipa', 'individual', 'female'], ['Duane Eddy', 'individual', 'male'], ['Dusty Springfield', 'individual', 'female'], ['E-40', 'individual', 'male'], ['Earth, Wind & Fire', 'group', 'mixed gender group'], ['Ed Sheeran', 'individual', 'male'], ['Eddie Rabbitt', 'individual', 'male'], ['Edgar Winter Group', 'group', 'male'], ['Edward Byrnes', 'individual', 'male'], ['Electric Light Orchestra', 'group', 'male'], ['Elton John', 'individual', 'male'], ['Elvis Presley', 'individual', 'male'], ['Eminem', 'individual', 'male'], ['En Vogue', 'group', 'female'], ['Encanto Cast', 'group', 'mixed gender group'], ['Enrique Iglesias', 'individual', 'male'], ['Enya', 'individual', 'female'], ['Eric B.', 'individual', 'male'], ['Eric Weissberg', 'individual', 'male']]
# [250, 300]
# ['Erykah Badu' 'Eslabon Armado' 'Estelle' 'Esther Phillips' 'Evanescence'
#  'Eve' 'F. Williams' 'Fabolous' 'Faith Evans' 'Faith Hill'
#  'Far*East Movement' 'Fat Joe' 'Fat Man Scoop' 'Felly' 'Fergie'
#  'Fetty Wap' 'Field Mob' 'Fifth Harmony' 'Flo Rida' 'Florence Welch'
#  'Florida Georgia Line' 'Fort Minor' 'Foxes' 'Foxy Brown'
#  "Franck Pourcel's French Fiddles" 'Frank Mills' 'Frank Sinatra'
#  'Frankie J' 'Frankie Valli' 'Freekey Zekey' 'French Montana' 'Fridayy'
#  'Full Force' 'Future' 'G-Eazy' 'Gabby Barrett' 'Gary Puckett'
#  'George Michael' 'Ginuwine' 'Gipp' 'Giveon' 'Glenn Medeiros' 'GloRilla'
#  'Gloria Estefan' 'Gloria Loring' 'GoonRock' 'Gotye' 'Grey'
#  'Grover Washington, Jr.' 'Grupo Frontera']
# ["Erykah Badu", "Eslabon Armado", "Estelle", "Esther Phillips", "Evanescence", "Eve", "F. Williams", "Fabolous", "Faith Evans", "Faith Hill", "Far*East Movement", "Fat Joe", "Fat Man Scoop", "Felly", "Fergie", "Fetty Wap", "Field Mob", "Fifth Harmony", "Flo Rida", "Florence Welch", "Florida Georgia Line", "Fort Minor", "Foxes", "Foxy Brown", "Franck Pourcel's French Fiddles", "Frank Mills", "Frank Sinatra", "Frankie J", "Frankie Valli", "Freekey Zekey", "French Montana", "Fridayy", "Full Force", "Future", "G-Eazy", "Gabby Barrett", "Gary Puckett", "George Michael", "Ginuwine", "Gipp", "Giveon", "Glenn Medeiros", "GloRilla", "Gloria Estefan", "Gloria Loring", "GoonRock", "Gotye", "Grey", "Grover Washington, Jr.", "Grupo Frontera"]
#
# [['Erykah Badu', 'individual', 'female'], ['Eslabon Armado', 'group', 'male'], ['Estelle', 'individual', 'female'], ['Esther Phillips', 'individual', 'female'], ['Evanescence', 'group', 'mixed gender group'], ['Eve', 'individual', 'female'], ['F. Williams', 'unknown', 'unknown'], ['Fabolous', 'individual', 'male'], ['Faith Evans', 'individual', 'female'], ['Faith Hill', 'individual', 'female'], ['Far*East Movement', 'group', 'male'], ['Fat Joe', 'individual', 'male'], ['Fat Man Scoop', 'individual', 'male'], ['Felly', 'individual', 'male'], ['Fergie', 'individual', 'female'], ['Fetty Wap', 'individual', 'male'], ['Field Mob', 'group', 'male'], ['Fifth Harmony', 'group', 'female'], ['Flo Rida', 'individual', 'male'], ['Florence Welch', 'individual', 'female'], ['Florida Georgia Line', 'group', 'male'], ['Fort Minor', 'group', 'male'], ['Foxes', 'individual', 'female'], ['Foxy Brown', 'individual', 'female'], ["Franck Pourcel's French Fiddles", 'unknown', 'unknown'], ['Frank Mills', 'individual', 'male'], ['Frank Sinatra', 'individual', 'male'], ['Frankie J', 'individual', 'male'], ['Frankie Valli', 'individual', 'male'], ['Freekey Zekey', 'individual', 'male'], ['French Montana', 'individual', 'male'], ['Fridayy', 'individual', 'male'], ['Full Force', 'group', 'male'], ['Future', 'individual', 'male'], ['G-Eazy', 'individual', 'male'], ['Gabby Barrett', 'individual', 'female'], ['Gary Puckett', 'individual', 'male'], ['George Michael', 'individual', 'male'], ['Ginuwine', 'individual', 'male'], ['Gipp', 'individual', 'male'], ['Giveon', 'individual', 'male'], ['Glenn Medeiros', 'individual', 'male'], ['GloRilla', 'individual', 'female'], ['Gloria Estefan', 'individual', 'female'], ['Gloria Loring', 'individual', 'female'], ['GoonRock', 'individual', 'male'], ['Gotye', 'individual', 'male'], ['Grey', 'group', 'male'], ['Grover Washington, Jr.', 'individual', 'male'], ['Grupo Frontera', 'group', 'male']]
# [300, 350]
# ['Gucci Mane' 'Gunna' 'Gwen Stefani' 'Gym Class Heroes' 'Halsey'
#  'Harold Faltermeyer' 'Hayley Mills' 'Hayley Williams' 'Herb Alpert'
#  'His Cast Of Idiots' 'His Orchestra And Chorus' 'His Piano' 'His Rockets'
#  'His Twangy Guitar' 'Holly Brook' 'Hot Butter' 'Howard Hewett'
#  'Hugh Masekela' 'Hugo Montenegro' 'Ice Spice' 'Icona Pop' 'Iggy Azalea'
#  'Imagine Dragons' 'Inez Foxx' 'Infamous 2.0' 'Internet Money' 'Irv Gotti'
#  'J Balvin' 'J. Cole' 'J. Weav' 'JID' 'JT Money' 'JVKE' 'Ja Rule' 'Jabba'
#  'Jack Harlow' 'Jadakiss' 'Jaden Smith' 'Jagged Edge' 'Jaheim'
#  'James Ingram' 'James Taylor' 'Jamie Foxx' 'Jan Hammer' 'Janelle Monae'
#  'Janet' 'Janet Jackson' 'Jason Derulo' 'Jawsh 685' 'Jay Sean']
# ["Gucci Mane", "Gunna", "Gwen Stefani", "Gym Class Heroes", "Halsey", "Harold Faltermeyer", "Hayley Mills", "Hayley Williams", "Herb Alpert", "His Cast Of Idiots", "His Orchestra And Chorus", "His Piano", "His Rockets", "His Twangy Guitar", "Holly Brook", "Hot Butter", "Howard Hewett", "Hugh Masekela", "Hugo Montenegro", "Ice Spice", "Icona Pop", "Iggy Azalea", "Imagine Dragons", "Inez Foxx", "Infamous 2.0", "Internet Money", "Irv Gotti", "J Balvin", "J. Cole", "J. Weav", "JID", "JT Money", "JVKE", "Ja Rule", "Jabba", "Jack Harlow", "Jadakiss", "Jaden Smith", "Jagged Edge", "Jaheim", "James Ingram", "James Taylor", "Jamie Foxx", "Jan Hammer", "Janelle Monae", "Janet", "Janet Jackson", "Jason Derulo", "Jawsh 685", "Jay Sean"]
#
# [['Gucci Mane', 'individual', 'male'], ['Gunna', 'individual', 'male'], ['Gwen Stefani', 'individual', 'female'], ['Gym Class Heroes', 'group', 'mixed gender group'], ['Halsey', 'individual', 'female'], ['Harold Faltermeyer', 'individual', 'male'], ['Hayley Mills', 'individual', 'female'], ['Hayley Williams', 'individual', 'female'], ['Herb Alpert', 'individual', 'male'], ['His Cast Of Idiots', 'unknown', 'unknown'], ['His Orchestra And Chorus', 'unknown', 'unknown'], ['His Piano', 'unknown', 'unknown'], ['His Rockets', 'unknown', 'unknown'], ['His Twangy Guitar', 'unknown', 'unknown'], ['Holly Brook', 'individual', 'female'], ['Hot Butter', 'group', 'male'], ['Howard Hewett', 'individual', 'male'], ['Hugh Masekela', 'individual', 'male'], ['Hugo Montenegro', 'individual', 'male'], ['Ice Spice', 'individual', 'female'], ['Icona Pop', 'group', 'female'], ['Iggy Azalea', 'individual', 'female'], ['Imagine Dragons', 'group', 'male'], ['Inez Foxx', 'individual', 'female'], ['Infamous 2.0', 'unknown', 'unknown'], ['Internet Money', 'group', 'male'], ['Irv Gotti', 'individual', 'male'], ['J Balvin', 'individual', 'male'], ['J. Cole', 'individual', 'male'], ['J. Weav', 'individual', 'male'], ['JID', 'individual', 'male'], ['JT Money', 'individual', 'male'], ['JVKE', 'individual', 'male'], ['Ja Rule', 'individual', 'male'], ['Jabba', 'unknown', 'unknown'], ['Jack Harlow', 'individual', 'male'], ['Jadakiss', 'individual', 'male'], ['Jaden Smith', 'individual', 'male'], ['Jagged Edge', 'group', 'male'], ['Jaheim', 'individual', 'male'], ['James Ingram', 'individual', 'male'], ['James Taylor', 'individual', 'male'], ['Jamie Foxx', 'individual', 'male'], ['Jan Hammer', 'individual', 'male'], ['Janelle Monae', 'individual', 'non-binary'], ['Janet', 'individual', 'female'], ['Janet Jackson', 'individual', 'female'], ['Jason Derulo', 'individual', 'male'], ['Jawsh 685', 'individual', 'male'], ['Jay Sean', 'individual', 'male']]
# [350, 400]
# ['Jay-Z' 'Jeezy' 'Jeffrey Daniels' 'Jennifer Lopez' 'Jennifer Warnes'
#  'Jeremih' 'Jerry Butler' 'Jerry Corbetta' 'Jerry Wallace' 'Jess Glynne'
#  'Jessie J' 'Jhay Cortez' 'Jim Edward Brown' 'Jim Messina' 'Jimin'
#  'Jimmy Charles' 'Jimmy Clanton' 'Jimmy Gilmer' 'Jimmy Harnen'
#  'Jimmy Page' 'Joan Jett' 'Jody Watley' 'Joe' 'Joe Cocker' 'Joe Esposito'
#  'Joe Jonas' 'Joe Rene And Orchestra' 'John Legend' 'John Lennon'
#  'John Martin' 'John Mellencamp' 'John Oates' 'John Travolta' 'Johnny'
#  'Johnny And The Hurricanes' 'Johnny Mathis' 'Johnta Austin' 'Jon B.'
#  'Jordin Sparks' 'Josey Scott' 'Joyner Lucas' 'Juelz Santana' 'Juice WRLD'
#  'Juicy J' 'Julio Iglesias' 'Jung Kook' 'Justin Bieber'
#  'Justin Timberlake' 'Juvenile' 'K-Ci And JoJo']
# ["Jay-Z", "Jeezy", "Jeffrey Daniels", "Jennifer Lopez", "Jennifer Warnes", "Jeremih", "Jerry Butler", "Jerry Corbetta", "Jerry Wallace", "Jess Glynne", "Jessie J", "Jhay Cortez", "Jim Edward Brown", "Jim Messina", "Jimin", "Jimmy Charles", "Jimmy Clanton", "Jimmy Gilmer", "Jimmy Harnen", "Jimmy Page", "Joan Jett", "Jody Watley", "Joe", "Joe Cocker", "Joe Esposito", "Joe Jonas", "Joe Rene And Orchestra", "John Legend", "John Lennon", "John Martin", "John Mellencamp", "John Oates", "John Travolta", "Johnny", "Johnny And The Hurricanes", "Johnny Mathis", "Johnta Austin", "Jon B.", "Jordin Sparks", "Josey Scott", "Joyner Lucas", "Juelz Santana", "Juice WRLD", "Juicy J", "Julio Iglesias", "Jung Kook", "Justin Bieber", "Justin Timberlake", "Juvenile", "K-Ci And JoJo"]
#
# [['Jay-Z', 'individual', 'male'], ['Jeezy', 'individual', 'male'], ['Jeffrey Daniels', 'individual', 'male'], ['Jennifer Lopez', 'individual', 'female'], ['Jennifer Warnes', 'individual', 'female'], ['Jeremih', 'individual', 'male'], ['Jerry Butler', 'individual', 'male'], ['Jerry Corbetta', 'individual', 'male'], ['Jerry Wallace', 'individual', 'male'], ['Jess Glynne', 'individual', 'female'], ['Jessie J', 'individual', 'female'], ['Jhay Cortez', 'individual', 'male'], ['Jim Edward Brown', 'individual', 'male'], ['Jim Messina', 'individual', 'male'], ['Jimin', 'individual', 'male'], ['Jimmy Charles', 'individual', 'male'], ['Jimmy Clanton', 'individual', 'male'], ['Jimmy Gilmer', 'individual', 'male'], ['Jimmy Harnen', 'individual', 'male'], ['Jimmy Page', 'individual', 'male'], ['Joan Jett', 'individual', 'female'], ['Jody Watley', 'individual', 'female'], ['Joe', 'individual', 'male'], ['Joe Cocker', 'individual', 'male'], ['Joe Esposito', 'individual', 'male'], ['Joe Jonas', 'individual', 'male'], ['Joe Rene And Orchestra', 'group', 'mixed gender group'], ['John Legend', 'individual', 'male'], ['John Lennon', 'individual', 'male'], ['John Martin', 'individual', 'male'], ['John Mellencamp', 'individual', 'male'], ['John Oates', 'individual', 'male'], ['John Travolta', 'individual', 'male'], ['Johnny', 'unknown', 'unknown'], ['Johnny And The Hurricanes', 'group', 'male'], ['Johnny Mathis', 'individual', 'male'], ['Johnta Austin', 'individual', 'male'], ['Jon B.', 'individual', 'male'], ['Jordin Sparks', 'individual', 'female'], ['Josey Scott', 'individual', 'male'], ['Joyner Lucas', 'individual', 'male'], ['Juelz Santana', 'individual', 'male'], ['Juice WRLD', 'individual', 'male'], ['Juicy J', 'individual', 'male'], ['Julio Iglesias', 'individual', 'male'], ['Jung Kook', 'individual', 'male'], ['Justin Bieber', 'individual', 'male'], ['Justin Timberlake', 'individual', 'male'], ['Juvenile', 'individual', 'male'], ['K-Ci And JoJo', 'group', 'male']]
# [400, 450]
# ['K.C.' 'KYLE' 'Kacey Musgraves' 'Kai Winding' 'Kanye West'
#  'Kardinal Offishall' 'Karol G' 'Kathy Young' 'Katy Perry' 'Ke$ha'
#  'Keith Sweat' 'Kelly Price' 'Kelly Rowland' 'Kendrick Lamar'
#  'Kenny Ball and his Jazzmen' 'Kenny G' 'Kenny Loggins' 'Kenny Rogers'
#  'Keri Hilson' 'Kevin Lyttle' 'Kevin Rudolf' 'Keyshia Cole' 'Khalid'
#  'Kid Cudi' 'Kid Rock' 'Kiki Dee' 'Kim Carnes' 'Kim Petras' 'Kimbra'
#  'Kodak Black' 'Kool Mo Dee' 'Krayzie Bone' 'Kygo' 'Kyjuan' 'Kyla' 'L.V.'
#  'LL Cool J' 'LMFAO' 'Lady Gaga' 'Lady Saw' 'Lana Del Rey' 'Larry Carlton'
#  'Larry Mullen' 'Latto' 'Lauren Bennett' 'Lea' 'Left Eye'
#  'Leighton Meester' 'Leon Russell' 'Liam Payne']
# ["K.C.", "KYLE", "Kacey Musgraves", "Kai Winding", "Kanye West", "Kardinal Offishall", "Karol G", "Kathy Young", "Katy Perry", "Ke$ha", "Keith Sweat", "Kelly Price", "Kelly Rowland", "Kendrick Lamar", "Kenny Ball and his Jazzmen", "Kenny G", "Kenny Loggins", "Kenny Rogers", "Keri Hilson", "Kevin Lyttle", "Kevin Rudolf", "Keyshia Cole", "Khalid", "Kid Cudi", "Kid Rock", "Kiki Dee", "Kim Carnes", "Kim Petras", "Kimbra", "Kodak Black", "Kool Mo Dee", "Krayzie Bone", "Kygo", "Kyjuan", "Kyla", "L.V.", "LL Cool J", "LMFAO", "Lady Gaga", "Lady Saw", "Lana Del Rey", "Larry Carlton", "Larry Mullen", "Latto", "Lauren Bennett", "Lea", "Left Eye", "Leighton Meester", "Leon Russell", "Liam Payne"]
#
# [['K.C.', 'unknown', 'unknown'], ['KYLE', 'individual', 'male'], ['Kacey Musgraves', 'individual', 'female'], ['Kai Winding', 'individual', 'male'], ['Kanye West', 'individual', 'male'], ['Kardinal Offishall', 'individual', 'male'], ['Karol G', 'individual', 'female'], ['Kathy Young', 'individual', 'female'], ['Katy Perry', 'individual', 'female'], ['Ke$ha', 'individual', 'female'], ['Keith Sweat', 'individual', 'male'], ['Kelly Price', 'individual', 'female'], ['Kelly Rowland', 'individual', 'female'], ['Kendrick Lamar', 'individual', 'male'], ['Kenny Ball and his Jazzmen', 'group', 'male'], ['Kenny G', 'individual', 'male'], ['Kenny Loggins', 'individual', 'male'], ['Kenny Rogers', 'individual', 'male'], ['Keri Hilson', 'individual', 'female'], ['Kevin Lyttle', 'individual', 'male'], ['Kevin Rudolf', 'individual', 'male'], ['Keyshia Cole', 'individual', 'female'], ['Khalid', 'individual', 'male'], ['Kid Cudi', 'individual', 'male'], ['Kid Rock', 'individual', 'male'], ['Kiki Dee', 'individual', 'female'], ['Kim Carnes', 'individual', 'female'], ['Kim Petras', 'individual', 'female'], ['Kimbra', 'individual', 'female'], ['Kodak Black', 'individual', 'male'], ['Kool Mo Dee', 'individual', 'male'], ['Krayzie Bone', 'individual', 'male'], ['Kygo', 'individual', 'male'], ['Kyjuan', 'individual', 'male'], ['Kyla', 'individual', 'female'], ['L.V.', 'unknown', 'unknown'], ['LL Cool J', 'individual', 'male'], ['LMFAO', 'group', 'male'], ['Lady Gaga', 'individual', 'female'], ['Lady Saw', 'individual', 'female'], ['Lana Del Rey', 'individual', 'female'], ['Larry Carlton', 'individual', 'male'], ['Larry Mullen', 'individual', 'male'], ['Latto', 'individual', 'female'], ['Lauren Bennett', 'individual', 'female'], ['Lea', 'unknown', 'unknown'], ['Left Eye', 'individual', 'female'], ['Leighton Meester', 'individual', 'female'], ['Leon Russell', 'individual', 'male'], ['Liam Payne', 'individual', 'male']]
# [450, 500]
# ['Lil Baby' 'Lil Dicky' 'Lil Durk' 'Lil Jon' 'Lil Mama' 'Lil Nas X'
#  'Lil Peanut' 'Lil Pump' 'Lil Tjay' 'Lil Uzi Vert' 'Lil Wayne'
#  'Lil Yachty' "Lil' Boosie" "Lil' Flip" "Lil' Kim" "Lil' Mo" "Lil' Phat"
#  'Lily Allen' 'Linda Ronstadt' 'Lionel Richie' 'Lisa Lisa And Cult Jam'
#  'Lita Ford' 'Lizzo' 'Lloyd' 'Logic' 'Loleatta Holloway'
#  'London Symphony Orchestra' 'Lonnie Mack' 'Lookas' 'Loon'
#  'Los Indios Tabajaras' 'Love Unlimited Orchestra' 'Ludacris' 'Luis Fonsi'
#  'Lupe Fiasco' 'Luther Vandross' 'M.I.A.' 'MC Lyte' 'MFSB' 'MO'
#  'Mac Miller' 'Machine Gun Kelly' 'Macklemore' 'Madonna' 'Majid Jordan'
#  'Major Lazer' 'Mar-Keys' 'Maren Morris' 'Mariah Carey' 'Marilyn Martin']
# ["Lil Baby", "Lil Dicky", "Lil Durk", "Lil Jon", "Lil Mama", "Lil Nas X", "Lil Peanut", "Lil Pump", "Lil Tjay", "Lil Uzi Vert", "Lil Wayne", "Lil Yachty", "Lil' Boosie", "Lil' Flip", "Lil' Kim", "Lil' Mo", "Lil' Phat", "Lily Allen", "Linda Ronstadt", "Lionel Richie", "Lisa Lisa And Cult Jam", "Lita Ford", "Lizzo", "Lloyd", "Logic", "Loleatta Holloway", "London Symphony Orchestra", "Lonnie Mack", "Lookas", "Loon", "Los Indios Tabajaras", "Love Unlimited Orchestra", "Ludacris", "Luis Fonsi", "Lupe Fiasco", "Luther Vandross", "M.I.A.", "MC Lyte", "MFSB", "MO", "Mac Miller", "Machine Gun Kelly", "Macklemore", "Madonna", "Majid Jordan", "Major Lazer", "Mar-Keys", "Maren Morris", "Mariah Carey", "Marilyn Martin"]
#
# [['Lil Baby', 'individual', 'male'], ['Lil Dicky', 'individual', 'male'], ['Lil Durk', 'individual', 'male'], ['Lil Jon', 'individual', 'male'], ['Lil Mama', 'individual', 'female'], ['Lil Nas X', 'individual', 'male'], ['Lil Peanut', 'unknown', 'unknown'], ['Lil Pump', 'individual', 'male'], ['Lil Tjay', 'individual', 'male'], ['Lil Uzi Vert', 'individual', 'male'], ['Lil Wayne', 'individual', 'male'], ['Lil Yachty', 'individual', 'male'], ["Lil' Boosie", 'individual', 'male'], ["Lil' Flip", 'individual', 'male'], ["Lil' Kim", 'individual', 'female'], ["Lil' Mo", 'individual', 'female'], ["Lil' Phat", 'individual', 'male'], ['Lily Allen', 'individual', 'female'], ['Linda Ronstadt', 'individual', 'female'], ['Lionel Richie', 'individual', 'male'], ['Lisa Lisa And Cult Jam', 'group', 'mixed gender group'], ['Lita Ford', 'individual', 'female'], ['Lizzo', 'individual', 'female'], ['Lloyd', 'individual', 'male'], ['Logic', 'individual', 'male'], ['Loleatta Holloway', 'individual', 'female'], ['London Symphony Orchestra', 'group', 'mixed gender group'], ['Lonnie Mack', 'individual', 'male'], ['Lookas', 'individual', 'male'], ['Loon', 'individual', 'male'], ['Los Indios Tabajaras', 'group', 'male'], ['Love Unlimited Orchestra', 'group', 'mixed gender group'], ['Ludacris', 'individual', 'male'], ['Luis Fonsi', 'individual', 'male'], ['Lupe Fiasco', 'individual', 'male'], ['Luther Vandross', 'individual', 'male'], ['M.I.A.', 'individual', 'female'], ['MC Lyte', 'individual', 'female'], ['MFSB', 'group', 'mixed gender group'], ['MO', 'individual', 'female'], ['Mac Miller', 'individual', 'male'], ['Machine Gun Kelly', 'individual', 'male'], ['Macklemore', 'individual', 'male'], ['Madonna', 'individual', 'female'], ['Majid Jordan', 'group', 'male'], ['Major Lazer', 'group', 'male'], ['Mar-Keys', 'group', 'male'], ['Maren Morris', 'individual', 'female'], ['Mariah Carey', 'individual', 'female'], ['Marilyn Martin', 'individual', 'female']]
# [500, 550]
# ['Marilyn McCoo' 'Mario Winans' 'Mark Lindsay' 'Mark Ronson'
#  'Marky Mark & The Funky Bunch' 'Maroon 5' 'Marshmello' 'Marvin Gaye'
#  'Marvin Hamlisch' 'Mary J. Blige' 'Mase' 'Mason Williams' 'Master P'
#  'Matthew Santos' 'Mauro Castillo' 'Maxi Priest' "Me'Shell Ndegeocello"
#  'Meco' 'Meek Mill' 'Megan Thee Stallion' 'Meghan Trainor' 'Melanie'
#  'Method Man' 'Metro Boomin' 'Miami Sound Machine' 'Michael Jackson'
#  'Michael McDonald' 'Michelle Branch' 'Mick Jagger' 'Migos' 'Mike Jones'
#  'Mike Post' 'Mike Reno' 'Mike Shorey' 'Mikky Ekko' 'Miley Cyrus'
#  'Missy "Misdemeanor" Elliott' 'Missy Elliott' 'Mobb Deep' 'Mocha'
#  'Mongo Santamaria Band' 'Monica' 'Montell Jordan' 'Monty' 'Morray'
#  'Mr. Acker Bilk' 'Mr. ColliPark' 'Mr. Hudson' 'Murda Beatz' 'Murphy Lee']
# ["Marilyn McCoo", "Mario Winans", "Mark Lindsay", "Mark Ronson", "Marky Mark & The Funky Bunch", "Maroon 5", "Marshmello", "Marvin Gaye", "Marvin Hamlisch", "Mary J. Blige", "Mase", "Mason Williams", "Master P", "Matthew Santos", "Mauro Castillo", "Maxi Priest", "Me'Shell Ndegeocello", "Meco", "Meek Mill", "Megan Thee Stallion", "Meghan Trainor", "Melanie", "Method Man", "Metro Boomin", "Miami Sound Machine", "Michael Jackson", "Michael McDonald", "Michelle Branch", "Mick Jagger", "Migos", "Mike Jones", "Mike Post", "Mike Reno", "Mike Shorey", "Mikky Ekko", "Miley Cyrus", "Missy \"Misdemeanor\" Elliott", "Missy Elliott", "Mobb Deep", "Mocha", "Mongo Santamaria Band", "Monica", "Montell Jordan", "Monty", "Morray", "Mr. Acker Bilk", "Mr. ColliPark", "Mr. Hudson", "Murda Beatz", "Murphy Lee"]
#
# [['Marilyn McCoo', 'individual', 'female'], ['Mario Winans', 'individual', 'male'], ['Mark Lindsay', 'individual', 'male'], ['Mark Ronson', 'individual', 'male'], ['Marky Mark & The Funky Bunch', 'group', 'male'], ['Maroon 5', 'group', 'male'], ['Marshmello', 'individual', 'male'], ['Marvin Gaye', 'individual', 'male'], ['Marvin Hamlisch', 'individual', 'male'], ['Mary J. Blige', 'individual', 'female'], ['Mase', 'individual', 'male'], ['Mason Williams', 'individual', 'male'], ['Master P', 'individual', 'male'], ['Matthew Santos', 'individual', 'male'], ['Mauro Castillo', 'individual', 'male'], ['Maxi Priest', 'individual', 'male'], ["Me'Shell Ndegeocello", 'individual', 'female'], ['Meco', 'individual', 'male'], ['Meek Mill', 'individual', 'male'], ['Megan Thee Stallion', 'individual', 'female'], ['Meghan Trainor', 'individual', 'female'], ['Melanie', 'individual', 'female'], ['Method Man', 'individual', 'male'], ['Metro Boomin', 'individual', 'male'], ['Miami Sound Machine', 'group', 'mixed gender group'], ['Michael Jackson', 'individual', 'male'], ['Michael McDonald', 'individual', 'male'], ['Michelle Branch', 'individual', 'female'], ['Mick Jagger', 'individual', 'male'], ['Migos', 'group', 'male'], ['Mike Jones', 'individual', 'male'], ['Mike Post', 'individual', 'male'], ['Mike Reno', 'individual', 'male'], ['Mike Shorey', 'individual', 'male'], ['Mikky Ekko', 'individual', 'male'], ['Miley Cyrus', 'individual', 'female'], ['Missy "Misdemeanor" Elliott', 'individual', 'female'], ['Missy Elliott', 'individual', 'female'], ['Mobb Deep', 'group', 'male'], ['Mocha', 'individual', 'female'], ['Mongo Santamaria Band', 'group', 'mixed gender group'], ['Monica', 'individual', 'female'], ['Montell Jordan', 'individual', 'male'], ['Monty', 'individual', 'male'], ['Morray', 'individual', 'male'], ['Mr. Acker Bilk', 'individual', 'male'], ['Mr. ColliPark', 'individual', 'male'], ['Mr. Hudson', 'individual', 'male'], ['Murda Beatz', 'individual', 'male'], ['Murphy Lee', 'individual', 'male']]
# [550, 600]
# ['Mya' 'Mystikal' 'NAV' 'Nancy Sinatra' 'Nas' 'Natalie La Rose'
#  'Nate Dogg' 'Nate Ruess' 'Naughty By Nature' 'Nayer' 'Ne-Yo'
#  'Neil Diamond' 'Nelly' 'Nelly Furtado' 'Nicki Minaj' 'Nicky Youre'
#  'Nicole' 'Nicole Scherzinger' 'Nina Sky' 'Nino Tempo' 'Nivea' 'No Doubt'
#  'Normani' 'Odia Coates' 'Offset' 'Oliver Anthony Music' 'Olivia'
#  'Olivia Newton-John' "Olivia O'Brien" 'Omarion' 'OneRepublic' 'Orchestra'
#  'OutKast' 'Owl City' 'Ozzy Osbourne' 'P!nk' 'P. Diddy' 'Patrick Stump'
#  'Patrick Swayze' 'Patti Austin' 'Patti LaBelle' 'Patty Smyth' 'Paul'
#  'Paul Anka' 'Paul Anthony' 'Paul Evans' 'Paul Mauriat' 'Paul McCartney'
#  'Paul McCoy' 'Paul Revere & The Raiders']
# ["Mya", "Mystikal", "NAV", "Nancy Sinatra", "Nas", "Natalie La Rose", "Nate Dogg", "Nate Ruess", "Naughty By Nature", "Nayer", "Ne-Yo", "Neil Diamond", "Nelly", "Nelly Furtado", "Nicki Minaj", "Nicky Youre", "Nicole", "Nicole Scherzinger", "Nina Sky", "Nino Tempo", "Nivea", "No Doubt", "Normani", "Odia Coates", "Offset", "Oliver Anthony Music", "Olivia", "Olivia Newton-John", "Olivia O'Brien", "Omarion", "OneRepublic", "Orchestra", "OutKast", "Owl City", "Ozzy Osbourne", "P!nk", "P. Diddy", "Patrick Stump", "Patrick Swayze", "Patti Austin", "Patti LaBelle", "Patty Smyth", "Paul", "Paul Anka", "Paul Anthony", "Paul Evans", "Paul Mauriat", "Paul McCartney", "Paul McCoy", "Paul Revere & The Raiders"]
#
# [['Mya', 'individual', 'female'], ['Mystikal', 'individual', 'male'], ['NAV', 'individual', 'male'], ['Nancy Sinatra', 'individual', 'female'], ['Nas', 'individual', 'male'], ['Natalie La Rose', 'individual', 'female'], ['Nate Dogg', 'individual', 'male'], ['Nate Ruess', 'individual', 'male'], ['Naughty By Nature', 'group', 'male'], ['Nayer', 'individual', 'female'], ['Ne-Yo', 'individual', 'male'], ['Neil Diamond', 'individual', 'male'], ['Nelly', 'individual', 'male'], ['Nelly Furtado', 'individual', 'female'], ['Nicki Minaj', 'individual', 'female'], ['Nicky Youre', 'individual', 'male'], ['Nicole', 'individual', 'female'], ['Nicole Scherzinger', 'individual', 'female'], ['Nina Sky', 'group', 'female'], ['Nino Tempo', 'individual', 'male'], ['Nivea', 'individual', 'female'], ['No Doubt', 'group', 'mixed gender group'], ['Normani', 'individual', 'female'], ['Odia Coates', 'individual', 'female'], ['Offset', 'individual', 'male'], ['Oliver Anthony Music', 'individual', 'male'], ['Olivia', 'individual', 'female'], ['Olivia Newton-John', 'individual', 'female'], ["Olivia O'Brien", 'individual', 'female'], ['Omarion', 'individual', 'male'], ['OneRepublic', 'group', 'male'], ['Orchestra', 'unknown', 'unknown'], ['OutKast', 'group', 'male'], ['Owl City', 'individual', 'male'], ['Ozzy Osbourne', 'individual', 'male'], ['P!nk', 'individual', 'female'], ['P. Diddy', 'individual', 'male'], ['Patrick Stump', 'individual', 'male'], ['Patrick Swayze', 'individual', 'male'], ['Patti Austin', 'individual', 'female'], ['Patti LaBelle', 'individual', 'female'], ['Patty Smyth', 'individual', 'female'], ['Paul', 'unknown', 'unknown'], ['Paul Anka', 'individual', 'male'], ['Paul Anthony', 'unknown', 'unknown'], ['Paul Evans', 'individual', 'male'], ['Paul Mauriat', 'individual', 'male'], ['Paul McCartney', 'individual', 'male'], ['Paul McCoy', 'individual', 'male'], ['Paul Revere & The Raiders', 'group', 'male']]
# [600, 650]
# ['Paul Simon' 'Paul Wall' 'Paula' 'Paula Abdul' 'Peabo Bryson'
#  'Percy Faith' 'Perez Prado' 'Perry Botkin Jr.' 'Perry Botkin, Jr.'
#  'Peso Pluma' 'Pet Shop Boys' 'Peter Brown' 'Peter Cetera' 'Petey Pablo'
#  'Pharrell' 'Pharrell Williams' 'Phil Collins' 'Phil Phillips'
#  'Philip Bailey' 'PinkPantheress' 'Pitbull' 'Playboi Carti' 'Plies'
#  'Polo G' 'Polow Da Don' 'Pop Smoke' 'Post Malone' 'Pratt & McClain'
#  'Project Pat' 'Puff Daddy' 'Puff Daddy & The Family' 'Q-Tip' 'Quavo'
#  'R. City' 'R. Kelly' 'R.L.' 'Rae Sremmurd' 'Rakim' 'Ralph Tresvant'
#  'Ramsey Lewis Trio' 'Randy Travis' 'Randy VanWarmer' 'Ray Anthony'
#  'Ray Charles' 'Ray Dalton' 'Ray J' 'Ray Parker Jr.' 'Raydio' 'Rayvon'
#  'Redman']
# ["Paul Simon", "Paul Wall", "Paula", "Paula Abdul", "Peabo Bryson", "Percy Faith", "Perez Prado", "Perry Botkin Jr.", "Perry Botkin, Jr.", "Peso Pluma", "Pet Shop Boys", "Peter Brown", "Peter Cetera", "Petey Pablo", "Pharrell", "Pharrell Williams", "Phil Collins", "Phil Phillips", "Philip Bailey", "PinkPantheress", "Pitbull", "Playboi Carti", "Plies", "Polo G", "Polow Da Don", "Pop Smoke", "Post Malone", "Pratt & McClain", "Project Pat", "Puff Daddy", "Puff Daddy & The Family", "Q-Tip", "Quavo", "R. City", "R. Kelly", "R.L.", "Rae Sremmurd", "Rakim", "Ralph Tresvant", "Ramsey Lewis Trio", "Randy Travis", "Randy VanWarmer", "Ray Anthony", "Ray Charles", "Ray Dalton", "Ray J", "Ray Parker Jr.", "Raydio", "Rayvon", "Redman"]
#
# [['Paul Simon', 'individual', 'male'], ['Paul Wall', 'individual', 'male'], ['Paula', 'unknown', 'unknown'], ['Paula Abdul', 'individual', 'female'], ['Peabo Bryson', 'individual', 'male'], ['Percy Faith', 'individual', 'male'], ['Perez Prado', 'individual', 'male'], ['Perry Botkin Jr.', 'individual', 'male'], ['Perry Botkin, Jr.', 'individual', 'male'], ['Peso Pluma', 'individual', 'male'], ['Pet Shop Boys', 'group', 'male'], ['Peter Brown', 'individual', 'male'], ['Peter Cetera', 'individual', 'male'], ['Petey Pablo', 'individual', 'male'], ['Pharrell', 'individual', 'male'], ['Pharrell Williams', 'individual', 'male'], ['Phil Collins', 'individual', 'male'], ['Phil Phillips', 'individual', 'male'], ['Philip Bailey', 'individual', 'male'], ['PinkPantheress', 'individual', 'female'], ['Pitbull', 'individual', 'male'], ['Playboi Carti', 'individual', 'male'], ['Plies', 'individual', 'male'], ['Polo G', 'individual', 'male'], ['Polow Da Don', 'individual', 'male'], ['Pop Smoke', 'individual', 'male'], ['Post Malone', 'individual', 'male'], ['Pratt & McClain', 'group', 'male'], ['Project Pat', 'individual', 'male'], ['Puff Daddy', 'individual', 'male'], ['Puff Daddy & The Family', 'group', 'mixed gender group'], ['Q-Tip', 'individual', 'male'], ['Quavo', 'individual', 'male'], ['R. City', 'group', 'male'], ['R. Kelly', 'individual', 'male'], ['R.L.', 'individual', 'male'], ['Rae Sremmurd', 'group', 'male'], ['Rakim', 'individual', 'male'], ['Ralph Tresvant', 'individual', 'male'], ['Ramsey Lewis Trio', 'group', 'male'], ['Randy Travis', 'individual', 'male'], ['Randy VanWarmer', 'individual', 'male'], ['Ray Anthony', 'individual', 'male'], ['Ray Charles', 'individual', 'male'], ['Ray Dalton', 'individual', 'male'], ['Ray J', 'individual', 'male'], ['Ray Parker Jr.', 'individual', 'male'], ['Raydio', 'group', 'male'], ['Rayvon', 'individual', 'male'], ['Redman', 'individual', 'male']]
# [650, 700]
# ['Regina Belle' 'Rema' 'Remy Boyz' 'Rhenzy Feliz' 'Rhythm Heritage'
#  'Ricardo "RikRok" Ducent' 'Rich Boy' 'Rick Dees' 'Rick Ross' 'Rihanna'
#  'Rita Ora' 'Rivers Cuomo' 'Rob Thomas' 'Roberta Flack' 'Robin Thicke'
#  'Robin Zander' 'Rod Stewart' 'Roddy Ricch' 'Ron Holden' 'Ronald Isley'
#  'Roy Orbison' 'Royal Philharmonic Orchestra' 'Rozes' 'Rufus'
#  'Russell Thompkins, Jr.' 'Ryan Lewis' 'Ryan Tedder' 'SZA' 'Sabi'
#  'Safaris' 'Sage The Gemini' 'Salt-N-Pepa' 'Sam Smith' 'Sammie'
#  'Sammy Davis, Jr.' 'Sandy Nelson' 'Santana' 'Santo' 'Scandal'
#  'Seals & Crofts' 'Sean Paul' 'Sean Paul Of The YoungBloodZ'
#  'Selena Gomez' 'Shaggy' 'Shakira' 'Shawn Mendes' 'Shawnna' 'Shay'
#  'Sheena Easton' 'Sheryl Crow']
# ["Regina Belle", "Rema", "Remy Boyz", "Rhenzy Feliz", "Rhythm Heritage", "Ricardo \"RikRok\" Ducent", "Rich Boy", "Rick Dees", "Rick Ross", "Rihanna", "Rita Ora", "Rivers Cuomo", "Rob Thomas", "Roberta Flack", "Robin Thicke", "Robin Zander", "Rod Stewart", "Roddy Ricch", "Ron Holden", "Ronald Isley", "Roy Orbison", "Royal Philharmonic Orchestra", "Rozes", "Rufus", "Russell Thompkins, Jr.", "Ryan Lewis", "Ryan Tedder", "SZA", "Sabi", "Safaris", "Sage The Gemini", "Salt-N-Pepa", "Sam Smith", "Sammie", "Sammy Davis, Jr.", "Sandy Nelson", "Santana", "Santo", "Scandal", "Seals & Crofts", "Sean Paul", "Sean Paul Of The YoungBloodZ", "Selena Gomez", "Shaggy", "Shakira", "Shawn Mendes", "Shawnna", "Shay", "Sheena Easton", "Sheryl Crow"]
#
# [['Regina Belle', 'individual', 'female'], ['Rema', 'individual', 'male'], ['Remy Boyz', 'group', 'male'], ['Rhenzy Feliz', 'individual', 'male'], ['Rhythm Heritage', 'group', 'male'], ['Ricardo "RikRok" Ducent', 'individual', 'male'], ['Rich Boy', 'individual', 'male'], ['Rick Dees', 'individual', 'male'], ['Rick Ross', 'individual', 'male'], ['Rihanna', 'individual', 'female'], ['Rita Ora', 'individual', 'female'], ['Rivers Cuomo', 'individual', 'male'], ['Rob Thomas', 'individual', 'male'], ['Roberta Flack', 'individual', 'female'], ['Robin Thicke', 'individual', 'male'], ['Robin Zander', 'individual', 'male'], ['Rod Stewart', 'individual', 'male'], ['Roddy Ricch', 'individual', 'male'], ['Ron Holden', 'individual', 'male'], ['Ronald Isley', 'individual', 'male'], ['Roy Orbison', 'individual', 'male'], ['Royal Philharmonic Orchestra', 'group', 'mixed gender group'], ['Rozes', 'individual', 'female'], ['Rufus', 'group', 'mixed gender group'], ['Russell Thompkins, Jr.', 'individual', 'male'], ['Ryan Lewis', 'individual', 'male'], ['Ryan Tedder', 'individual', 'male'], ['SZA', 'individual', 'female'], ['Sabi', 'individual', 'female'], ['Safaris', 'group', 'male'], ['Sage The Gemini', 'individual', 'male'], ['Salt-N-Pepa', 'group', 'female'], ['Sam Smith', 'individual', 'non-binary'], ['Sammie', 'individual', 'male'], ['Sammy Davis, Jr.', 'individual', 'male'], ['Sandy Nelson', 'individual', 'male'], ['Santana', 'group', 'mixed gender group'], ['Santo', 'unknown', 'unknown'], ['Scandal', 'group', 'mixed gender group'], ['Seals & Crofts', 'group', 'male'], ['Sean Paul', 'individual', 'male'], ['Sean Paul Of The YoungBloodZ', 'individual', 'male'], ['Selena Gomez', 'individual', 'female'], ['Shaggy', 'individual', 'male'], ['Shakira', 'individual', 'female'], ['Shawn Mendes', 'individual', 'male'], ['Shawnna', 'individual', 'female'], ['Shay', 'unknown', 'unknown'], ['Sheena Easton', 'individual', 'female'], ['Sheryl Crow', 'individual', 'female']]
# [700, 750]
# ['Shirley Jones' 'Sia' 'Siedah Garrett' 'Silkk The Shocker'
#  'Sir Monti Rock III' 'Sisqo' 'Skip Marley' 'Skrillex & Diplo'
#  'Skylar Grey' 'Sleepy Brown' 'Slim Thug' 'Snoop Dogg'
#  'Snoop Dogg & Wiz Khalifa' 'Social House' 'Sole'
#  "Somethin' For The People" 'Soulja Boy' 'Soulja Slim' 'Spinners'
#  'Spragga Benz' 'Stan Getz' 'Static Major' 'Stephanie Beatriz'
#  'Steve Mandell' 'Stevie Nicks' 'Stevie Wonder' 'Sting' 'Styles'
#  'Styles P.' 'Sugarloaf' 'Susan Jacks' 'Suzanne Vega' 'Suzi Quatro'
#  'Swae Lee' 'Swedish House Mafia' 'Syleena Johnson' 'Sylk-E. Fyne' 'Synch'
#  'Syreeta' 'T-Pain' 'T.I.' 'THE SCOTTS' 'Taio Cruz' 'Tamara' 'Tamia'
#  'Tammi Terrell' 'Tammy Ruggeri' 'Taylor Swift' 'Technotronic' 'Tems']
# ["Shirley Jones", "Sia", "Siedah Garrett", "Silkk The Shocker", "Sir Monti Rock III", "Sisqo", "Skip Marley", "Skrillex & Diplo", "Skylar Grey", "Sleepy Brown", "Slim Thug", "Snoop Dogg", "Snoop Dogg & Wiz Khalifa", "Social House", "Sole", "Somethin' For The People", "Soulja Boy", "Soulja Slim", "Spinners", "Spragga Benz", "Stan Getz", "Static Major", "Stephanie Beatriz", "Steve Mandell", "Stevie Nicks", "Stevie Wonder", "Sting", "Styles", "Styles P.", "Sugarloaf", "Susan Jacks", "Suzanne Vega", "Suzi Quatro", "Swae Lee", "Swedish House Mafia", "Syleena Johnson", "Sylk-E. Fyne", "Synch", "Syreeta", "T-Pain", "T.I.", "THE SCOTTS", "Taio Cruz", "Tamara", "Tamia", "Tammi Terrell", "Tammy Ruggeri", "Taylor Swift", "Technotronic", "Tems"]
#
# [['Shirley Jones', 'individual', 'female'], ['Sia', 'individual', 'female'], ['Siedah Garrett', 'individual', 'female'], ['Silkk The Shocker', 'individual', 'male'], ['Sir Monti Rock III', 'individual', 'male'], ['Sisqo', 'individual', 'male'], ['Skip Marley', 'individual', 'male'], ['Skrillex & Diplo', 'group', 'male'], ['Skylar Grey', 'individual', 'female'], ['Sleepy Brown', 'individual', 'male'], ['Slim Thug', 'individual', 'male'], ['Snoop Dogg', 'individual', 'male'], ['Snoop Dogg & Wiz Khalifa', 'group', 'male'], ['Social House', 'group', 'male'], ['Sole', 'individual', 'female'], ["Somethin' For The People", 'group', 'mixed gender group'], ['Soulja Boy', 'individual', 'male'], ['Soulja Slim', 'individual', 'male'], ['Spinners', 'group', 'male'], ['Spragga Benz', 'individual', 'male'], ['Stan Getz', 'individual', 'male'], ['Static Major', 'individual', 'male'], ['Stephanie Beatriz', 'individual', 'female'], ['Steve Mandell', 'individual', 'male'], ['Stevie Nicks', 'individual', 'female'], ['Stevie Wonder', 'individual', 'male'], ['Sting', 'individual', 'male'], ['Styles', 'individual', 'male'], ['Styles P.', 'individual', 'male'], ['Sugarloaf', 'group', 'male'], ['Susan Jacks', 'individual', 'female'], ['Suzanne Vega', 'individual', 'female'], ['Suzi Quatro', 'individual', 'female'], ['Swae Lee', 'individual', 'male'], ['Swedish House Mafia', 'group', 'male'], ['Syleena Johnson', 'individual', 'female'], ['Sylk-E. Fyne', 'individual', 'female'], ['Synch', 'unknown', 'unknown'], ['Syreeta', 'individual', 'female'], ['T-Pain', 'individual', 'male'], ['T.I.', 'individual', 'male'], ['THE SCOTTS', 'group', 'male'], ['Taio Cruz', 'individual', 'male'], ['Tamara', 'unknown', 'unknown'], ['Tamia', 'individual', 'female'], ['Tammi Terrell', 'individual', 'female'], ['Tammy Ruggeri', 'unknown', 'unknown'], ['Taylor Swift', 'individual', 'female'], ['Technotronic', 'group', 'mixed gender group'], ['Tems', 'individual', 'female']]
# [750, 800]
# ['Tennille' 'Teri DeSario' 'The 4 Seasons' 'The Aces' 'The Afterbeats'
#  'The Beaters' 'The Beatles' 'The Belmonts' 'The Big Apple Band'
#  'The Browns' 'The Candy Men' 'The Captain' 'The Chainsmokers'
#  'The Checkmates' 'The Chipmunks' 'The Dakotas' 'The DeFranco Family'
#  'The Delegates' 'The Detroit Guitar Band' 'The Dixie Hummingbirds'
#  'The Dominos' 'The Drells' 'The East Side Boyz'
#  'The Edwin Hawkins Singers' "The Edwin Hawkins' Singers"
#  'The Electric Light Orchestra' 'The Emotions'
#  'The Exotic Sounds of Martin Denny' 'The Fireballs' 'The First Edition'
#  'The Flipmode Squad' 'The Fresh Prince' 'The Game' 'The Innocents'
#  'The Jewels' 'The Jive Five' 'The Jordanaires' 'The Kid LAROI'
#  'The Marketts' 'The Medicine Show' 'The Mike Curb Congregation'
#  'The Mindbenders' 'The Miracles' 'The Mysterians' 'The Notorious B.I.G.'
#  'The Osmonds' 'The Partridge Family' "The Phantom's Band"
#  'The Plastic Ono Nuclear Band' 'The Poppy Family']
# ["Tennille", "Teri DeSario", "The 4 Seasons", "The Aces", "The Afterbeats", "The Beaters", "The Beatles", "The Belmonts", "The Big Apple Band", "The Browns", "The Candy Men", "The Captain", "The Chainsmokers", "The Checkmates", "The Chipmunks", "The Dakotas", "The DeFranco Family", "The Delegates", "The Detroit Guitar Band", "The Dixie Hummingbirds", "The Dominos", "The Drells", "The East Side Boyz", "The Edwin Hawkins Singers", "The Edwin Hawkins' Singers", "The Electric Light Orchestra", "The Emotions", "The Exotic Sounds of Martin Denny", "The Fireballs", "The First Edition", "The Flipmode Squad", "The Fresh Prince", "The Game", "The Innocents", "The Jewels", "The Jive Five", "The Jordanaires", "The Kid LAROI", "The Marketts", "The Medicine Show", "The Mike Curb Congregation", "The Mindbenders", "The Miracles", "The Mysterians", "The Notorious B.I.G.", "The Osmonds", "The Partridge Family", "The Phantom's Band", "The Plastic Ono Nuclear Band", "The Poppy Family"]
#
# [['Tennille', 'individual', 'female'], ['Teri DeSario', 'individual', 'female'], ['The 4 Seasons', 'group', 'male'], ['The Aces', 'group', 'female'], ['The Afterbeats', 'unknown', 'unknown'], ['The Beaters', 'unknown', 'unknown'], ['The Beatles', 'group', 'male'], ['The Belmonts', 'group', 'male'], ['The Big Apple Band', 'group', 'male'], ['The Browns', 'group', 'mixed gender group'], ['The Candy Men', 'group', 'male'], ['The Captain', 'individual', 'male'], ['The Chainsmokers', 'group', 'male'], ['The Checkmates', 'group', 'male'], ['The Chipmunks', 'group', 'male'], ['The Dakotas', 'group', 'male'], ['The DeFranco Family', 'group', 'mixed gender group'], ['The Delegates', 'group', 'male'], ['The Detroit Guitar Band', 'unknown', 'unknown'], ['The Dixie Hummingbirds', 'group', 'male'], ['The Dominos', 'group', 'male'], ['The Drells', 'group', 'male'], ['The East Side Boyz', 'group', 'male'], ['The Edwin Hawkins Singers', 'group', 'mixed gender group'], ["The Edwin Hawkins' Singers", 'group', 'mixed gender group'], ['The Electric Light Orchestra', 'group', 'male'], ['The Emotions', 'group', 'female'], ['The Exotic Sounds of Martin Denny', 'group', 'male'], ['The Fireballs', 'group', 'male'], ['The First Edition', 'group', 'mixed gender group'], ['The Flipmode Squad', 'group', 'male'], ['The Fresh Prince', 'individual', 'male'], ['The Game', 'individual', 'male'], ['The Innocents', 'group', 'male'], ['The Jewels', 'group', 'female'], ['The Jive Five', 'group', 'male'], ['The Jordanaires', 'group', 'male'], ['The Kid LAROI', 'individual', 'male'], ['The Marketts', 'group', 'male'], ['The Medicine Show', 'unknown', 'unknown'], ['The Mike Curb Congregation', 'group', 'mixed gender group'], ['The Mindbenders', 'group', 'male'], ['The Miracles', 'group', 'mixed gender group'], ['The Mysterians', 'group', 'male'], ['The Notorious B.I.G.', 'individual', 'male'], ['The Osmonds', 'group', 'male'], ['The Partridge Family', 'group', 'mixed gender group'], ["The Phantom's Band", 'unknown', 'unknown'], ['The Plastic Ono Nuclear Band', 'unknown', 'unknown'], ['The Poppy Family', 'group', 'mixed gender group']]
# [800, 850]
# ['The Product G&B' 'The Pussycat Dolls' 'The Rebels' 'The Revelletts'
#  'The Sex-O-Lettes' 'The Shelter People' 'The Soul City Symphony'
#  'The Stylistics' 'The Supremes' 'The T-Bones' 'The Temptations'
#  'The Three Degrees' 'The Thunderbirds' 'The Tijuana Brass'
#  'The Tornadoes' 'The Triumphs' 'The Twilights' 'The Union Gap'
#  'The Ventures' 'The Village Stompers' 'The Weeknd' 'The Wild Pair'
#  'Thomas Wayne' 'Tijuana Brass' 'Tim McGraw' 'Timbaland' 'Tom Clay'
#  'Tom Parker' 'Tom Petty And The Heartbreakers' 'Tommy Boyce'
#  'Tony DeFranco' 'Tony Orlando' 'Tony! Toni! Tone!' 'Too $hort' 'Toosii'
#  'Tory Lanez' 'Total' 'Toya' 'Travie McCoy' 'Travis Scott' 'Trey Songz'
#  'Trick Daddy' 'Trina' 'Truth Hurts' 'Twista' 'Ty Dolla $ign' 'Tyga'
#  'Tyrese' 'Uncle Charlie Wilson' 'Uncle Kracker']
# ["The Product G&B", "The Pussycat Dolls", "The Rebels", "The Revelletts", "The Sex-O-Lettes", "The Shelter People", "The Soul City Symphony", "The Stylistics", "The Supremes", "The T-Bones", "The Temptations", "The Three Degrees", "The Thunderbirds", "The Tijuana Brass", "The Tornadoes", "The Triumphs", "The Twilights", "The Union Gap", "The Ventures", "The Village Stompers", "The Weeknd", "The Wild Pair", "Thomas Wayne", "Tijuana Brass", "Tim McGraw", "Timbaland", "Tom Clay", "Tom Parker", "Tom Petty And The Heartbreakers", "Tommy Boyce", "Tony DeFranco", "Tony Orlando", "Tony! Toni! Tone!", "Too $hort", "Toosii", "Tory Lanez", "Total", "Toya", "Travie McCoy", "Travis Scott", "Trey Songz", "Trick Daddy", "Trina", "Truth Hurts", "Twista", "Ty Dolla $ign", "Tyga", "Tyrese", "Uncle Charlie Wilson", "Uncle Kracker"]
#
# [['The Product G&B', 'group', 'male'], ['The Pussycat Dolls', 'group', 'female'], ['The Rebels', 'unknown', 'unknown'], ['The Revelletts', 'unknown', 'unknown'], ['The Sex-O-Lettes', 'unknown', 'unknown'], ['The Shelter People', 'unknown', 'unknown'], ['The Soul City Symphony', 'unknown', 'unknown'], ['The Stylistics', 'group', 'male'], ['The Supremes', 'group', 'female'], ['The T-Bones', 'group', 'male'], ['The Temptations', 'group', 'male'], ['The Three Degrees', 'group', 'female'], ['The Thunderbirds', 'unknown', 'unknown'], ['The Tijuana Brass', 'group', 'male'], ['The Tornadoes', 'group', 'male'], ['The Triumphs', 'unknown', 'unknown'], ['The Twilights', 'unknown', 'unknown'], ['The Union Gap', 'group', 'male'], ['The Ventures', 'group', 'male'], ['The Village Stompers', 'group', 'male'], ['The Weeknd', 'individual', 'male'], ['The Wild Pair', 'unknown', 'unknown'], ['Thomas Wayne', 'individual', 'male'], ['Tijuana Brass', 'unknown', 'unknown'], ['Tim McGraw', 'individual', 'male'], ['Timbaland', 'individual', 'male'], ['Tom Clay', 'individual', 'male'], ['Tom Parker', 'individual', 'male'], ['Tom Petty And The Heartbreakers', 'group', 'male'], ['Tommy Boyce', 'individual', 'male'], ['Tony DeFranco', 'individual', 'male'], ['Tony Orlando', 'individual', 'male'], ['Tony! Toni! Tone!', 'group', 'male'], ['Too $hort', 'individual', 'male'], ['Toosii', 'individual', 'male'], ['Tory Lanez', 'individual', 'male'], ['Total', 'group', 'female'], ['Toya', 'individual', 'female'], ['Travie McCoy', 'individual', 'male'], ['Travis Scott', 'individual', 'male'], ['Trey Songz', 'individual', 'male'], ['Trick Daddy', 'individual', 'male'], ['Trina', 'individual', 'female'], ['Truth Hurts', 'individual', 'female'], ['Twista', 'individual', 'male'], ['Ty Dolla $ign', 'individual', 'male'], ['Tyga', 'individual', 'male'], ['Tyrese', 'individual', 'male'], ['Uncle Charlie Wilson', 'individual', 'male'], ['Uncle Kracker', 'individual', 'male']]
# [850, 900]
# ['Usher' 'Van McCoy' 'Vanessa Anne Hudgens' 'Vanessa Williams' 'Vita'
#  'Vonda Shepard' 'Walter Murphy' 'Wanz' 'Warren G' 'Wayne Fontana'
#  'Webbie' 'Wendy Fraser' 'Wham!' 'Whitney Houston' 'Will Smith'
#  'Willie Nelson' 'Willy William' 'Wings' 'Wiz Khalifa' 'Wizkid'
#  'Wyclef Jean' 'Wynter' 'XXXTENTACION' 'Xscape' 'YG' 'Ya Kid K' 'Yanou'
#  'Ying Yang Twins' 'Yo Gotti' 'Young Dro' 'Young Jeezy' 'Young Money'
#  'Young Thug' 'Young-Holt Unlimited' 'YoungBloodZ'
#  'YoungBoy Never Broke Again' 'Yung Berg' 'Yung Joc' 'Zac Efron'
#  'Zach Bryan' 'Zay Hilfigerrr' 'Zayion McCall' 'Zayn' 'Zedd' 'Zhane'
#  'benny blanco' 'dazy' 'fun.' 'gnash' 'iann dior']
# ["Usher", "Van McCoy", "Vanessa Anne Hudgens", "Vanessa Williams", "Vita", "Vonda Shepard", "Walter Murphy", "Wanz", "Warren G", "Wayne Fontana", "Webbie", "Wendy Fraser", "Wham!", "Whitney Houston", "Will Smith", "Willie Nelson", "Willy William", "Wings", "Wiz Khalifa", "Wizkid", "Wyclef Jean", "Wynter", "XXXTENTACION", "Xscape", "YG", "Ya Kid K", "Yanou", "Ying Yang Twins", "Yo Gotti", "Young Dro", "Young Jeezy", "Young Money", "Young Thug", "Young-Holt Unlimited", "YoungBloodZ", "YoungBoy Never Broke Again", "Yung Berg", "Yung Joc", "Zac Efron", "Zach Bryan", "Zay Hilfigerrr", "Zayion McCall", "Zayn", "Zedd", "Zhane", "benny blanco", "dazy", "fun.", "gnash", "iann dior"]
#
# [['Usher', 'individual', 'male'], ['Van McCoy', 'individual', 'male'], ['Vanessa Anne Hudgens', 'individual', 'female'], ['Vanessa Williams', 'individual', 'female'], ['Vita', 'individual', 'female'], ['Vonda Shepard', 'individual', 'female'], ['Walter Murphy', 'individual', 'male'], ['Wanz', 'individual', 'male'], ['Warren G', 'individual', 'male'], ['Wayne Fontana', 'individual', 'male'], ['Webbie', 'individual', 'male'], ['Wendy Fraser', 'individual', 'female'], ['Wham!', 'group', 'male'], ['Whitney Houston', 'individual', 'female'], ['Will Smith', 'individual', 'male'], ['Willie Nelson', 'individual', 'male'], ['Willy William', 'individual', 'male'], ['Wings', 'group', 'mixed gender group'], ['Wiz Khalifa', 'individual', 'male'], ['Wizkid', 'individual', 'male'], ['Wyclef Jean', 'individual', 'male'], ['Wynter', 'individual', 'female'], ['XXXTENTACION', 'individual', 'male'], ['Xscape', 'group', 'female'], ['YG', 'individual', 'male'], ['Ya Kid K', 'individual', 'female'], ['Yanou', 'individual', 'male'], ['Ying Yang Twins', 'group', 'male'], ['Yo Gotti', 'individual', 'male'], ['Young Dro', 'individual', 'male'], ['Young Jeezy', 'individual', 'male'], ['Young Money', 'group', 'mixed gender group'], ['Young Thug', 'individual', 'male'], ['Young-Holt Unlimited', 'group', 'male'], ['YoungBloodZ', 'group', 'male'], ['YoungBoy Never Broke Again', 'individual', 'male'], ['Yung Berg', 'individual', 'male'], ['Yung Joc', 'individual', 'male'], ['Zac Efron', 'individual', 'male'], ['Zach Bryan', 'individual', 'male'], ['Zay Hilfigerrr', 'individual', 'male'], ['Zayion McCall', 'individual', 'male'], ['Zayn', 'individual', 'male'], ['Zedd', 'individual', 'male'], ['Zhane', 'group', 'female'], ['benny blanco', 'individual', 'male'], ['dazy', 'individual', 'male'], ['fun.', 'group', 'male'], ['gnash', 'individual', 'male'], ['iann dior', 'individual', 'male']]
# [900, 950]
# ['the Blackhearts' 'the Curls' 'the Delons' 'will.i.am']
# ["the Blackhearts", "the Curls", "the Delons", "will.i.am"]
#
# ERROR FETCHING unexpected indent (<unknown>, line 2)
# []

# %%
# save_to_temp_csv(
#     fetch_all_data_in_batches(
#         performers_list[900:950] # an error apparently happened
#     ), 
#     2
# )
# Out:
# [0, 50]
# ['the Blackhearts' 'the Curls' 'the Delons' 'will.i.am']
# ["the Blackhearts", "the Curls", "the Delons", "will.i.am"]
#
# [['the Blackhearts', 'group', 'mixed gender group'], ['the Curls', 'group', 'mixed gender group'], ['the Delons', 'unknown', 'unknown'], ['will.i.am', 'individual', 'male']]

# %%
# save_to_temp_csv(
#     fetch_all_data_in_batches(
#         performers_list[2000:3000]
#     ), 
#     3
# )

# %% [markdown]
# # Merge the fetched data with the existing data. !NOTE! for convenience, I'm doing a no-no and renaming `gender_df` and `performers_list` to be the full dataset going forward. Honestly this should have been 2 separate notebooks.

# %%
new_gender_df = pd.concat([
    pd.read_csv(get_file_path(DATA_FILE_KEY_1)),
    pd.read_csv(get_file_path(2)),
    # pd.read_csv(get_file_path(3))
])


# make a df of any in performers_list NOT in gender_df

# Ok, merge with existing, removing any duplicates
gender_df = pd.concat([
    existing_gender_table,
    new_gender_df
])

assert(len(existing_gender_table) == len(gender_df) - len(new_gender_df))

# Now let's get a new 
raw_performers_df = _all_performers_df.copy()
performers_list = np.unique(
    np.concatenate(raw_performers_df['performers_list_str'].str.split("|").apply(lambda x: [i for i in x if i]).values)
)
performers_list
# Out:
# array(['"The Sting"', '"Weird Al" Yankovic', "'N Sync", ..., 'the Delons',
#        'twenty one pilots', 'will.i.am'], dtype='<U43')

# %% [markdown]
# ## Do some sanity checks & identify issues

# %%
gender_df.type.value_counts()
# Out:
# type
# individual    2013
# group         1117
# unknown         52
# Name: count, dtype: int64

# %%
gender_df.gender.value_counts()
# Out:
# gender
# male                  2168
# female                 697
# mixed gender group     254
# unknown                 54
# non-binary               9
# Name: count, dtype: int64

# %% [markdown]
# ### Here is where we first caught the mistakes, which we fix below
#
# (why am I using "we"? It's just me, David. Hi.)

# %%
combnined = set([*performers_list, *gender_df['performer']])
# Print any performers that are not in both performers_list AND gender_df['performer']
culprit = None
for p in combnined:
    if p not in performers_list:
        culprit = p
        print(f"Performer '{p}' not in performers_list")

for performer in performers_list:
    if performer not in combnined:
        print(f"Performer '{performer}' not in combined")

gender_df[
    gender_df.performer.str.contains(culprit or '')
]

print('What IS in performers_list:', [performer for performer in performers_list if performer.startswith('Henry Mancini')])


# NA: write out WHAT the mistake is. Figure out how to fix it. (in this notebook of the last?)
# The mistakes is that I failed to TRIM the whitespace from the performer names, in the last notebook.
#
# Out:
# Performer 'Paul & Paula' not in performers_list
# Performer '? and the Mysterians' not in performers_list
# Performer 'The Curls' not in performers_list
# Performer 'I-20' not in performers_list
# Performer 'Diana Gordon' not in performers_list
# Performer 'Dan + Shay' not in performers_list
# Performer 'Tha Chill' not in performers_list
# Performer 'Cornelius Brothers & Sister Rose' not in performers_list
# Performer 'Randy Vanwarmer' not in performers_list
# Performer 'Travis & Bob' not in performers_list
# Performer 'Disco-Tex and the Sex-O-Lettes' not in performers_list
# Performer 'James & Bobby Purify' not in performers_list
# Performer 'Freedom Williams' not in performers_list
# Performer 'Trina & Tamara' not in performers_list
# Performer 'Dale & Grace' not in performers_list
# Performer 'Angie Martinez' not in performers_list
# Performer 'Jimmy Harnen with Synch' not in performers_list
# Performer 'Derek and the Dominos' not in performers_list
# Performer 'The Delons' not in performers_list
# What IS in performers_list: ['Henry Mancini And His Orchestra']

# %% [markdown]
# ### We detected an underlying data mistake: several performers end in some variation of `" And "`
#
# Note, however: these were all, helpfully, marketed as `unknown`. So we can address them within that larger type.

# %%
# The issue: seems GPT strugled with chopping of the ending "and ", thankfully pretty easy to identify.
[performer for performer in performers_list if performer.endswith(' ')]
# Out:
# []

# %%
gender_df[
    gender_df.performer.str.endswith(' And ')
    | gender_df.performer.str.endswith(' and ')
    | gender_df.performer.str.endswith(' & ')
    | gender_df.performer.str.endswith(' And')
]
# Out:
# Empty DataFrame
# Columns: [performer, type, gender]
# Index: []

# %% [markdown]
# # Make corrections

# %% [markdown]
# ## Apply `unkown` fixes

# %% [markdown]
# ### A. Export the `unknown`s, hand fix them in a spreadsheet, correct
#
# Types of fixes provided by gsheet:
# - It *is* a real performer. ACTION: Add the info, correct *just in the gender lookup table*
# - Incorrectly *parsed* name. ACTION: fix the name, correct both *gender lookup and name split tables*
# - The name shouldn't be in the dataset at all. ACTION: drop from BOTH *gender lookup and name split tables*

# %%
pd.set_option('display.max_rows', 30)
gender_df[
    gender_df.type == 'unknown'
]#.to_csv('./data/22.5-TEMP-unknown-gender-to-hand-correct.csv', index=False)
# Out:
#          performer     type   gender
# 0      "The Sting"  unknown  unknown
# 2        100 Proof  unknown  unknown
# 14               ?  unknown  unknown
# 29     Alice Bowie  unknown  unknown
# 36       Angie Mar  unknown  unknown
# ..             ...      ...      ...
# 815   The Triumphs  unknown  unknown
# 816  The Twilights  unknown  unknown
# 821  The Wild Pair  unknown  unknown
# 823  Tijuana Brass  unknown  unknown
# 2       the Delons  unknown  unknown
#
# [52 rows x 3 columns]

# %% [markdown]
# # PULL IN GOOGLE HAND FIXES

# %%
# Fetch the correction gSheet
G_SHEET_URL = "https://docs.google.com/spreadsheets/d/1xxE-vvzDUQTgYeigHMK_4lUznXAzDgNlAdY6JMOIOcc/export?format=csv&gid=1356757517"
gsheet_unknown_corrections_df = pd.read_csv(G_SHEET_URL)
gsheet_unknown_corrections_df

gsheet_unknown_corrections_df[gsheet_unknown_corrections_df.performer.str.contains('Henry Mancini')]
# Out:
#                           performer   type              gender  \
# 28  Henry Mancini And His Orchestra  group  mixed gender group
#
#                        correct_name drop_it
# 28  Henry Mancini And His Orchestra     NaN

# %%
# Fetch the incorrect split correction gSheet
INCORRECT_SPLIT_G_SHEET_URL = "https://docs.google.com/spreadsheets/d/1xxE-vvzDUQTgYeigHMK_4lUznXAzDgNlAdY6JMOIOcc/export?format=csv&gid=659955835"
gsheet_incorrect_split_corrections_df = pd.read_csv(INCORRECT_SPLIT_G_SHEET_URL)
gsheet_incorrect_split_corrections_df
# Out:
#           split_part_1        split_part_2                 replace_with_this  \
# 0                    ?      The Mysterians              ? and the Mysterians
# 1               Travis                 Bob                      Travis & Bob
# 2                James        Bobby Purify              James & Bobby Purify
# 3                 Dale               Grace                      Dale & Grace
# 4                  Dan                Shay                        Dan + Shay
# 5                Derek         The Dominos             Derek and the Dominos
# 6            Disco Tex    The Sex-O-Lettes    Disco-Tex and the Sex-O-Lettes
# 7                 Paul               Paula                      Paul & Paula
# 8   Cornelius Brothers         Sister Rose  Cornelius Brothers & Sister Rose
# 9         Jimmy Harnen               Synch           Jimmy Harnen with Synch
# 10               Trina              Tamara                    Trina & Tamara
# 11              Apollo          Tom Parker       Apollo featuring Tom Parker
# 12           Billy Joe      The Checkmates        Billy Joe & The Checkmates
# 13           Rick Dees  His Cast Of Idiots    Rick Dees & His Cast Of Idiots
# 14               Santo              Johnny                    Santo & Johnny
# 15         Herb Alpert       Tijuana Brass     Herb Alpert And Tijuana Brass
# 16         Herb Alpert   The Tijuana Brass   Herb Alpert & The Tijuana Brass
#
#      type              gender
# 0   group                male
# 1   group                male
# 2   group                male
# 3   group  mixed gender group
# 4   group                male
# 5   group                male
# 6   group  mixed gender group
# 7   group  mixed gender group
# 8   group  mixed gender group
# 9   group                male
# 10  group              female
# 11  group                male
# 12  group                male
# 13  group  mixed gender group
# 14  group                male
# 15  group                male
# 16  group                male

# %% [markdown]
# ### B. Finicky fixes listed below by removing the SPLIT names, replacing them with the FULL name
#
# *Groups that were erroniously split* (these have been marked as `drop_it` in the gsheet)
# - "? and the Mysterians" should be the entry, not a split out "?" and "The Mysterians"
# - "Travis & Bob" is right, not "Travis" and "Bob"
# - "James & Bobby Purify" is a group (don't split)
# - "Dale and Grace" eg on I'm Leaving it Up to You
# - "Dan + Shay" not "Dan" "Shay"
# - "Derek and the Dominos" not "Derek" "The Dominos"
# - "Disco-Tex and the Sex-O-Lettes"
# - "Paul & Paula"
# - "Cornelius Brothers & Sister Rose"
# - "Jimmy Harnen with Synch"
# - "Trina & Tamara"

# %% [markdown]
# # How to approach this bug:
#
# ## Break it down
# 1. Chose one NAME to track a time
# 2. Choose one CORRECTION DATASET to track at a time
# 3. Chose one FIXED dataset to track at a time
#
#
# OPTION: "Soko", who was corrected in gsheet_unknown_corrections_df
#
# ## Leads on the potential cause:
# - Only names from `gsheet_unknown_corrections_df` seem to be causing issues (so check that first)

# %%
# Create copies
fixed_gender_df = gender_df.copy()
fixed_raw_performers_df = raw_performers_df.copy()



# PART 1: apply hand fixes to incorrect splits

# The algorithm to update:
# 1. For each `row` in `gsheet_incorrect_split_corrections_df`:
# 2. For both `fixed_raw_performers_df` and `fixed_gender_df`, for every `performer` column that contains `row.split_part_1` or `row.split_part_2`
# a. Remove both `row.split_part_1` and/or `row.split_part_2`
# b. Append the `row.replace_with_this` (which is the corrected, unsplit version)
# c. If relevant, update with the `row.type` and `row.gender`

def add_delim(str):
    return f"{str}|"

def update_row_if_needed(performers_list_str, row):
    if add_delim(row['split_part_1']) in performers_list_str and add_delim(row['split_part_2']) in performers_list_str:
        updated = add_delim(row['replace_with_this']) + performers_list_str.replace(add_delim(row['split_part_1']), '').replace(add_delim(row['split_part_2']), '')
        print(f"{performers_list_str} => {updated}")
        return updated
    return performers_list_str

for index, row in gsheet_incorrect_split_corrections_df.iterrows():
    # Drop rows from `fixed_raw_performers_df` that contain `row.split_part_1` or `row.split_part_2`
    fixed_gender_df = fixed_gender_df[
        ~fixed_gender_df['performer'].str.contains(add_delim(row['split_part_1']), regex=False) &
        ~fixed_gender_df['performer'].str.contains(add_delim(row['split_part_2']), regex=False)
    ]
    # Append the corrected unsplit version
    fixed_gender_df = pd.concat([
        fixed_gender_df,
        pd.DataFrame({
            'performer': [row['replace_with_this']],
            'type': [row['type']],
            'gender': [row['gender']]
        })
    ], ignore_index=True)

    # Now handle the performers in `fixed_raw_performers_df`
    fixed_raw_performers_df['performers_list_str'] = fixed_raw_performers_df['performers_list_str'].apply(
        lambda performers_list_str: update_row_if_needed(performers_list_str, row)
    )



# PART 2: apply hand fixes to unkNowns
for index, row in gsheet_unknown_corrections_df.iterrows():
    performer = row['performer']
    # Clear, we'll leave it out or add it in later based on the corrections
    fixed_gender_df = fixed_gender_df[fixed_gender_df.performer != performer]
    # DROP MISTAKES
    if row['drop_it'] == 'y':
        # Go through each row in the fixed_raw_performers_df, removing the string f'{performer}|' from performers_list_str, if it exists
        fixed_raw_performers_df['performers_list_str'] = fixed_raw_performers_df['performers_list_str'].str.replace(f'{performer}|', '')
    elif row['type'] != 'unknown':
        if row['performer'] == 'Reg Owen & ':
            print('DEBUG')
        corrected_name = row['correct_name']
        performer_name = corrected_name if not pd.isnull(corrected_name) else performer
        fixed_gender_df = pd.concat([
            fixed_gender_df,
            pd.DataFrame(
                {
                    'performer': [performer_name],
                    'type': [row['type']],
                    'gender': [row['gender']]
                }
            )
        ])
        fixed_raw_performers_df['performers_list_str'] = fixed_raw_performers_df['performers_list_str'].str.replace(f'{performer}|', f'{performer_name}|')
    else:
        # Anything remaining should have been handled in PART 1
        if add_delim(row['performer']) in fixed_raw_performers_df['performers_list_str'].values:
            print('ERROR: unhandled')
        if add_delim(row['performer']) in fixed_gender_df['performer'].values:
            print('ERROR: unhandled')

# There are some gender labels which were incorrect when fed to chatGPT, so we can drop them after corrections
fixed_gender_df = fixed_gender_df[
    fixed_gender_df.type != 'unknown'
]

assert(len(fixed_gender_df) != len(gender_df))
assert(len(fixed_raw_performers_df) == len(raw_performers_df))
# Out:
# ?|The Mysterians| => ? and the Mysterians|
# Travis|Bob| => Travis & Bob|
# James|Bobby Purify| => James & Bobby Purify|
# Dale|Grace| => Dale & Grace|
# Dan|Shay|Justin Bieber| => Dan + Shay|Justin Bieber|
# Derek|The Dominos| => Derek and the Dominos|
# Disco Tex|The Sex-O-Lettes|Sir Monti Rock III| => Disco-Tex and the Sex-O-Lettes|Sir Monti Rock III|
# Paul|Paula| => Paul & Paula|
# Cornelius Brothers|Sister Rose| => Cornelius Brothers & Sister Rose|
# Jimmy Harnen|Synch| => Jimmy Harnen with Synch|
# Somethin' For The People|Trina|Tamara| => Trina & Tamara|Somethin' For The People|
# Apollo|Tom Parker| => Apollo featuring Tom Parker|
# Billy Joe|The Checkmates| => Billy Joe & The Checkmates|
# Rick Dees|His Cast Of Idiots| => Rick Dees & His Cast Of Idiots|
# Santo|Johnny| => Santo & Johnny|
# Herb Alpert|The Tijuana Brass| => Herb Alpert And Tijuana Brass|The
# Herb Alpert|Tijuana Brass| => Herb Alpert And Tijuana Brass|

# %% [markdown]
# ## Handle special case fixes:

# %%
# Handle "Orchestra" special case: it's NOT a meaningful performer
# First, let's find it 
ORCHESTRA_WORD = 'Orchestra'

fixed_raw_performers_df[
    fixed_raw_performers_df['performers_list_str'].str.startswith(f'{ORCHESTRA_WORD}|') |
    fixed_raw_performers_df['performers_list_str'].str.contains(f'|{ORCHESTRA_WORD}|', regex=False)
]

# Manually remove the "Orchestra" performer: replace "|Orchestra|" with "|" in the performers_list_str
fixed_raw_performers_df['performers_list_str'] = fixed_raw_performers_df['performers_list_str'].str.replace(f'|{ORCHESTRA_WORD}|', '|')

# %%
# Handle "The " special case: it's NOT a meaningful performer
OFFENDING_WORD = 'The '

fixed_raw_performers_df[
    fixed_raw_performers_df['performers_list_str'].str.startswith(f'{OFFENDING_WORD}|') |
    fixed_raw_performers_df['performers_list_str'].str.contains(f'|{OFFENDING_WORD}|', regex=False) |
    fixed_raw_performers_df['performers_list_str'].str.endswith(f'|{OFFENDING_WORD}')
]

def remove_thingy(x):
    if x.endswith(f'|{OFFENDING_WORD}'):
        return x.replace(f'|{OFFENDING_WORD}', '|')
    else:
        return x

remove_thingy('Herb Alpert And Tijuana Brass|The ')

# Manually remove
fixed_raw_performers_df['performers_list_str'] = fixed_raw_performers_df['performers_list_str'].apply(remove_thingy)

# %% [markdown]
# # Sanity check our fixes

# %%
assert(len(fixed_raw_performers_df) == len(raw_performers_df))
fixed_performers_list = np.unique(
    np.concatenate(fixed_raw_performers_df['performers_list_str'].str.split("|").apply(lambda x: [i for i in x if i]).values)
)

unique_values, value_counts = np.unique(np.concatenate(fixed_raw_performers_df['performers_list_str'].str.split("|").apply(lambda x: [i for i in x if i]).values), return_counts=True)
sorted_output = sorted(zip(unique_values, value_counts), key=lambda x: x[1], reverse=True)
sorted_output # Note: this is not TOTAL SONG COUNT, this is just "total appearances in unique performer strings" which is a bit different

fixed_performers_list
# Out:
# array(['"Weird Al" Yankovic', "'N Sync", "'Til Tuesday", ...,
#        'the Blackhearts', 'twenty one pilots', 'will.i.am'], dtype='<U43')

# %%
remaining_unknowns = fixed_gender_df[
    fixed_gender_df.type == 'unknown'
]
assert(len(remaining_unknowns) == 0)
fixed_gender_df.type.value_counts()
# Out:
# type
# individual    2007
# group         1132
# Name: count, dtype: int64

# %%
remaining_unknowns = fixed_gender_df[
    fixed_gender_df.gender == 'unknown'
]
for index, row in remaining_unknowns.iterrows():
    print(row['performer'])
assert(len(remaining_unknowns) == 0)
print(len(remaining_unknowns))

fixed_gender_df.gender.value_counts()

# Filter to non-binary artists:
fixed_gender_df[
    fixed_gender_df.gender == 'non-binary'
]
# Out:
# 0
#           performer        type      gender
# 180   Billie Eilish  individual  non-binary
# 485     Demi Lovato  individual  non-binary
# 744          Halsey  individual  non-binary
# 814     Jaden Smith  individual  non-binary
# 828   Janelle Monae  individual  non-binary
# 1579      Sam Smith  individual  non-binary
# 2475    Demi Lovato  individual  non-binary
# 2622  Janelle Monae  individual  non-binary
# 2960      Sam Smith  individual  non-binary

# %%
fixed_gender_df
# Out:
#                           performer        type              gender
# 0               "Weird Al" Yankovic  individual                male
# 1                           'N Sync       group                male
# 2                      'Til Tuesday       group  mixed gender group
# 3                         100 Proof       group  mixed gender group
# 4                              10cc       group                male
# ..                              ...         ...                 ...
# 0                            Divine       group              female
# 0                              Soko  individual              female
# 0                          Ya Kid K  individual              female
# 0   Franck Pourcel's French Fiddles       group  mixed gender group
# 0           The Detroit Guitar Band       group  mixed gender group
#
# [3139 rows x 3 columns]

# %%
# Finally, check that every name in fixed_raw_performers_df has a corresponding entry in fixed_gender_df

# Print any performers that are not in both performers_list
for p in fixed_performers_list:
    try:
        gender = fixed_gender_df[fixed_gender_df.performer == p].iloc[0]
        # print(gender)
    except:
        print(f"Performer '{p}' not found in gender table")
        print(_all_performers_df[_all_performers_df.performers_list_str.str.contains(p)], '\n')
        
        assert(False) # raise the alarm

# %% [markdown]
# # Ok, now let's create a gender column on the split table
#
# Use
# - female: f
# - male: m
# - mixed gender group: x
# - non-binary: n
#
# In other words, for example:
# - Taylor Swift|Sam Smith|
# - f|n|

# %%
PERFORMER_TYPE_ABBREVIATIONS = {
    'individual': 'i',
    'group': 'g'
}
GENDER_ABBREVIATIONS = {
    'female': 'f',
    'male': 'm',
    'non-binary': 'n',
    'mixed gender group': 'x', # OPTIMIZATION: technically this is redundant, so we could drop "g" for this.
}

def create_type_and_gender_string(performers_list_str):
    performers = performers_list_str.split("|")
    type_and_gender_string = ''
    for performer in performers:
        if not performer:
            continue
        row = fixed_gender_df[fixed_gender_df.performer == performer].iloc[0]
        performer_type = row['type']
        gender = row['gender']
        type_and_gender_string += f"{PERFORMER_TYPE_ABBREVIATIONS[performer_type]}{GENDER_ABBREVIATIONS[gender]}|"
    return type_and_gender_string

        
create_type_and_gender_string('Taylor Swift|Sam Smith|The Beatles|The Black Eyed Peas|')

fixed_raw_performers_df['type_and_gender_list_str'] = fixed_raw_performers_df['performers_list_str'].apply(create_type_and_gender_string)

# %%
fixed_raw_performers_df
# Out:
#                                               performer  \
# 0                                                  10cc
# 1                                                  ABBA
# 2                                                   AWB
# 3                                               Aaliyah
# 4                                         Aaron Neville
# ...                                                 ...
# 2558                                           Tom Clay
# 2559                                 Bill Black's Combo
# 2560                                                 CJ
# 2561                        The Kid LAROI & Miley Cyrus
# 2562  Olivia Newton-John And The Electric Light Orch...
#
#                                    performers_list_str  \
# 0                                                10cc|
# 1                                                ABBA|
# 2                                                 AWB|
# 3                                             Aaliyah|
# 4                                       Aaron Neville|
# ...                                                ...
# 2558                                         Tom Clay|
# 2559                               Bill Black's Combo|
# 2560                                               CJ|
# 2561                        The Kid LAROI|Miley Cyrus|
# 2562  Olivia Newton-John|The Electric Light Orchestra|
#
#      type_and_gender_list_str
# 0                         gm|
# 1                         gx|
# 2                         gm|
# 3                         if|
# 4                         im|
# ...                       ...
# 2558                      im|
# 2559                      gm|
# 2560                      im|
# 2561                   im|if|
# 2562                   if|gm|
#
# [2563 rows x 3 columns]

# %% [markdown]
# # Export as a key value lookup table & the corrected name split dataset

# %%
GENDER_LOOKUP_TABLE_PATH = './data/22.5-OUTPUT-1-gender-lookup-table-SEP-2023-UPDATE.csv'
fixed_gender_df.to_csv(GENDER_LOOKUP_TABLE_PATH, index=False)

CORRECTED_PERFORMER_NAME_SPLITS_AND_GENDER_PATH = './data/22.5-OUTPUT-2-corrected-name-splits-with_type_and_gender-SEP-2023-UPDATE.csv'
fixed_raw_performers_df.to_csv(CORRECTED_PERFORMER_NAME_SPLITS_AND_GENDER_PATH, index=False)

# %%
# # double checking :D
pd.read_csv(GENDER_LOOKUP_TABLE_PATH)
pd.read_csv(CORRECTED_PERFORMER_NAME_SPLITS_AND_GENDER_PATH)
# Out:
#                                               performer  \
# 0                                                  10cc
# 1                                                  ABBA
# 2                                                   AWB
# 3                                               Aaliyah
# 4                                         Aaron Neville
# ...                                                 ...
# 2558                                           Tom Clay
# 2559                                 Bill Black's Combo
# 2560                                                 CJ
# 2561                        The Kid LAROI & Miley Cyrus
# 2562  Olivia Newton-John And The Electric Light Orch...
#
#                                    performers_list_str  \
# 0                                                10cc|
# 1                                                ABBA|
# 2                                                 AWB|
# 3                                             Aaliyah|
# 4                                       Aaron Neville|
# ...                                                ...
# 2558                                         Tom Clay|
# 2559                               Bill Black's Combo|
# 2560                                               CJ|
# 2561                        The Kid LAROI|Miley Cyrus|
# 2562  Olivia Newton-John|The Electric Light Orchestra|
#
#      type_and_gender_list_str
# 0                         gm|
# 1                         gx|
# 2                         gm|
# 3                         if|
# 4                         im|
# ...                       ...
# 2558                      im|
# 2559                      gm|
# 2560                      im|
# 2561                   im|if|
# 2562                   if|gm|
#
# [2563 rows x 3 columns]

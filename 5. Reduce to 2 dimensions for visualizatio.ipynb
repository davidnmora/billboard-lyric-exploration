# %% [markdown]
# # Exploration spark: "What's the most cliche song ever written? How do we even measure cliche-ness?"

# %%
import pandas as pd
import numpy as np

# %%
np.__version__
# Out:
# '1.19.5'

# %% [markdown]
# # Pull in data (prepped in other notebook)

# %%
df = pd.read_csv('./data/Songs with metadata and lyrics.csv')

# %%
df.head()
# Out:
#                                               SongID  \
# 0                ...Baby One More TimeBritney Spears
# 1                       ...Ready For It?Taylor Swift
# 2  '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles
# 3                          '65 Love AffairPaul Davis
# 4                                     'TilThe Angels
#
#                          Performer                   Song  \
# 0                   Britney Spears  ...Baby One More Time
# 1                     Taylor Swift       ...Ready For It?
# 2  Jay-Z Featuring Beyonce Knowles     '03 Bonnie & Clyde
# 3                       Paul Davis        '65 Love Affair
# 4                       The Angels                   'Til
#
#                                        spotify_genre  \
# 0              ['dance pop', 'pop', 'post-teen pop']
# 1                           ['pop', 'post-teen pop']
# 2  ['east coast hip hop', 'hip hop', 'pop rap', '...
# 3  ['album rock', 'bubblegum pop', 'country rock'...
# 4  ['blues rock', 'garage rock', 'modern blues ro...
#
#                            spotify_track_preview_url spotify_track_explicit  \
# 0  https://p.scdn.co/mp3-preview/da2134a161f1cb34...                  False
# 1                                                NaN                  False
# 2                                                NaN                   True
# 3  https://p.scdn.co/mp3-preview/a701445830ecacfb...                  False
# 4  https://p.scdn.co/mp3-preview/bf264f14124ddf08...                  False
#
#                                  spotify_track_album      WeekID  \
# 0     ...Baby One More Time (Digital Deluxe Version)   5/29/1999
# 1  {'album_type': 'album', 'artists': [{'external...   12/2/2017
# 2               The Blueprint 2 The Gift & The Curse  12/28/2002
# 3                             Radio Hits Of the '80s   6/12/1982
# 4  Caprice! The Story Behind Gerry Granahan's Cap...   1/20/1962
#
#    Week Position  Peak Position  \
# 0           31.0            1.0
# 1           18.0            4.0
# 2            4.0            4.0
# 3           18.0            6.0
# 4           38.0           14.0
#
#                                               Lyrics
# 0  [Intro]\nOh baby, baby\nOh baby, baby\n\n[Vers...
# 1  [Verse 1]\nKnew he was a killer first time tha...
# 2  [Intro: Jay Z]\nUhh, uhh, uhh\nYou ready, B?\n...
# 3  '65 love affair\nPaul Davis\n\nI was a car hop...
# 4  [Intro]\nYeah, yeah, yeah\nRap diablo\nYeah, y...

# %%
df[df.Song == 'Our Song'].Lyrics.iloc[0]
# Out:
# '[Verse 1]\nI was riding shotgun with my hair undone\nIn the front seat of his car\nHe\'s got a one-hand feel on the steering wheel\nThe other on my heart\nI look around, turn the radio down\nHe says, "Baby, is something wrong?"\nI say, "Nothing, I was just thinking\nHow we don\'t have a song"\nAnd he says\n\n[Chorus]\nOur song is the slamming screen door\nSneakin\' out late, tapping on your window\nWhen we\'re on the phone and you talk real slow\n\'Cause it\'s late and your mama don\'t know\nOur song is the way you laugh\nThe first date: "Man, I didn\'t kiss her, and I should have"\nAnd when I got home \'fore I said amen\nAsking God if he could play it again\n\n[Verse 2]\nI was walking up the front porch steps\nAfter everything that day\nHad gone all wrong and been trampled on\nAnd lost and thrown away\nGot to the hallway, well on my way\nTo my lovin\' bed\nI almost didn\'t notice all the roses\nAnd the note that said\n\n[Chorus]\nOur song is the slamming screen door\nSneakin\' out late, tapping on your window\nWhen we\'re on the phone and you talk real slow\n\'Cause it\'s late and your mama don\'t know\nOur song is the way you laugh\nThe first date: "Man, I didn\'t kiss her, and I should have"\nAnd when I got home \'fore I said amen\nAsking God if he could play it again\n\n[Bridge]\nI\'ve heard every album, listened to the radio\nWaited for something to come along\nThat was as good as our song\n\n[Chorus]\n\'Cause our song is the slamming screen door\nSneakin\' out late, tapping on his window\nWhen we\'re on the phone and he talks real slow\n\'Cause it\'s late and his mama don\'t know\nOur song is the way he laughs\nThe first date: "Man, I didn\'t kiss him, and I should have"\nAnd when I got home \'fore I said amen\nAsking God if he could play it again\nPlay it again\n\n[Outro]\nI was riding shotgun with my hair undone\nIn the front seat of his car\nI grabbed a pen and an old napkin\nAnd I wrote down our song'

# %% [markdown]
# # Simple definition: "cliche" is when write lines very similar to lines published in previous years.
#
# ## CLICHE->SONGS: choose a cliche (eg "I love you", "I've never felt this way before", "you're my everything"), then try to identify which songs contain it.
#
# ## SONGS->analyze->CLICHES: identify cliches from the songs

# %% [markdown]
# ## Simplest: *word-for-word* identical

# %%
# using title as proxy for a single line here (lyrics too big to view)
df[df.Song.str.contains('i love you', case=False)]
# Out:
#                                                  SongID  \
# 460                      Baby I Love YouAretha Franklin
# 461   Baby I Love Your Way (From "Reality Bites")Big...
# 479                            Baby, I Love YouAndy Kim
# 480   Baby, I Love Your Way/Freebird MedleyWill To P...
# 481                 Baby, I Love Your WayPeter Frampton
# 595       Because I Love You (The Postman Song)Stevie B
# 846            But You Know I Love YouThe First Edition
# 2256        Hate That I Love YouRihanna Featuring Ne-Yo
# 2279  He Don't Love You (Like I Love You)Tony Orland...
# 2360                         Hello, I Love YouThe Doors
# 2726       I Just Called To Say I Love YouStevie Wonder
# 2771               I Love You Always ForeverDonna Lewis
# 2772                       I Love You BecauseAl Martino
# 2773       I Love You More And More Every DayAl Martino
# 2774                 I Love You This BigScotty McCreery
# 2775                        I Love YouClimax Blues Band
# 2776                              I Love YouFaith Evans
# 2777                                   I Love YouPeople
# 2778                           I Love Your SmileShanice
# 2797  I Never Loved A Man (The Way I Love You)Aretha...
# 2938     I'll Have To Say I Love You In A SongJim Croce
# 3385                   Just Remember I Love YouFirefall
# 3476            La - La - Means I Love YouThe Delfonics
# 3658                   Like I Love YouJustin Timberlake
# 3728  Lo Mucho Que Te Quiero (The More I Love You)Re...
# 4641                         P.S. I Love YouThe Beatles
# 5192  Say Hey (I Love You)Michael Franti & Spearhead...
# 6028            That's Why (I Love You So)Jackie Wilson
# 7076          Why I Love You So Much/Ain't NobodyMonica
# 7296     You Know I Love You ... Don't You?Howard Jones
#
#                                               Performer  \
# 460                                     Aretha Franklin
# 461                                        Big Mountain
# 479                                            Andy Kim
# 480                                       Will To Power
# 481                                      Peter Frampton
# 595                                            Stevie B
# 846                                   The First Edition
# 2256                            Rihanna Featuring Ne-Yo
# 2279                                Tony Orlando & Dawn
# 2360                                          The Doors
# 2726                                      Stevie Wonder
# 2771                                        Donna Lewis
# 2772                                         Al Martino
# 2773                                         Al Martino
# 2774                                    Scotty McCreery
# 2775                                  Climax Blues Band
# 2776                                        Faith Evans
# 2777                                             People
# 2778                                            Shanice
# 2797                                    Aretha Franklin
# 2938                                          Jim Croce
# 3385                                           Firefall
# 3476                                      The Delfonics
# 3658                                  Justin Timberlake
# 3728                                        Rene & Rene
# 4641                                        The Beatles
# 5192  Michael Franti & Spearhead Featuring Cherine A...
# 6028                                      Jackie Wilson
# 7076                                             Monica
# 7296                                       Howard Jones
#
#                                               Song  \
# 460                                Baby I Love You
# 461    Baby I Love Your Way (From "Reality Bites")
# 479                               Baby, I Love You
# 480          Baby, I Love Your Way/Freebird Medley
# 481                          Baby, I Love Your Way
# 595          Because I Love You (The Postman Song)
# 846                        But You Know I Love You
# 2256                          Hate That I Love You
# 2279           He Don't Love You (Like I Love You)
# 2360                             Hello, I Love You
# 2726               I Just Called To Say I Love You
# 2771                     I Love You Always Forever
# 2772                            I Love You Because
# 2773            I Love You More And More Every Day
# 2774                           I Love You This Big
# 2775                                    I Love You
# 2776                                    I Love You
# 2777                                    I Love You
# 2778                             I Love Your Smile
# 2797      I Never Loved A Man (The Way I Love You)
# 2938         I'll Have To Say I Love You In A Song
# 3385                      Just Remember I Love You
# 3476                    La - La - Means I Love You
# 3658                               Like I Love You
# 3728  Lo Mucho Que Te Quiero (The More I Love You)
# 4641                               P.S. I Love You
# 5192                          Say Hey (I Love You)
# 6028                    That's Why (I Love You So)
# 7076           Why I Love You So Much/Ain't Nobody
# 7296            You Know I Love You ... Don't You?
#
#                                           spotify_genre  \
# 460   ['classic soul', 'jazz blues', 'memphis soul',...
# 461                                          ['reggae']
# 479             ['brill building pop', 'bubblegum pop']
# 480                                       ['freestyle']
# 481   ['album rock', 'art rock', 'blues rock', 'brit...
# 595                                       ['freestyle']
# 846                                                  []
# 2256  ['barbadian pop', 'dance pop', 'pop', 'post-te...
# 2279  ['bubblegum pop', 'classic uk pop', 'country r...
# 2360  ['album rock', 'classic rock', 'piano rock', '...
# 2726  ['adult standards', 'motown', 'quiet storm', '...
# 2771                                   ['new wave pop']
# 2772  ['adult standards', 'brill building pop', 'eas...
# 2773  ['adult standards', 'brill building pop', 'eas...
# 2774  ['contemporary country', 'country', 'country r...
# 2775  ['blues rock', 'british blues', 'classic rock'...
# 2776  ['dance pop', 'hip hop', 'hip pop', 'neo soul'...
# 2777  ['indie pop', 'indietronica', 'modern rock', '...
# 2778  ['hip pop', 'new jack swing', 'quiet storm', '...
# 2797  ['classic soul', 'jazz blues', 'memphis soul',...
# 2938  ['album rock', 'classic rock', 'folk', 'folk r...
# 3385  ['album rock', 'bubblegum pop', 'classic rock'...
# 3476  ['classic soul', 'disco', 'funk', 'motown', 'p...
# 3658                    ['dance pop', 'pop', 'pop rap']
# 3728  ['banda', 'grupera', 'norteno', 'regional mexi...
# 4641  ['british invasion', 'merseybeat', 'psychedeli...
# 5192                                  ['reggae fusion']
# 6028  ['adult standards', 'brill building pop', 'chi...
# 7076  ['dance pop', 'deep pop r&b', 'hip hop', 'hip ...
# 7296  ['dance rock', 'mellow gold', 'new romantic', ...
#
#                               spotify_track_preview_url  \
# 460   https://p.scdn.co/mp3-preview/39a582336820d9ae...
# 461                                                 NaN
# 479                                                 NaN
# 480                                                 NaN
# 481                                                 NaN
# 595   https://p.scdn.co/mp3-preview/5894932928df6362...
# 846   https://p.scdn.co/mp3-preview/4aabe0d5899dbf62...
# 2256                                                NaN
# 2279  https://p.scdn.co/mp3-preview/719f19b28e71a491...
# 2360  https://p.scdn.co/mp3-preview/3d31a54a62e7489a...
# 2726                                                NaN
# 2771  https://p.scdn.co/mp3-preview/17a0534bdeee4390...
# 2772                                                NaN
# 2773                                                NaN
# 2774                                                NaN
# 2775  https://p.scdn.co/mp3-preview/40878cd082285801...
# 2776  https://p.scdn.co/mp3-preview/fc42ce71c03c0448...
# 2777                                                NaN
# 2778                                                NaN
# 2797  https://p.scdn.co/mp3-preview/a779699342b72029...
# 2938  https://p.scdn.co/mp3-preview/b0f3f75683056308...
# 3385  https://p.scdn.co/mp3-preview/5509965ef1028890...
# 3476  https://p.scdn.co/mp3-preview/f1eecbd0fda7e827...
# 3658  https://p.scdn.co/mp3-preview/a2814d4b18ddb6ec...
# 3728                                                NaN
# 4641  https://p.scdn.co/mp3-preview/8634f8f80fac9b5b...
# 5192                                                NaN
# 6028  https://p.scdn.co/mp3-preview/ce25af29a7dc0acc...
# 7076                                                NaN
# 7296  https://p.scdn.co/mp3-preview/92d586e64a477afa...
#
#      spotify_track_explicit  \
# 460                   False
# 461                     NaN
# 479                   False
# 480                     NaN
# 481                   False
# 595                   False
# 846                   False
# 2256                  False
# 2279                  False
# 2360                  False
# 2726                  False
# 2771                  False
# 2772                  False
# 2773                  False
# 2774                  False
# 2775                  False
# 2776                  False
# 2777                  False
# 2778                  False
# 2797                  False
# 2938                  False
# 3385                  False
# 3476                  False
# 3658                  False
# 3728                    NaN
# 4641                  False
# 5192                  False
# 6028                  False
# 7076                    NaN
# 7296                  False
#
#                                     spotify_track_album      WeekID  \
# 460                                      Aretha Arrives   9/16/1967
# 461                                                 NaN   8/27/1994
# 479                                     Baby I Love You    9/6/1969
# 480                                                 NaN   2/18/1989
# 481              Frampton Comes Alive! (Deluxe Edition)   9/18/1976
# 595                Valentine's Day Love… A Special Kind   2/16/1991
# 846                            Country & Western Legend    3/8/1969
# 2256                       Good Girl Gone Bad: Reloaded   1/12/2008
# 2279                                  He Don't Love You   6/14/1975
# 2360                                Waiting for the Sun    8/3/1968
# 2726                          At The Close Of A Century  12/29/1984
# 2771                                    Now In A Minute  12/28/1996
# 2772                                 I Love You Because   6/15/1963
# 2773                          Capitol Collectors Series   3/21/1964
# 2774                                       Clear As Day    7/2/2011
# 2775                                    Flying the Flag    7/4/1981
# 2776                                         Faithfully   5/11/2002
# 2777  Lost Hits Of The 60's (All Original Artists & ...   7/27/1968
# 2778                       Ultimate Collection: Shanice   2/15/1992
# 2797             I Never Loved a Man the Way I Love You   4/22/1967
# 2938                                       I Got A Name   5/25/1974
# 3385                            'firefall Reunion Live'   12/3/1977
# 3476                             La La Means I Love You   4/13/1968
# 3658                                          Justified  10/12/2002
# 3728                                                NaN   1/18/1969
# 4641  Beatles Tribute: A Dedicatio To Please Please ...   6/27/1964
# 5192                                  All Rebel Rockers  11/14/2009
# 6028                                   Lonely Teardrops    5/2/1959
# 7076                                                NaN   7/13/1996
# 7296                                         One To One   1/31/1987
#
#       Week Position  Peak Position  \
# 460             5.0            4.0
# 461            34.0            6.0
# 479            25.0            9.0
# 480            91.0            1.0
# 481            30.0           12.0
# 595            49.0            1.0
# 846            19.0           19.0
# 2256           15.0            7.0
# 2279           54.0            1.0
# 2360            1.0            1.0
# 2726           63.0            1.0
# 2771           18.0            2.0
# 2772            5.0            3.0
# 2773            9.0            9.0
# 2774           72.0           11.0
# 2775           31.0           12.0
# 2776           25.0           14.0
# 2777           22.0           14.0
# 2778            2.0            2.0
# 2797            9.0            9.0
# 2938           34.0            9.0
# 3385           37.0           11.0
# 3476            8.0            4.0
# 3658           11.0           11.0
# 3728           14.0           14.0
# 4641           37.0           10.0
# 5192           38.0           18.0
# 6028           13.0           13.0
# 7076           10.0            9.0
# 7296           93.0           17.0
#
#                                                  Lyrics
# 460   If you want my lovin'\nIf you really do\nDon't...
# 461   PROLOGUE\n\nTwo tires fly. Two wail.\n\nA bamb...
# 479   Have I ever told you\nHow good it feels to hol...
# 480   Shadows grow so long before my eyes\nAnd they'...
# 481   [Verse 1]\nShadows grow so long before my eyes...
# 595   I got your letter from the postman just the ot...
# 846   When the morning sun\nStreaks across my room\n...
# 2256  [Intro: Rihanna & Ne-Yo]\nYeah, yeah\nYeah, ye...
# 2279  He don't love you, like I love you\nIf he did,...
# 2360  [Chorus]\nHello, I love you\nWon't you tell me...
# 2726  [Verse 1]\nNo New Year's Day to celebrate\nNo ...
# 2771  [Verse 1]\nFeels like I'm standing in a timele...
# 2772  I love you because you understand, dear\nEvery...
# 2773  I love you more and more every day\n\nThey sai...
# 2774  [Verse 1]\nI know I'm still young\nBut, I know...
# 2775  When I was younger, man\nI hadn't a care\nFool...
# 2776  [Verse 1]\nMy heart belongs to you\nSo what co...
# 2777  [Intro]\nBeen a long time coming\nA lot of pai...
# 2778  [Verse 1]\nSitting in my class\nJust drifting ...
# 2797  [Verse 1]\nYou're a no good heart breaker\nYou...
# 2938  Well, I know it's kind of late\nI hope I didn'...
# 3385  When it all goes crazy and the thrill is gone\...
# 3476  [Verse 1]\nMany guys have come to you\nWith a ...
# 3658  [Produced by The Neptunes]\n\n[Intro: Justin T...
# 3728  Believe me when I say how much I love you\nBel...
# 4641  [Intro]\nAs I write this letter\nSend my love ...
# 5192  [Intro]\nThis one goes out to you and yours, w...
# 6028  The way you make me feel like I belong\nThe wa...
# 7076  Thereâs not enough drugs in the world to wip...
# 7296  YOU KNOW I LOVE YOU...DON'T YOU?\nHoward Jones...

# %% [markdown]
# ## But how do you find similar lines that aren't *word-for-word* matches?
#
# ie I want something like
# > "Look at this cluster: "I love you", "you are my love", and "you are the love of my life" are close together. But "you are my spring dew" is far away."
#
# ### One approach: create a row for every *line*, then use word2vec & dimensio reduction to plot a 2D "phrase cloud"
# - maybe limmit to first 10 lines of a song to quickly remove duplicates)
# - maybe just start with most recent year

# %% [markdown]
# # DATA PREP: "explode" data into "one row per line"

# %% [markdown]
# # NOTE: I'm limiting data to1976-1980

# %%
tiny_df = df[
    df.WeekID.str.endswith('1980') |
    df.WeekID.str.endswith('1979') |
    df.WeekID.str.endswith('1978') |
    df.WeekID.str.endswith('1977') |
    df.WeekID.str.endswith('1976')
]
tiny_df
# Out:
#                                                  SongID  \
# 9               (Don't Fear) The ReaperBlue Oyster Cult
# 10     (Every Time I Turn Around) Back In Love AgainLTD
# 38                (Love Is) Thicker Than WaterAndy Gibb
# 41          (Our Love) Don't Throw It All AwayAndy Gibb
# 43    (Shake, Shake, Shake) Shake Your BootyKC And T...
# ...                                                 ...
# 7368            You're The Only Woman (You & I)Ambrosia
# 7383                             Young BloodBad Company
# 7387                  Young Hearts Run FreeCandi Staton
# 7400          Your LoveMarilyn McCoo & Billy Davis, Jr.
# 7406                      Your Smiling FaceJames Taylor
#
#                              Performer  \
# 9                     Blue Oyster Cult
# 10                                 LTD
# 38                           Andy Gibb
# 41                           Andy Gibb
# 43            KC And The Sunshine Band
# ...                                ...
# 7368                          Ambrosia
# 7383                       Bad Company
# 7387                      Candi Staton
# 7400  Marilyn McCoo & Billy Davis, Jr.
# 7406                      James Taylor
#
#                                                Song  \
# 9                           (Don't Fear) The Reaper
# 10    (Every Time I Turn Around) Back In Love Again
# 38                     (Love Is) Thicker Than Water
# 41               (Our Love) Don't Throw It All Away
# 43           (Shake, Shake, Shake) Shake Your Booty
# ...                                             ...
# 7368                You're The Only Woman (You & I)
# 7383                                    Young Blood
# 7387                          Young Hearts Run Free
# 7400                                      Your Love
# 7406                              Your Smiling Face
#
#                                           spotify_genre  \
# 9     ['album rock', 'art rock', 'blues rock', 'clas...
# 10                                        ['reggaeton']
# 38    ['adult standards', 'bubblegum pop', 'country ...
# 41    ['adult standards', 'bubblegum pop', 'country ...
# 43             ['disco', 'funk', 'motown', 'soft rock']
# ...                                                 ...
# 7368  ['adult standards', 'album rock', 'art rock', ...
# 7383  ['album rock', 'blues rock', 'classic rock', '...
# 7387  ['classic soul', 'disco', 'motown', 'quiet sto...
# 7400                                                 []
# 7406  ['adult standards', 'folk', 'folk rock', 'mell...
#
#                               spotify_track_preview_url  \
# 9     https://p.scdn.co/mp3-preview/596db216a6621b8c...
# 10                                                  NaN
# 38                                                  NaN
# 41                                                  NaN
# 43    https://p.scdn.co/mp3-preview/fe0fa4239fab4ad7...
# ...                                                 ...
# 7368  https://p.scdn.co/mp3-preview/c8ffa80fb4fe60de...
# 7383  https://p.scdn.co/mp3-preview/32e39a60def288ae...
# 7387  https://p.scdn.co/mp3-preview/b0b96bb7e0e4f151...
# 7400  https://p.scdn.co/mp3-preview/4fb26d7f63aee83b...
# 7406  https://p.scdn.co/mp3-preview/73345f373382a094...
#
#      spotify_track_explicit                          spotify_track_album  \
# 9                     False                            Agents Of Fortune
# 10                      NaN                                          NaN
# 38                    False                               Flowing Rivers
# 41                    False                               Shadow Dancing
# 43                    False   KC & The Sunshine Band - Part 3...And More
# ...                     ...                                          ...
# 7368                  False                                   One Eighty
# 7383                  False                   Run With The Pack (Deluxe)
# 7387                  False  Young Hearts Run Free (US Internet Release)
# 7400                  False                I Hope We Get To Love In Time
# 7406                  False                                           JT
#
#           WeekID  Week Position  Peak Position  \
# 9     11/20/1976           17.0           12.0
# 10     2/11/1978           62.0            4.0
# 38     5/13/1978           47.0            1.0
# 41      2/3/1979           53.0            9.0
# 43    11/20/1976           44.0            1.0
# ...          ...            ...            ...
# 7368   9/20/1980           13.0           13.0
# 7383   6/12/1976           64.0           20.0
# 7387   8/21/1976           20.0           20.0
# 7400   5/28/1977           65.0           15.0
# 7406  12/24/1977           38.0           20.0
#
#                                                  Lyrics
# 9     [Intro]\n\n[Verse 1: Buck Dharma]\nAll our tim...
# 10    Every time I move, I lose\nWhen I look I'm in\...
# 38    [Chorus:]\nLove is higher than a mountain\nLov...
# 41    Maybe I don't wanna know the reason why\nBut l...
# 43    [Intro]\nAh everybody, get on the floor, and l...
# ...                                                 ...
# 7368  Oh baby\nSay, now, you\nYou talk about The thi...
# 7383  I saw her standing on the corner\nA yellow rib...
# 7387  What's the sense in sharing this one and only ...
# 7400  YOUR LOVE\nMarilyn McCoo & Billy Davis\nEach d...
# 7406  [Verse 1]\nWhenever I see your smiling face\nI...
#
# [654 rows x 11 columns]

# %%
# tiny_df['Parsed Lyrics'] = tiny_df.Lyrics.apply(lambda l: l.split('\n')[:5])
tiny_df['Parsed Lyrics'] = tiny_df.Lyrics.apply(lambda l: l.split('\n'))
# Out:
# /Users/dmora/.virtualenvs/jupyter3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
tiny_df_parsed = tiny_df.explode('Parsed Lyrics').drop_duplicates(
    subset=['Parsed Lyrics', 'SongID']
).drop(
    columns=['Lyrics']
).rename(columns={'Parsed Lyrics': 'lyric_line'})

# %% [markdown]
# ### Filter & clean

# %%
ENDS_WITH_YEAR_IN_PAREN = '\(\d{4}?\)$'  # eg "... (2018)"
BRACKETED = '^\[.*?\]$'  # eg "[...]"
SONG_DASH_ARTIST = '[A-Z].+\s\-\s[A-Z].+'  # EG "Ariana Grande and Victoria MonÃ©t - MONOPOLY"

with_filters = tiny_df_parsed[
    ~tiny_df_parsed['lyric_line'].str.contains(
        f'{BRACKETED}|{ENDS_WITH_YEAR_IN_PAREN}|{SONG_DASH_ARTIST}', 
        regex= True, case=False, na=False
    )
]

# %%
with_more_filters = with_filters[~with_filters.lyric_line.str.contains('" by ')]
with_more_filters['lyric_line'] = with_more_filters.lyric_line.str.replace('EmbedShare URLCopyEmbedCopy', '')
# Out:
# /Users/dmora/.virtualenvs/jupyter3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # NOTE: I'm dropping any row with *any* MISSING DATA
# Maybe we try something less aggressive later (eg blank genre is ok)

# %%
COLUMNS_FOR_VIZ = ['Performer', 'Song', 'spotify_genre', 'lyric_line', 'WeekID']

lyric_lines_ready_for_analysis = (
    with_more_filters[
        COLUMNS_FOR_VIZ
    ]
    .replace('', np.nan)
    .dropna()
    .reset_index(drop=True)
)

lyric_lines_ready_for_analysis['lyric_line'] = lyric_lines_ready_for_analysis['lyric_line'].apply(
    lambda val: val and val.replace('â\x80\x99', "'")
)
lyric_lines_ready_for_analysis
# Out:
#               Performer                     Song  \
# 0      Blue Oyster Cult  (Don't Fear) The Reaper
# 1      Blue Oyster Cult  (Don't Fear) The Reaper
# 2      Blue Oyster Cult  (Don't Fear) The Reaper
# 3      Blue Oyster Cult  (Don't Fear) The Reaper
# 4      Blue Oyster Cult  (Don't Fear) The Reaper
# ...                 ...                      ...
# 42665      James Taylor        Your Smiling Face
# 42666      James Taylor        Your Smiling Face
# 42667      James Taylor        Your Smiling Face
# 42668      James Taylor        Your Smiling Face
# 42669      James Taylor        Your Smiling Face
#
#                                            spotify_genre  \
# 0      ['album rock', 'art rock', 'blues rock', 'clas...
# 1      ['album rock', 'art rock', 'blues rock', 'clas...
# 2      ['album rock', 'art rock', 'blues rock', 'clas...
# 3      ['album rock', 'art rock', 'blues rock', 'clas...
# 4      ['album rock', 'art rock', 'blues rock', 'clas...
# ...                                                  ...
# 42665  ['adult standards', 'folk', 'folk rock', 'mell...
# 42666  ['adult standards', 'folk', 'folk rock', 'mell...
# 42667  ['adult standards', 'folk', 'folk rock', 'mell...
# 42668  ['adult standards', 'folk', 'folk rock', 'mell...
# 42669  ['adult standards', 'folk', 'folk rock', 'mell...
#
#                                               lyric_line      WeekID
# 0                                All our times have come  11/20/1976
# 1                             Here, but now they're gone  11/20/1976
# 2                          Seasons don't fear the reaper  11/20/1976
# 3                   Nor do the wind, the sun or the rain  11/20/1976
# 4                (We can be like they are) Come on, baby  11/20/1976
# ...                                                  ...         ...
# 42665                     Whenever I see you smile at me  12/24/1977
# 42666  No one can tell me that, tell me that I'm doin...  12/24/1977
# 42667            Whenever I see your smiling face my way  12/24/1977
# 42668  No one can tell me that I'm doing wrong today,...  12/24/1977
# 42669                   No no, darling, no no, yeah yeah  12/24/1977
#
# [42670 rows x 5 columns]

# %% [markdown]
# # EMBED WORDS USING Universal Encoder

# %%
#@title Load the Universal Sentence Encoder's TF Hub module
from absl import logging

import tensorflow as tf

import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns

# %%
model = hub.load('./data/universal-sentence-encoder-large_5/')
# Out:
# 2021-11-30 14:55:40.392424: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def embed(input):
    return model(input)

# %%
message_embeddings = embed(lyric_lines_ready_for_analysis['lyric_line'])

# %% [markdown]
# # Dimension reduction

# %% [markdown]
# ## Dimension reduction with TSNE

# %%
from sklearn.manifold import TSNE

# %%
# tsne_transformed_embeddings = TSNE(
#     n_components=2,
#     learning_rate='auto',
#     init='pca'
# ).fit_transform(message_embeddings)

# %%
def concat_x_and_y(x_and_y, df):
    return pd.concat(
    [df, pd.DataFrame(x_and_y, columns=['x', 'y'])],
    axis=1
)

# %%
# tsne_lyrics_and_artist = concat_x_and_y(
#     tsne_transformed_embeddings, 
#     lyric_lines_ready_for_analysis
# )

# %%
# sns.scatterplot(data=tsne_lyrics_and_artist, x='x', y='y')

# %% [markdown]
# # Dimension reduction with UMAP

# %%
import umap
from sklearn.preprocessing import StandardScaler

# %%
reducer = umap.UMAP()

# %%
embedding = reducer.fit_transform(
    StandardScaler().fit_transform(message_embeddings)
)

# %%
umap_x_and_y_added = concat_x_and_y(
    embedding, 
    df=lyric_lines_ready_for_analysis
)
umap_x_and_y_added

# %%
sns.scatterplot(data=umap_x_and_y_added, x='x', y='y')

# %% [markdown]
# ## Export to CSV

# %%
def normalize_zero_to_one(s):
    return (s - s.min()) / (s.max() - s.min())

def export_normalized_data(data):
    temp = data.copy().dropna()
    temp['x'] = normalize_zero_to_one(temp.x)
    temp['y'] = normalize_zero_to_one(temp.y)
    temp['x'] = temp['x'].round(3)
    temp['y'] = temp['y'].round(3)
    export = temp
    export.to_csv('./data/viz ready export 1976 - 1980.csv', index=False)
    return export

# %%
the_export = export_normalized_data(umap_x_and_y_added)
the_export

# %% [markdown]
# # List of all: genres, artists

# %%
my_set = set()
the_export['Performer'].unique()

# %%
from ast import literal_eval

my_set = set()
the_export['spotify_genre'].apply(
    lambda val: val and my_set.update(literal_eval(val))
)
my_set

# %%
rap_genres = [genre for genre in list(my_set) if 'rap' in genre]

# %%
pop_genres = [genre for genre in list(my_set) if 'pop' in genre]
pop_genres

# %%
import pandas as pd
import numpy as np
from IPython.display import Markdown as md
np.__version__
# Out:
# '1.19.5'

# %% [markdown]
# # Load in the Hot 100 data
# Basically, Sean Miller (who made this data.world dataset I used for the prototype) keeps [a super up-do-date list of Hot 100 on GitHub](https://github.com/HipsterVizNinja/random-data/tree/main/Music/hot-100) through much of 2022, last I checked.

# %%
USEFUL_COLUMNS = ['chart_position', 'chart_debut', 'song', 'performer', 'song_id']
hot_100_raw = pd.read_csv('./data/Hot 100 through Oct 2022.csv')[USEFUL_COLUMNS]

# %%
hot_100_raw.head()
# Out:
#    chart_position chart_debut       song           performer  \
# 0              84  1990-05-05  "B" Girls  Young And Restless
# 1              78  1990-05-05  "B" Girls  Young And Restless
# 2              68  1990-05-05  "B" Girls  Young And Restless
# 3              60  1990-05-05  "B" Girls  Young And Restless
# 4              58  1990-05-05  "B" Girls  Young And Restless
#
#                        song_id
# 0  "B" GirlsYoung And Restless
# 1  "B" GirlsYoung And Restless
# 2  "B" GirlsYoung And Restless
# 3  "B" GirlsYoung And Restless
# 4  "B" GirlsYoung And Restless

# %%
md(f"## Unique songs available in full dataset: {len(hot_100_raw.drop_duplicates(subset=['song_id']))}")
# Out:
# ## Unique songs available in full dataset: 30314

# %%
SONG_RANKING_FILTER_THRESHOLD = 10

# %%
md(f"# Filter to unique songs that breached the top {SONG_RANKING_FILTER_THRESHOLD}")
# Out:
# # Filter to unique songs that breached the top 10

# %%
temp = hot_100_raw.sort_values('chart_position').groupby(['song_id']).first()
only_songs_that_made_it_above_x = temp[
    temp['chart_position'] <= SONG_RANKING_FILTER_THRESHOLD
].reset_index()

only_songs_that_made_it_above_x
# Out:
#                                                 song_id  chart_position  \
# 0                                   #9 DreamJohn Lennon               9
# 1     '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles               4
# 2                             '65 Love AffairPaul Davis               6
# 3                ('til) I Kissed YouThe Everly Brothers               4
# 4     (Can't Live Without Your) Love And AffectionNe...               1
# ...                                                 ...             ...
# 5061                   everything i wantedBillie Eilish               8
# 5062                      iSpyKYLE Featuring Lil Yachty               4
# 5063                                   interludeJ. Cole               8
# 5064                 my.lifeJ. Cole, 21 Savage & Morray               2
# 5065               pride.is.the.devilJ. Cole & Lil Baby               7
#
#      chart_debut                                          song  \
# 0     1974-12-21                                      #9 Dream
# 1     2002-10-26                            '03 Bonnie & Clyde
# 2     1982-02-27                               '65 Love Affair
# 3     1959-08-15                           ('til) I Kissed You
# 4     1990-07-07  (Can't Live Without Your) Love And Affection
# ...          ...                                           ...
# 5061  2019-11-23                           everything i wanted
# 5062  2017-01-14                                          iSpy
# 5063  2021-05-22                                     interlude
# 5064  2021-05-29                                       my.life
# 5065  2021-05-29                            pride.is.the.devil
#
#                             performer
# 0                         John Lennon
# 1     Jay-Z Featuring Beyonce Knowles
# 2                          Paul Davis
# 3                 The Everly Brothers
# 4                              Nelson
# ...                               ...
# 5061                    Billie Eilish
# 5062        KYLE Featuring Lil Yachty
# 5063                          J. Cole
# 5064      J. Cole, 21 Savage & Morray
# 5065               J. Cole & Lil Baby
#
# [5066 rows x 5 columns]

# %% [markdown]
# # Pull Spotify
# Pull my own metadata from [Spotify](https://developer.spotify.com/documentation/web-api/), using [Spotipy](https://spotipy.readthedocs.io/en/2.19.0/).
#
# ### NOTE: unfortunately Spotify doesn't (no longer?) give you genre for a given song. The best you can get is genre for the *artist*. Darn...

# %%
import spotipy
import sys
from spotipy.oauth2 import SpotifyClientCredentials

spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials())

# %% [markdown]
# ## TEST / DEMOS

# %% [markdown]
# ### Search for Radiohead

# %%
name = 'Radiohead'

results = spotify.search(q='artist:' + name, type='artist')
items = results['artists']['items']
items[0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#  'followers': {'href': None, 'total': 7479537},
#  'genres': ['alternative rock',
#   'art rock',
#   'melancholia',
#   'oxford indie',
#   'permanent wave',
#   'rock'],
#  'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#  'id': '4Z8W4fKeB5YxbusRsdQVPb',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eba03696716c9ee605006047fd',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174a03696716c9ee605006047fd',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178a03696716c9ee605006047fd',
#    'width': 160}],
#  'name': 'Radiohead',
#  'popularity': 79,
#  'type': 'artist',
#  'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}

# %% [markdown]
# ### Get John Lennon genres

# %%
spotify.search(q=f'artist:{"John Lennon"}', type='artist')['artists']['items'][0]['genres']
# Out:
# ['album rock', 'art rock', 'beatlesque', 'classic rock', 'mellow gold', 'rock']

# %% [markdown]
# ### Search for Rolling in the Deep, then use the URI to fetch details

# %%
track = 'Rolling in the Deep'
results = spotify.search(q=f'track:{track}', type='track')
fetched_track_uri = results['tracks']['items'][0]['uri']

# %%
fetched_album_uri = results['tracks']['items'][0]['album']['uri']
spotify.album(fetched_album_uri)
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#    'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#    'id': '4dpARuHxo51G3z768sgnrY',
#    'name': 'Adele',
#    'type': 'artist',
#    'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#  'available_markets': ['AR',
#   'BO',
#   'BR',
#   'BZ',
#   'CL',
#   'CO',
#   'CR',
#   'DO',
#   'EC',
#   'GT',
#   'GY',
#   'HN',
#   'MX',
#   'NI',
#   'PA',
#   'PE',
#   'PY',
#   'SR',
#   'SV',
#   'US',
#   'UY',
#   'VE'],
#  'copyrights': [{'text': '2011 XL Recordings Ltd', 'type': 'C'},
#   {'text': '2011 XL Recordings Ltd', 'type': 'P'}],
#  'external_ids': {'upc': '191404113851'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/0Lg1uZvI312TPqxNWShFXL'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/0Lg1uZvI312TPqxNWShFXL',
#  'id': '0Lg1uZvI312TPqxNWShFXL',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2732118bf9b198b05a95ded6300',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e022118bf9b198b05a95ded6300',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048512118bf9b198b05a95ded6300',
#    'width': 64}],
#  'label': 'XL Recordings',
#  'name': '21',
#  'popularity': 76,
#  'release_date': '2011-01-24',
#  'release_date_precision': 'day',
#  'total_tracks': 11,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/0Lg1uZvI312TPqxNWShFXL/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 228093,
#     'explicit': True,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1c8gk2PeTE04A1pIDH9YMk'},
#     'href': 'https://api.spotify.com/v1/tracks/1c8gk2PeTE04A1pIDH9YMk',
#     'id': '1c8gk2PeTE04A1pIDH9YMk',
#     'is_local': False,
#     'name': 'Rolling in the Deep',
#     'preview_url': 'https://p.scdn.co/mp3-preview/d62ac3e141b5305efebfc51105fc0f1941235126?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1c8gk2PeTE04A1pIDH9YMk'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 223266,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2A73XBDBQgmdXO8VsXPWIs'},
#     'href': 'https://api.spotify.com/v1/tracks/2A73XBDBQgmdXO8VsXPWIs',
#     'id': '2A73XBDBQgmdXO8VsXPWIs',
#     'is_local': False,
#     'name': 'Rumour Has It',
#     'preview_url': 'https://p.scdn.co/mp3-preview/682a93cec827369894c0328c98c0fafe574b0d8e?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2A73XBDBQgmdXO8VsXPWIs'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 250000,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4oy98QoABnGKpvapDkI525'},
#     'href': 'https://api.spotify.com/v1/tracks/4oy98QoABnGKpvapDkI525',
#     'id': '4oy98QoABnGKpvapDkI525',
#     'is_local': False,
#     'name': 'Turning Tables',
#     'preview_url': 'https://p.scdn.co/mp3-preview/2087586ebfd956d472f885d063331dc9ce326a3c?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4oy98QoABnGKpvapDkI525'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 243200,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4RyjMERDcCJHTkFpXzgUw4'},
#     'href': 'https://api.spotify.com/v1/tracks/4RyjMERDcCJHTkFpXzgUw4',
#     'id': '4RyjMERDcCJHTkFpXzgUw4',
#     'is_local': False,
#     'name': "Don't You Remember",
#     'preview_url': 'https://p.scdn.co/mp3-preview/fc248fa33512d3183c700701a30058b57e06586c?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4RyjMERDcCJHTkFpXzgUw4'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 242973,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/73CMRj62VK8nUS4ezD2wvi'},
#     'href': 'https://api.spotify.com/v1/tracks/73CMRj62VK8nUS4ezD2wvi',
#     'id': '73CMRj62VK8nUS4ezD2wvi',
#     'is_local': False,
#     'name': 'Set Fire to the Rain',
#     'preview_url': 'https://p.scdn.co/mp3-preview/b7759947483d76df9445408bf9c53517fc92cd03?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:73CMRj62VK8nUS4ezD2wvi'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 278040,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3uVsdnIglL7aTjm8X08J0M'},
#     'href': 'https://api.spotify.com/v1/tracks/3uVsdnIglL7aTjm8X08J0M',
#     'id': '3uVsdnIglL7aTjm8X08J0M',
#     'is_local': False,
#     'name': "He Won't Go",
#     'preview_url': 'https://p.scdn.co/mp3-preview/e844d9634fe3ccc3de937bf28d3a48b7ac38b0e5?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:3uVsdnIglL7aTjm8X08J0M'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 228293,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/08YJEcxGtYXwCGqXMZDiyQ'},
#     'href': 'https://api.spotify.com/v1/tracks/08YJEcxGtYXwCGqXMZDiyQ',
#     'id': '08YJEcxGtYXwCGqXMZDiyQ',
#     'is_local': False,
#     'name': 'Take It All',
#     'preview_url': 'https://p.scdn.co/mp3-preview/b45ccf8f1647144c808c80be5baa32096b8c062a?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:08YJEcxGtYXwCGqXMZDiyQ'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 241351,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5AKAyMEL5LqCkafztPdBSI'},
#     'href': 'https://api.spotify.com/v1/tracks/5AKAyMEL5LqCkafztPdBSI',
#     'id': '5AKAyMEL5LqCkafztPdBSI',
#     'is_local': False,
#     'name': "I'll Be Waiting",
#     'preview_url': 'https://p.scdn.co/mp3-preview/145237472641be1d6f5131bed24c637b88480d62?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:5AKAyMEL5LqCkafztPdBSI'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 348226,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/43dcCpx19I0R4zLr4KH1UC'},
#     'href': 'https://api.spotify.com/v1/tracks/43dcCpx19I0R4zLr4KH1UC',
#     'id': '43dcCpx19I0R4zLr4KH1UC',
#     'is_local': False,
#     'name': 'One And Only',
#     'preview_url': 'https://p.scdn.co/mp3-preview/13b30ab96351d225c023688e688767c06cf880f8?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:43dcCpx19I0R4zLr4KH1UC'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 316240,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7nm6DlSzzJTH1rk2e6EgJz'},
#     'href': 'https://api.spotify.com/v1/tracks/7nm6DlSzzJTH1rk2e6EgJz',
#     'id': '7nm6DlSzzJTH1rk2e6EgJz',
#     'is_local': False,
#     'name': 'Lovesong',
#     'preview_url': 'https://p.scdn.co/mp3-preview/2776a21ba4d5747a19ff4e1939fd1ff2071231d2?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7nm6DlSzzJTH1rk2e6EgJz'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GT',
#      'GY',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'US',
#      'UY',
#      'VE'],
#     'disc_number': 1,
#     'duration_ms': 285240,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1zwMYTA5nlNjZxYrvBB2pV'},
#     'href': 'https://api.spotify.com/v1/tracks/1zwMYTA5nlNjZxYrvBB2pV',
#     'id': '1zwMYTA5nlNjZxYrvBB2pV',
#     'is_local': False,
#     'name': 'Someone Like You',
#     'preview_url': 'https://p.scdn.co/mp3-preview/c919f6cf0b2e3cba093631682ae25aef644f49c3?cid=8d5441abc3fc486fad784142cadfbeac',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:1zwMYTA5nlNjZxYrvBB2pV'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 11},
#  'type': 'album',
#  'uri': 'spotify:album:0Lg1uZvI312TPqxNWShFXL'}

# %%
fetched_artist_uri = results['tracks']['items'][0]['artists'][0]['uri']
spotify.artist(fetched_artist_uri)['genres']
# Out:
# ['british soul', 'pop', 'pop soul', 'uk pop']

# %%
analysis = spotify.audio_analysis(fetched_track_uri)
features = spotify.audio_features(fetched_track_uri)

# %%
features
# Out:
# [{'danceability': 0.73,
#   'energy': 0.769,
#   'key': 8,
#   'loudness': -5.114,
#   'mode': 1,
#   'speechiness': 0.0298,
#   'acousticness': 0.138,
#   'instrumentalness': 0,
#   'liveness': 0.0473,
#   'valence': 0.507,
#   'tempo': 104.948,
#   'type': 'audio_features',
#   'id': '1c8gk2PeTE04A1pIDH9YMk',
#   'uri': 'spotify:track:1c8gk2PeTE04A1pIDH9YMk',
#   'track_href': 'https://api.spotify.com/v1/tracks/1c8gk2PeTE04A1pIDH9YMk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1c8gk2PeTE04A1pIDH9YMk',
#   'duration_ms': 228093,
#   'time_signature': 4}]

# %% [markdown]
# # Merge in spotify (if any) data

# %%
ready_for_export = only_songs_that_made_it_above_x

# %%
ready_for_export.to_csv('./data/1 DONE RIGHT OUTPUT unique songs.csv', index=False)

# %%
import pandas as pd
import numpy as np
from IPython.display import Markdown as md
import re

import json
np.__version__
# Out:
# '1.19.5'

# %% [markdown]
# # Load in the Hot 100 data
# Basically, Sean Miller (who made this data.world dataset I used for the prototype) keeps [a super up-do-date list of Hot 100 on GitHub](https://github.com/HipsterVizNinja/random-data/tree/main/Music/hot-100) through much of 2022, last I checked.

# %%
USEFUL_COLUMNS = ['chart_position', 'chart_debut', 'song', 'performer', 'song_id']
hot_100_raw = pd.read_csv('./data/Hot 100 through Oct 2022.csv')[USEFUL_COLUMNS]

# %%
hot_100_raw.head()
# Out:
#    chart_position chart_debut       song           performer  \
# 0              84  1990-05-05  "B" Girls  Young And Restless
# 1              78  1990-05-05  "B" Girls  Young And Restless
# 2              68  1990-05-05  "B" Girls  Young And Restless
# 3              60  1990-05-05  "B" Girls  Young And Restless
# 4              58  1990-05-05  "B" Girls  Young And Restless
#
#                        song_id
# 0  "B" GirlsYoung And Restless
# 1  "B" GirlsYoung And Restless
# 2  "B" GirlsYoung And Restless
# 3  "B" GirlsYoung And Restless
# 4  "B" GirlsYoung And Restless

# %%
md(f"## Unique songs available in full dataset: {len(hot_100_raw.drop_duplicates(subset=['song_id']))}")
# Out:
# ## Unique songs available in full dataset: 30314

# %%
SONG_RANKING_FILTER_THRESHOLD = 10

# %%
md(f"# 1. Filter to unique songs that breached the top {SONG_RANKING_FILTER_THRESHOLD}")
# Out:
# # 1. Filter to unique songs that breached the top 10

# %%
temp = hot_100_raw.sort_values('chart_position').groupby(['song_id']).first()
songs_that_made_it_above_x = temp[
    temp['chart_position'] <= SONG_RANKING_FILTER_THRESHOLD
].reset_index()

songs_that_made_it_above_x
# Out:
#                                                 song_id  chart_position  \
# 0                                   #9 DreamJohn Lennon               9
# 1     '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles               4
# 2                             '65 Love AffairPaul Davis               6
# 3                ('til) I Kissed YouThe Everly Brothers               4
# 4     (Can't Live Without Your) Love And AffectionNe...               1
# ...                                                 ...             ...
# 5061                   everything i wantedBillie Eilish               8
# 5062                      iSpyKYLE Featuring Lil Yachty               4
# 5063                                   interludeJ. Cole               8
# 5064                 my.lifeJ. Cole, 21 Savage & Morray               2
# 5065               pride.is.the.devilJ. Cole & Lil Baby               7
#
#      chart_debut                                          song  \
# 0     1974-12-21                                      #9 Dream
# 1     2002-10-26                            '03 Bonnie & Clyde
# 2     1982-02-27                               '65 Love Affair
# 3     1959-08-15                           ('til) I Kissed You
# 4     1990-07-07  (Can't Live Without Your) Love And Affection
# ...          ...                                           ...
# 5061  2019-11-23                           everything i wanted
# 5062  2017-01-14                                          iSpy
# 5063  2021-05-22                                     interlude
# 5064  2021-05-29                                       my.life
# 5065  2021-05-29                            pride.is.the.devil
#
#                             performer
# 0                         John Lennon
# 1     Jay-Z Featuring Beyonce Knowles
# 2                          Paul Davis
# 3                 The Everly Brothers
# 4                              Nelson
# ...                               ...
# 5061                    Billie Eilish
# 5062        KYLE Featuring Lil Yachty
# 5063                          J. Cole
# 5064      J. Cole, 21 Savage & Morray
# 5065               J. Cole & Lil Baby
#
# [5066 rows x 5 columns]

# %% [markdown]
# # 2. Pull genre for songs
#
# Ok, so at this point I think just *using an artist's Spotify genres as a proxy* is best.
#
# Thinking:
# - Spotify has high quality & rich data: the artist's top 5 genres ranked in order
# - Given we're looking at popular hits, it's likely song is in their most well-known genre

# %% [markdown]
# ## A. get a list of unique artists in the dataset
#
# Challenge: we need to deal with things `J. Cole & Lil Baby`. They won't always have identical genres. Likely they have overlap cuz they worked together.

# %%
def split_at(splitter, a):
    b = []
    for x in a:
        b = [
            *b,
            *x.split(splitter)
        ]
    return b

def get_array_of_performers(performer_str):
    a = split_at('&', performer_str.split(','))    
    b = split_at('&', a)
    c = split_at('Featuring', b)
    d = split_at('/', c)
    return [performer.strip() for performer in d]

get_array_of_performers('Jay-Z Featuring Beyonce Knowles')
# Out:
# ['Jay-Z', 'Beyonce Knowles']

# %%
songs_that_made_it_above_x[
    songs_that_made_it_above_x.performer.str.contains('/')
]
# Out:
#                                                 song_id  chart_position  \
# 183           All For LoveBryan Adams/Rod Stewart/Sting               1
# 982   Don't Call Us, We'll Call YouSugarloaf/Jerry C...               9
# 1012  Don't Let The Sun Go Down On MeGeorge Michael/...               1
# 1101  Dueling BanjosDeliverance/Eric Weissberg & Ste...               2
# 1648            Here We GoC+C Music Factory/F. Williams               3
# 1838  I Don't Wanna Live Forever (Fifty Shades Darke...               2
# 2618  Love Is (From "Beverly Hills, 90210")Vanessa W...               3
# 3019  No More Tears (Enough Is Enough)Barbra Streisa...               1
# 3747  Smoke From A Distant FireThe Sanford/Townsend ...               9
# 4155         The EntertainerMarvin Hamlisch/"The Sting"               3
# 4167     The Girl From IpanemaStan Getz/Astrud Gilberto               5
# 4439  Too Much, Too Little, Too LateJohnny Mathis/De...               1
# 4909  XanaduOlivia Newton-John/Electric Light Orchestra               8
#
#      chart_debut                                              song  \
# 183   1993-11-27                                      All For Love
# 982   1974-12-07                     Don't Call Us, We'll Call You
# 1012  1991-12-07                   Don't Let The Sun Go Down On Me
# 1101  1973-01-13                                    Dueling Banjos
# 1648  1991-03-02                                        Here We Go
# 1838  2016-12-31  I Don't Wanna Live Forever (Fifty Shades Darker)
# 2618  1993-01-23             Love Is (From "Beverly Hills, 90210")
# 3019  1979-10-20                  No More Tears (Enough Is Enough)
# 3747  1977-06-18                         Smoke From A Distant Fire
# 4155  1974-03-23                                   The Entertainer
# 4167  1964-06-06                             The Girl From Ipanema
# 4439  1978-04-01                    Too Much, Too Little, Too Late
# 4909  1980-08-09                                            Xanadu
#
#                                         performer
# 183                 Bryan Adams/Rod Stewart/Sting
# 982                      Sugarloaf/Jerry Corbetta
# 1012                    George Michael/Elton John
# 1101   Deliverance/Eric Weissberg & Steve Mandell
# 1648                C+C Music Factory/F. Williams
# 1838                          Zayn / Taylor Swift
# 2618              Vanessa Williams/Brian McKnight
# 3019                Barbra Streisand/Donna Summer
# 3747                    The Sanford/Townsend Band
# 4155                  Marvin Hamlisch/"The Sting"
# 4167                    Stan Getz/Astrud Gilberto
# 4439               Johnny Mathis/Deniece Williams
# 4909  Olivia Newton-John/Electric Light Orchestra

# %%
artist_list = []
def f(s):
    artist_list.extend(get_array_of_performers(s))
    
songs_that_made_it_above_x.performer.apply(lambda s: f(s))
all_artists = list(set(artist_list))
all_artists
# Out:
# ['Fall Out Boy',
#  'Roxette',
#  'Jawsh 685 x Jason Derulo',
#  'French Montana Or Too $hort Or Tyga',
#  'Jay And The Techniques',
#  'Steve Lawrence',
#  'The Sex-O-Lettes',
#  'Asia',
#  'Lorne Greene',
#  'Susan Jacks)',
#  'D.J. Jazzy Jeff',
#  'WizKid',
#  'Macklemore',
#  'Cornelius Brothers',
#  'Macy Gray',
#  'Kim Carnes',
#  'Yvonne Elliman',
#  'Timi Yuro',
#  'Rose Royce',
#  'Mike Shorey',
#  'Incubus',
#  'YoungBloodZ',
#  'George McCrae',
#  'Billy Preston',
#  'Carly Simon',
#  'R. Kelly',
#  'J. Holiday',
#  'Nine Stories',
#  'Jabba',
#  'Dionne Warwick',
#  'Smokey Robinson',
#  'Eric Clapton',
#  'John Waite',
#  'Skip Marley',
#  'The Cars',
#  'Seal',
#  'the Blackhearts',
#  'Kings Of Leon',
#  'C+C Music Factory',
#  'Sylvia (r',
#  'Paul Anthony',
#  'LeAnn Rimes',
#  'Blues Traveler',
#  'Mason Williams',
#  'Carl Dobkins',
#  'Michael McDonald',
#  'Crosby',
#  'Joey Dee',
#  'House Of Pain',
#  'Damn Yankees',
#  'Vanity Fare',
#  'Willie Nelson',
#  'Johnny Rivers',
#  'The New Seekers',
#  'Zay Hilfigerrr',
#  'Toni Braxton',
#  'Spinners',
#  'Terry Stafford',
#  'Real McCoy',
#  'iann dior',
#  "Dexy's Midnight Runners",
#  'Jay-Z + Alicia Keys',
#  'The Yardbirds',
#  'Starship',
#  'Dr. Dre)',
#  'The Americans',
#  'Charli Baltimore',
#  'Sean Paul Of The YoungBloodZ',
#  'Milli Vanilli',
#  '3OH!3',
#  'MoKenStef',
#  'Simple Minds',
#  'Tevin Campbell',
#  'Pablo Cruise',
#  'Lulu',
#  'Andy Gibb',
#  'Bow Legged Lou',
#  'Hugh Masekela',
#  'Johnny Tillotson',
#  'Merril Bainbridge',
#  'Five',
#  'The Cowsills',
#  'Travis Scott',
#  'Swing Out Sister',
#  "The O'Jays",
#  'Sleepy Brown',
#  'Tommy Tutone',
#  'Chris Stapleton',
#  'Guy Mitchell',
#  'Talking Heads',
#  'Nat King Cole',
#  "Go-Go's",
#  'The New Vaudeville Band',
#  'Charlie Daniels',
#  'Donny',
#  'Faith Hill',
#  'Raspberries',
#  'Yung Berg',
#  'Wyclef Jean',
#  'The East Side Boyz',
#  'Looking Glass',
#  'Bobby Freeman',
#  'Kicking',
#  'Andy Grammer',
#  'Evans',
#  'The Kinks',
#  'Friend And Lover',
#  'The Elton John Band',
#  'Murda Beatz',
#  'Tamara',
#  'Mike Posner',
#  'Johnny Cash',
#  'Grateful Dead',
#  'Jerry Butler',
#  'Jr. (With Bill Withers)',
#  'Joe Dowell',
#  'Brenton Wood',
#  'Athena Cage',
#  'David Naughton',
#  'Jimmy Ruffin',
#  'Mariah Carey',
#  'Luniz',
#  'The Supremes',
#  'Extreme',
#  'US3',
#  'After 7',
#  'Social House',
#  'Vanessa Carlton',
#  'Lindsey Buckingham',
#  'the "Sound of Frankie Valli"',
#  'Dinah Washington',
#  'Count Five',
#  'Bruce Hornsby',
#  'Robin Luke',
#  'Toya',
#  'The Chi-lites',
#  'Wizkid',
#  'DJ Khaled',
#  'Billy Grammer',
#  'The Mysterians',
#  'Jim Croce',
#  'Aaliyah',
#  'Joe Cocker',
#  'The Staple Singers',
#  'The Blackbyrds',
#  'Hot Butter',
#  'Cory Gunz',
#  'Dire Straits',
#  'The Bells',
#  'D4L',
#  'Luther Vandross And Janet Jackson With BBD And Ralph Tresvant',
#  'The Jaggerz',
#  'Redman',
#  'Lou Monte',
#  'Natasha Bedingfield',
#  'Artists For Haiti',
#  'Nickelback',
#  'Lord Tariq',
#  'Love Unlimited Orchestra',
#  'Kool Mo Dee',
#  'The Marketts',
#  'Chris Norman',
#  "Quad City DJ's",
#  'Jigsaw',
#  'Diane Guerrero',
#  'Inner Circle',
#  'Bill Withers',
#  'Black Box',
#  'Natural Selection',
#  'Dan Fogelberg',
#  'Dawn',
#  '3 Doors Down',
#  'Shadows Of Knight',
#  'Olivia Rodrigo',
#  'Chris Brown',
#  'The Cure',
#  'Taylor Swift',
#  'The Lumineers',
#  'Sammy Davis',
#  'Randy Travis',
#  'Tavares',
#  'Ray Stevens',
#  'Kid Cudi',
#  'Irv Gotti Presents The Inc.',
#  'Claudine Clark',
#  'EMF',
#  'Color Me Badd',
#  'Olivia',
#  'Amerie',
#  'Daddy Yankee',
#  'Perry Como',
#  'Bobby Goldsboro',
#  'Go West',
#  'The Box Tops',
#  'Paramore',
#  'Tennille',
#  'Friends',
#  'Tears For Fears',
#  'Engelbert Humperdinck',
#  'Soko',
#  'Dean',
#  'Sounds Orchestral',
#  "Chantay's",
#  'B*Witched',
#  'Bob Dylan',
#  'Billy J. Kramer With The Dakotas',
#  'Johnny Burnette',
#  'Future',
#  'LL Cool J',
#  'Tems',
#  'Coldplay',
#  'Janelle Monae',
#  'Paper Lace',
#  'Johnny Horton',
#  'Sean Kingston',
#  'Nick Jonas',
#  'Masked Wolf',
#  'Inez Foxx with Charlie Foxx',
#  'Andy Kim',
#  'L.V.',
#  'Jess Glynne',
#  'Joey McIntyre',
#  'Lynyrd Skynyrd',
#  'Night Ranger',
#  'The Orlons',
#  'Wilson Phillips',
#  'Vicki Lawrence',
#  'Rod Stewart With Ronald Isley',
#  'Justin Timberlake',
#  'Lady Saw',
#  'The Crazy World Of Arthur Brown',
#  'Stevie Nicks With Don Henley',
#  'Kyjuan',
#  'Alannah Myles',
#  'The Tymes',
#  'Iggy Azalea',
#  'Kelly Rowland',
#  'Marty Robbins',
#  "Lil' Boosie",
#  'Wilson Pickett',
#  'The Tubes',
#  'Mr. Mister',
#  'Karyn White',
#  'Bad Company',
#  'Londonbeat',
#  'Naked Eyes',
#  'The Power Station',
#  'Ambrosia',
#  'Nirvana',
#  'The Mindbenders',
#  '2Pac',
#  'Little Eva',
#  'Ray Charles and his Orchestra',
#  'Expose',
#  'Nick Lachey',
#  'Roger Williams',
#  'Elvis Presley With The Jordanaires',
#  'The Browns',
#  'Dickie Goodman',
#  'Poison',
#  'Andrea True Connection',
#  'Leif Garrett',
#  'Craig David',
#  'Jon Secada',
#  'Bill Parsons',
#  'Samantha Sang',
#  'Flo Rida',
#  'Gloria Estefan',
#  'The Animals',
#  'Janet Jackson',
#  'Scott McKenzie',
#  'Oleta Adams',
#  'Dave',
#  'John Travolta',
#  'Nina Sky',
#  "Cam'Ron",
#  'David Banner',
#  '"Weird Al" Yankovic',
#  'Mary',
#  'Christine McVie',
#  'Al Green',
#  'The Winstons',
#  'Mims',
#  'Styx',
#  'Joan Jett',
#  'The Spinners',
#  'Yung Joc',
#  'Freddie And The Dreamers',
#  'Melissa Manchester',
#  'Lipps',
#  'Baauer',
#  'Jody Watley With Eric B.',
#  'Norman Greenbaum',
#  'Kate Bush',
#  'Katrina And The Waves',
#  'New Kids On The Block',
#  'Allure',
#  'Erykah Badu',
#  'Reynolds',
#  'The Doobie Brothers',
#  'Ying Yang Twins',
#  'The Village Stompers',
#  'Sonique',
#  'A Great Big World',
#  'The Honey Cone',
#  'My Chemical Romance',
#  'The Seekers',
#  'Jordin Sparks',
#  'Rascal Flatts',
#  'Derek',
#  'Scandal',
#  'The Miracles',
#  'Sisqo',
#  'Latto',
#  'A Taste Of Honey',
#  'Victor Lundberg',
#  'Peter Cetera With Amy Grant',
#  'Steve Winwood',
#  'Mary J. Blige',
#  'The Miracles (featuring Bill "Smokey" Robinson)',
#  'DNA',
#  'Vanessa Anne Hudgens',
#  'Ryan Lewis',
#  'Toni Basil',
#  'The Delfonics',
#  'Krayzie Bone',
#  'Pure Prairie League',
#  'Lloyd Price',
#  'Linda McCartney',
#  'Deborah Cox With R.L.',
#  'Scorpions',
#  'Jody Watley',
#  'Changing Faces',
#  'Groove Theory',
#  'The Capris',
#  'USA For Africa',
#  'Dee Clark',
#  'Della Reese',
#  'Nicki French',
#  'Robert Parker',
#  'Bobby Bare',
#  'Frankie Valli',
#  'Fifth Harmony',
#  'Demi Lovato',
#  'Dean Martin',
#  'The Alan Parsons Project',
#  'Four Tops',
#  'Ohio Players',
#  'Ernie K-Doe',
#  'Az Yet',
#  'Alicia Bridges',
#  'Mario',
#  'Gene Pitney',
#  'Selena Gomez',
#  'The Killers',
#  'Mint Condition',
#  'Aerosmith',
#  'Tony Orlando',
#  'Henry Mancini And His Orchestra',
#  'The Bizz',
#  'Strawberry Alarm Clock',
#  'Brownsville Station',
#  'Bob Welch',
#  'Mauro Castillo',
#  'a-ha',
#  'Anita Ward',
#  'Leighton Meester',
#  'Rhenzy Feliz',
#  'Kyu Sakamoto',
#  'Lil Tecca',
#  'Robert John',
#  'YoungBoy Never Broke Again',
#  'Jade',
#  'Patrick Swayze (',
#  'Ketty Lester',
#  'Nelly Furtado',
#  'twenty one pilots',
#  'Rhythm Heritage',
#  'Bob Moore and His Orch.',
#  'Bad Bunny',
#  'Wings',
#  'Lenny Kravitz',
#  'NAV',
#  'Alanis Morissette',
#  'Stephanie Mills',
#  'Eric Carmen',
#  'George Harrison',
#  'Lawrence Welk And His Orchestra',
#  'Carl Anderson',
#  'Bill Pursell',
#  'The Intruders',
#  'David Seville And The Chipmunks',
#  'Duane Eddy His Twangy Guitar And The Rebels',
#  'Ray J',
#  'Ronnie Milsap',
#  'The All Stars',
#  'The Funky Bunch',
#  'Walter Murphy',
#  'The Surfaris',
#  'Delbert McClinton',
#  'AWB',
#  'The Fortunes',
#  'Ali',
#  'The Reflections',
#  'Sam',
#  'Bruce Willis',
#  'Buckcherry',
#  "Gilbert O'Sullivan",
#  'Kenny Rogers Duet With Dolly Parton',
#  'Jr. Walker',
#  'Baby Bash',
#  'The Cascades',
#  'Marvin Gaye',
#  'Dan + Shay',
#  'Len',
#  'Tracey Ullman',
#  'Sandy Nelson',
#  'Charlie Rich',
#  'Cardi B',
#  'The Tommy Dorsey Orchestra',
#  'City Spud',
#  'Enigma',
#  'Mocha',
#  'Sylk-E. Fyne',
#  'Shai',
#  'Pharrell',
#  'Puff Daddy',
#  'J. Frank Wilson and The Cavaliers',
#  'THE SCOTTS',
#  'Loon',
#  'Mike Post',
#  'Wilbert Harrison',
#  "'Til Tuesday",
#  'Robin Thicke',
#  'Bette Midler',
#  'The Allman Brothers Band',
#  'Chumbawamba',
#  'The Drifters',
#  'The Marvelettes',
#  'Paul McCartney And Michael Jackson',
#  'Daniel Bedingfield',
#  'Chubby Checker',
#  'Tatyana Ali',
#  'Jim Edward Brown',
#  'Morray',
#  'Joe Frank',
#  'The Essex',
#  'Sir Mix-A-Lot',
#  "Eden's Crush",
#  'Philip Bailey With Phil Collins',
#  'The Family Stone',
#  'Avril Lavigne',
#  'Chencho Corleone',
#  'Ozzy Osbourne',
#  'Feist',
#  'Red Hot Chili Peppers',
#  'Trick Daddy',
#  'Johnnie Taylor',
#  'The S.O.S. Band',
#  'Heatwave',
#  'The Vanilla Fudge',
#  'Anne Murray',
#  'Felly',
#  'The Tijuana Brass',
#  'William Bell',
#  'The Grass Roots',
#  'The Platters',
#  'Shinedown',
#  'Irene Cara',
#  'The Friends Of Distinction',
#  'matchbox twenty',
#  'Nicole',
#  'La Roux',
#  'Rickie Lee Jones',
#  'Johnny Kemp',
#  'Ella Mai',
#  'John Stewart',
#  'Corey Hart',
#  'Great White',
#  'John Paul Young',
#  'Rare Earth',
#  'Salt-N-Pepa',
#  'Arthur Conley',
#  'Soul II Soul',
#  'Janis Ian',
#  'The Zodiacs',
#  'Cher',
#  'Logic',
#  'Gnarls Barkley',
#  'The DeFranco Family featuring Tony DeFranco',
#  'Ocean',
#  'Falco',
#  'Nico',
#  'Marcy Playground',
#  'Europe',
#  'Motley Crue',
#  'The Young Rascals',
#  'The Gentrys',
#  'Lil Yachty',
#  'Stevie B',
#  'Betty Wright',
#  'Taco',
#  'Keith',
#  'Kiki Dee',
#  'Captain',
#  'Bubba Sparxxx',
#  'Chante Moore',
#  'Sugar Ray',
#  'Zac Efron',
#  'Amy Grant',
#  'C.W. McCall',
#  'The Dream Academy',
#  'ZZ Top',
#  '6LACK',
#  'Les Crane',
#  'Prince And The Revolution',
#  'Steam',
#  'The 5th Dimension',
#  'Domino',
#  'Lauren Bennett',
#  'Argent',
#  'All-4-One',
#  'Kelis',
#  'The Dixiebelles',
#  'Boy Meets Girl',
#  'Grace',
#  "Colby O'Donis",
#  'Martika',
#  'Jimmy Gilmer And The Fireballs',
#  'Def Leppard',
#  'Blues Image',
#  'The Fleetwoods',
#  'Skeeter Davis',
#  'Sarah Vaughan',
#  'Jay-Z',
#  'Julie Rogers',
#  'NAS',
#  'Savage Garden',
#  'Camila Cabello',
#  'Chairman Of The Board',
#  'Joanie Sommers',
#  'Hootie',
#  'Sarah McLachlan',
#  'Crofts (',
#  'Snow Patrol',
#  'The Cookies',
#  'Mobb Deep',
#  'J-Kwon',
#  'The Wanted',
#  'Love And Rockets',
#  'Shep And The Limelites',
#  'The Troggs',
#  'Daniel Caesar',
#  'Tom Cochrane',
#  'Yael Naim',
#  'Gene Chandler',
#  'Bonnie Raitt',
#  'Robbie Dupree',
#  'Dino',
#  'Jaden Smith',
#  'Brenda Lee',
#  'Duane Eddy And The Rebels',
#  'Gwen McCrae',
#  'Edie Brickell',
#  'Blondie',
#  'Kool',
#  'Shaggy',
#  "The O'Kaysions",
#  'LMFAO',
#  'Booker T.',
#  "Lil' Phat",
#  'Juelz Santana',
#  'Andy Williams',
#  'Cameo',
#  'Eric Weissberg',
#  'Ray Dalton',
#  'Lisa Lisa And Cult Jam',
#  'Garth Brooks as Chris Gaines',
#  'Cheech',
#  'Mike Reno And Ann Wilson',
#  'Bruno Mars',
#  'Timmy Thomas',
#  'Nash',
#  'Cathy Dennis',
#  'Frijid Pink',
#  'Perfect Gentlemen',
#  'Bobby Shmurda',
#  'Nitty Gritty Dirt Band',
#  "Terence Trent D'Arby",
#  'Bobby Bloom',
#  'Edward Bear',
#  'Garcia',
#  'Immature',
#  'Hurricane Chris',
#  'The Clash',
#  "Force M.D.'s",
#  'Dennis Yost',
#  'Jackson Browne',
#  'Public Announcement',
#  'Ray Anthony and His Orchestra',
#  'Lonestar',
#  'Patsy Cline',
#  'Tommy Roe',
#  'Ariana Grande',
#  'One Direction',
#  'Daniel Powter',
#  'Mase)',
#  'Travie McCoy',
#  'Hozier',
#  'Was (Not Was)',
#  'Madonna',
#  'Redbone',
#  'April Stevens',
#  'Little Peggy March',
#  'Major Harris',
#  "Alan O'Day",
#  'The Human Beinz',
#  'Joyner Lucas',
#  'Orchestra',
#  'Freda Payne',
#  'Ron Holden with The Thunderbirds',
#  'The Happenings',
#  'Mercy',
#  'The Foundations',
#  'Tony Toni Tone',
#  'JAY Z',
#  'Gordon Lightfoot',
#  'The Beau Brummels',
#  'Kenny Rogers',
#  'Sly Fox',
#  'Roberta Flack',
#  'Robert Palmer',
#  'Keyshia Cole',
#  'Alex Clare',
#  'Lynn Anderson',
#  'Mark Morrison',
#  'The J. Geils Band',
#  'Tory Lanez',
#  'Gotye',
#  'Young Money',
#  'Jefferson Starship',
#  'The Caravelles',
#  'Ginuwine',
#  'Carolyn Willis)',
#  'Bruce Springsteen',
#  'Creedence Clearwater Revival',
#  'Richard Marx',
#  "Soulja Boy Tell 'em",
#  'His Cast Of Idiots',
#  'Jackie Wilson',
#  "Brasil '66",
#  'Eddy Grant',
#  'Gucci Mane',
#  'Barbara Lynn',
#  'The Virtues',
#  'Bob Seger',
#  'Bo Donaldson And The Heywoods',
#  'Tears',
#  'Dionne Warwicke',
#  'Samantha Mumba',
#  'Loleatta Holloway',
#  'The Fabulous Thunderbirds',
#  'Aqua',
#  'Shalamar',
#  'Hinder',
#  'Luther Ingram',
#  'Mystikal',
#  'Skrillex',
#  'Monty',
#  'Player',
#  'Wang Chung',
#  'Syndicate Of Sound',
#  'Jane Wiedlin',
#  'Silk Sonic (Bruno Mars',
#  'Debbie Gibson',
#  'The Pointer Sisters',
#  'Remy Boyz',
#  'Claude King',
#  'Prince',
#  'Joni Mitchell',
#  'Danity Kane',
#  'Missy Elliott',
#  'Lil Mama',
#  'Glass Tiger',
#  'G-Eazy',
#  'Adam Lambert',
#  'Soul For Real',
#  'Quarterflash',
#  'J Balvin',
#  'Fabian',
#  'Cliff Richard',
#  'Cascada',
#  '69 Boyz',
#  'Jim Jones',
#  'The Irish Rovers',
#  'Meat Loaf',
#  'Bachman-Turner Overdrive',
#  'Clyde McPhatter',
#  "Al (He's the King) Hirt",
#  'The Sanford',
#  'Mike + The Mechanics',
#  'The Monkees',
#  'Jimmy Soul',
#  'Debelah Morgan',
#  'Sheryl Crow',
#  'Brian Hyland',
#  'Bobby Helms',
#  'Rayvon',
#  'Luther Vandross',
#  'Sergio Mendes',
#  'Cat Stevens',
#  'Doris Troy',
#  'Bobby Sherman',
#  'Alias',
#  'Crispian St. Peters',
#  'Patty Smyth',
#  'AJR',
#  'Lita Ford (Duet With Ozzy Osbourne)',
#  'Dixie Chicks',
#  'The Heights',
#  'Jagged Edge With Nelly',
#  'Billy Bland',
#  'Murray Head',
#  'Post Malone',
#  'Rick Nelson And The Stone Canyon Band',
#  'Field Mob',
#  'Lloyd',
#  'Big Bopper',
#  'The Everly Brothers',
#  '42 Dugg',
#  'Dennis Coffey',
#  'Lauryn Hill',
#  'Jr. with The Mike Curb Congregation',
#  'Silkk The Shocker',
#  'Ian Whitcomb And Bluesville',
#  'Morgan Wallen',
#  'John Mellencamp',
#  'Larry Mullen',
#  'The Sandpipers',
#  'Gary Puckett',
#  'The Jimmy Castor Bunch',
#  'Matthew Wilder',
#  'UB40',
#  'Paul Anka with Odia Coates',
#  'Earth',
#  'Wham!',
#  'Wendy Fraser)',
#  'Alice Cooper',
#  'Brian',
#  'Merrilee Rush',
#  'David Soul',
#  'Imagine Dragons X JID',
#  'Donnie Brooks',
#  'Arthur Lyman Group',
#  'Garfunkel',
#  'Paul McCoy',
#  'The Rolling Stones',
#  'Bob B. Soxx And The Blue Jeans',
#  'Dr. Dre',
#  'Lukas Graham',
#  'Gary Glitter',
#  'Patti Austin With James Ingram',
#  'The Johnny Otis Show',
#  'GloRilla',
#  'Ritchie Valens',
#  'Right Said Fred',
#  'Kim Wilde',
#  'Toto',
#  'U.S. Bonds',
#  'Dionne Farris',
#  'Gary Puckett And The Union Gap',
#  'B.J. Thomas',
#  'The Lettermen',
#  'Another Bad Creation',
#  'The Sweet',
#  'Mr. Big',
#  'Sheena Easton',
#  'Wynter',
#  'Smith',
#  'Michael W. Smith',
#  'Stray Cats',
#  'Wayne Fontana',
#  "Shakespear's Sister",
#  'EVE',
#  'Los Lobos',
#  'Spragga Benz',
#  'Ray Peterson',
#  'Jessica Simpson',
#  'Wanz',
#  'Capital Cities',
#  'TLC',
#  'We Five',
#  'David Rose and His Orchestra',
#  'Spandau Ballet',
#  'The Free Movement',
#  'Da Brat',
#  'Randy Newman',
#  'Astrud Gilberto',
#  'Blu Cantrell',
#  'The Oak Ridge Boys',
#  'Mark Ronson',
#  'Dan Hartman',
#  'D-Mob Introducing Cathy Dennis',
#  'Madness',
#  'Tamia Or Ashanti',
#  'Wadsworth Mansion',
#  'J. Weav',
#  'Idina Menzel',
#  'Daryl Hall John Oates',
#  'Portugal. The Man',
#  'Uncle Kracker',
#  'D12',
#  'The Rascals',
#  'The B-52s',
#  'Journey',
#  'Colbie Caillat',
#  'Beastie Boys',
#  'Dua Lipa',
#  'Blues Magoos',
#  'Timbaland',
#  'Skid Row',
#  'Jodeci',
#  'Childish Gambino',
#  'Dennis DeYoung',
#  'Young Thug',
#  'Carl Carlton',
#  'OutKast',
#  'Charlay',
#  'Jesse McCartney',
#  'Project Pat',
#  'Mar-Keys',
#  'T.I.',
#  'Anita Bryant',
#  'Corina',
#  'Shelley Fabares',
#  'Warren G',
#  'Seduction',
#  'The Righteous Brothers',
#  'Esther Phillips "Little Esther"',
#  'Eric Burdon And War',
#  'CeCe Winans',
#  'The Impressions',
#  'Paul Nicholas',
#  'Eddie Murphy',
#  'Diana Ross',
#  'K-Ci',
#  'Hannah Montana',
#  'Survivor',
#  'Migos',
#  'Paul Evans and the Curls',
#  'Donny Osmond',
#  'Mitch Ryder And The Detroit Wheels',
#  'Barry Manilow',
#  'Mongo Santamaria Band',
#  'P.M. Dawn',
#  'Marc Anthony',
#  'Natalie Cole',
#  'Freddie Cannon',
#  'Gipp',
#  'Ferrante',
#  'The Contours',
#  'LSG',
#  'The Olympics',
#  'Tim McGraw',
#  'Mike Douglas',
#  'Led Zeppelin',
#  'The Serendipity Singers',
#  'SAINt JHN',
#  'Kid Rock',
#  'The Notorious B.I.G.',
#  'Royal Philharmonic Orchestra',
#  'Willy William',
#  'Juice WRLD',
#  'Voices Of Theory',
#  'INXS',
#  'Florence Welch',
#  'Big Mountain',
#  'Eddie Cochran',
#  'The American Breed',
#  'Dee Dee Sharp',
#  'B',
#  'Mel Carter',
#  'The Royal Guardsmen',
#  'Divinyls',
#  'Naughty By Nature',
#  'benny blanco',
#  'Lil Peanut',
#  'The Capitols',
#  'Ernie Maresca',
#  'Ray',
#  'The Honeycombs',
#  'His Lost Planet Airmen',
#  'Hank Locklin',
#  'The Silver Bullet Band',
#  'Pat Benatar',
#  'Neil Diamond',
#  'Chong',
#  'The Spencer Davis Group',
#  'Bay City Rollers',
#  'Yo Gotti',
#  'Far*East Movement',
#  'Miss Toni Fisher',
#  'Eddie Money',
#  'Clarence Henry',
#  'Nelson',
#  'The Emotions',
#  'Tony Joe White',
#  'Crazy Town',
#  'Whitesnake',
#  'Nelly',
#  'Sheck Wes',
#  'Jimmy Buffett',
#  'Ruben Studdard',
#  'Skylar Grey',
#  'Cassie',
#  'Bananarama',
#  'Judy Collins',
#  'Jonas Brothers',
#  'Kalin Twins',
#  'Ronnie Dyson',
#  'Dion',
#  'The Union Gap',
#  'Jhay Cortez',
#  'Ava Max',
#  'Major Lance',
#  'John Fred And The Playboys',
#  'Adina Howard',
#  'The G-Clefs',
#  'Jamie Foxx',
#  'Deep Purple',
#  'KC And The Sunshine Band',
#  'Bobby Vinton',
#  'David Guetta',
#  'Chicago',
#  'Weezer',
#  'Rufus',
#  'Johnny Mathis',
#  'Golden Earring',
#  'Glenn Frey',
#  'The Belmonts',
#  'Ringo Starr',
#  'Divine',
#  'Hoobastank',
#  'Musical Youth',
#  'Club Nouveau',
#  'Jan',
#  'M.C. Hammer',
#  'Elvis Presley',
#  'Meredith Brooks',
#  'Brenda Russell',
#  'Sister Janet Mead',
#  'David Ruffin',
#  'Neil Sedaka',
#  'Jack Scott',
#  'E-40',
#  'Sly',
#  'Fleetwood Mac',
#  'Walker Hayes',
#  'La Bouche',
#  'The Chiffons',
#  'Jorgen Ingmann',
#  'Linda Ronstadt',
#  'Dion (Di Muci)',
#  'Eurythmics',
#  'Bee Gees',
#  'Foxy Brown',
#  'The Beatles With Billy Preston',
#  'Bobby "Boris" Pickett And The Crypt-Kickers',
#  'Jon B',
#  'Jim Stafford',
#  'Bradley Cooper',
#  'Swae Lee',
#  'David Lee Roth',
#  'Anna Kendrick',
#  'Lonnie Donegan And His Skiffle Group',
#  'The Vandellas',
#  'Los Del Rio',
#  '"The Sting"',
#  'Wreckx-N-Effect',
#  'Billy Davis',
#  'Barry White',
#  'Chad Kroeger',
#  'Young-Holt Unlimited',
#  'Daft Punk',
#  'Blink-182',
#  'Meco',
#  'Eric Burdon',
#  'Fabolous',
#  'Blxst',
#  'Dazz Band',
#  'Johnny Thunder',
#  'Halsey',
#  'Trina',
#  'SSgt Barry Sadler',
#  'Blue Magic',
#  'Poni-Tails',
#  'Paul',
#  'Ronald Isley',
#  'Lee Michaels',
#  "Franck Pourcel's French Fiddles",
#  ...]

# %%
[a for a in all_artists if ' And ' in a]
# Out:
# ['Jay And The Techniques',
#  'Friend And Lover',
#  'Luther Vandross And Janet Jackson With BBD And Ralph Tresvant',
#  'Freddie And The Dreamers',
#  'Katrina And The Waves',
#  'Henry Mancini And His Orchestra',
#  'Lawrence Welk And His Orchestra',
#  'David Seville And The Chipmunks',
#  'Duane Eddy His Twangy Guitar And The Rebels',
#  'Paul McCartney And Michael Jackson',
#  'Prince And The Revolution',
#  'Jimmy Gilmer And The Fireballs',
#  'Love And Rockets',
#  'Shep And The Limelites',
#  'Duane Eddy And The Rebels',
#  'Lisa Lisa And Cult Jam',
#  'Mike Reno And Ann Wilson',
#  'Bo Donaldson And The Heywoods',
#  'Rick Nelson And The Stone Canyon Band',
#  'Ian Whitcomb And Bluesville',
#  'Bob B. Soxx And The Blue Jeans',
#  'Gary Puckett And The Union Gap',
#  'Eric Burdon And War',
#  'Mitch Ryder And The Detroit Wheels',
#  'John Fred And The Playboys',
#  'KC And The Sunshine Band',
#  'Bobby "Boris" Pickett And The Crypt-Kickers',
#  'Lonnie Donegan And His Skiffle Group',
#  'Roy Head And The Traits',
#  'Perez Prado And His Orchestra',
#  'Tommy James And The Shondells',
#  'B.J. Thomas And The Triumphs',
#  'Paul McCartney And Wings',
#  'Peter And Gordon',
#  'Hank Ballard And The Midnighters',
#  'Paul McCartney And Stevie Wonder',
#  'Percy Faith And His Orchestra',
#  'Tones And I',
#  'Eric Clapton And His Band',
#  'Joe Cocker And Jennifer Warnes',
#  'Gerry And The Pacemakers',
#  'Gary Lewis And The Playboys',
#  'The Jive Five With Joe Rene And Orchestra',
#  'Ronny And The Daytonas',
#  'Lisa Lisa And Cult Jam With Full Force',
#  'Stevie Nicks With Tom Petty And The Heartbreakers',
#  'Mel And Tim',
#  'Bobby Vee And The Strangers',
#  'Brewer And Shipley',
#  'Celine Dion And Peabo Bryson',
#  'Ruby And The Romantics',
#  'Johnny And The Hurricanes',
#  'His Orchestra And Chorus',
#  'Paul Mauriat And His Orchestra',
#  'Little Anthony And The Imperials',
#  'Gladys Knight And The Pips',
#  'Michael Jackson And Paul McCartney',
#  'Dr. Hook And The Medicine Show',
#  'Usher And Alicia Keys',
#  'Tom Petty And The Heartbreakers',
#  'Diana Ross And The Supremes',
#  'Louis Armstrong And The All Stars',
#  'Spanky And Our Gang',
#  'Roy Orbison And The Candy Men',
#  'Rosie And The Originals',
#  'Ray Conniff And The Singers',
#  'Harold Melvin And The Blue Notes',
#  'Van McCoy And The Soul City Symphony',
#  'K-Ci And JoJo',
#  'Prince And The New Power Generation',
#  'Prince And The N.P.G.',
#  'Ollie And Jerry',
#  'Bert Kaempfert And His Orchestra',
#  'Julio Iglesias And Willie Nelson',
#  'Kenny Rogers And Sheena Easton',
#  'James Brown And The Famous Flames',
#  'Jimmy Clanton And His Rockets']

# %% [markdown]
# ## B. pull from Spotify
# Pull my own metadata from [Spotify](https://developer.spotify.com/documentation/web-api/), using [Spotipy](https://spotipy.readthedocs.io/en/2.19.0/).
#
# ### NOTE: unfortunately Spotify doesn't (no longer?) give you genre for a given song. The best you can get is genre for the *artist*. Darn...

# %%
import spotipy
import sys
from spotipy.oauth2 import SpotifyClientCredentials

# spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
#     client_id='8d5441abc3fc486fad784142cadfbeac'
# ))

# %%
def get_name_and_genres_from_spotify(name):
    try: 
        print(name)
        results = spotify.search(q='artist:' + name, type='artist')
        try:
            items = results['artists']['items']
            first_result = items[0]
        except:
            print('NO RESULTS')
            return
        return (
            name,
            first_result['name'],
            first_result['genres'],
        )
    except:
        print(F'API failed: {name}')

# %%
# get_name_and_genres_from_spotify('Rick Nelson And The Stone Canyon Band')

# %% [markdown]
# ### Actual fetch (no need to repeat)

# %%
# artist_metadata = []
# for artist_name in all_artists:
#     artist_metadata.extend(
#         [get_name_and_genres_from_spotify(artist_name)]
#     )

# artist_metadata

# %% [markdown]
# ### Save fetched metadata to disk

# %%
# len(artist_metadata)

# %%
json_file = "./data/artist_metadata.json"
# with open(json_file, "w") as outfile:
#     json.dump(artist_metadata, outfile)

# %%
artist_metadata_from_disk = None
with open(json_file, "r") as outfile:
     artist_metadata_from_disk = json.load(outfile)
        
len(artist_metadata_from_disk)
# Out:
# 2451

# %%
orig_name_col = []
found_name_col = []
genres_col = []
for i in range(len(all_artists)):
    entry = artist_metadata_from_disk[i]
    orig_name_col.extend([all_artists[i]])
    found_name_col.extend([entry[1] if entry else None])
    genres_col.extend([entry[2] if (entry and len(entry[2])) else None])
    
orig_name_col
found_name_col
genres_col

df_artist_genres = pd.DataFrame({'orig_name': orig_name_col, 'found_name': found_name_col, 'genres': genres_col})
df_artist_genres
# Out:
#                                 orig_name                found_name  \
# 0                            Fall Out Boy             Jordan Knight
# 1                                 Roxette                      None
# 2                Jawsh 685 x Jason Derulo               Eddie Money
# 3     French Montana Or Too $hort Or Tyga                   Cam’ron
# 4                  Jay And The Techniques               The Hollies
# ...                                   ...                       ...
# 2446                      Bobby Valentino                 Young Dro
# 2447                                 Iyaz               Roddy Ricch
# 2448        Jimmy Clanton And His Rockets              Ugly Kid Joe
# 2449                        The Kid LAROI  Gladys Knight & The Pips
# 2450                              Nilsson        The String-A-Longs
#
#                                                  genres
# 0                                                  None
# 1                                                  None
# 2     [album rock, classic rock, country rock, folk ...
# 3     [battle rap, east coast hip hop, gangster rap,...
# 4     [album rock, brill building pop, british invas...
# ...                                                 ...
# 2446  [atl hip hop, crunk, dirty south rap, futurist...
# 2447                           [melodic rap, rap, trap]
# 2448  [funk metal, funk rock, glam metal, hard rock,...
# 2449  [classic soul, disco, funk, motown, quiet stor...
# 2450                                       [surf music]
#
# [2451 rows x 3 columns]

# %% [markdown]
# #### Notable: spotify found some more "official names" from our (imperfect) attempt at splitting out names:

# %%
df_artist_genres[
    (df_artist_genres.orig_name != df_artist_genres.found_name) &
    df_artist_genres.found_name.notna()
]
# Out:
#                                 orig_name                found_name  \
# 0                            Fall Out Boy             Jordan Knight
# 2                Jawsh 685 x Jason Derulo               Eddie Money
# 3     French Montana Or Too $hort Or Tyga                   Cam’ron
# 4                  Jay And The Techniques               The Hollies
# 5                          Steve Lawrence           Imagine Dragons
# ...                                   ...                       ...
# 2446                      Bobby Valentino                 Young Dro
# 2447                                 Iyaz               Roddy Ricch
# 2448        Jimmy Clanton And His Rockets              Ugly Kid Joe
# 2449                        The Kid LAROI  Gladys Knight & The Pips
# 2450                              Nilsson        The String-A-Longs
#
#                                                  genres
# 0                                                  None
# 2     [album rock, classic rock, country rock, folk ...
# 3     [battle rap, east coast hip hop, gangster rap,...
# 4     [album rock, brill building pop, british invas...
# 5                                   [modern rock, rock]
# ...                                                 ...
# 2446  [atl hip hop, crunk, dirty south rap, futurist...
# 2447                           [melodic rap, rap, trap]
# 2448  [funk metal, funk rock, glam metal, hard rock,...
# 2449  [classic soul, disco, funk, motown, quiet stor...
# 2450                                       [surf music]
#
# [2306 rows x 3 columns]

# %% [markdown]
# # 3. Merge genre into the dataset
#
# ## THE CHALLENGE OF WORKING WITH ARTSITS IN THIS DATASET:
#
# *Ideal world*: we're given data with an ARRAY of performers for each song. We can just get metadata about each.
#
# *Real world*: `performers` col has just strings, with (sometimes) multiple artist in them, seperated by stuff like `","` or `"&"` or `" and "` (and sometimes `" and "` is just part of the performer name!!)
#
# *My current chosen path forward*:
#
# 1. try splitting stuff into individual names as best as I can (imperfect method)
# 2. try fetching genres for those names (imperfect: some don't have genres, some aren't properly split into individual names from step 1)
# 3. re-assign genre to the original dataset.
# 4. PROBLEM: we have ~500 genres to chose. *ideal approach* is to tag every single genre to a meta genre (likely `pop, rock, jazz, hip hop, country/folk, electornic, latin` and the `misc` for things that can't be shoved into those bins well). *solution I'm going to go with now*: I'll shove them into some rough categories based on *sub-string* match (imperfect, I know), & just one of the original genre if I can't make it work.

# %%
genre_list = []
def merge_genres(genres):
    genres and genre_list.extend(genres)
    
df_artist_genres.genres.apply(lambda genres: merge_genres(genres))
all_genres = list(set(genre_list))
all_genres
# Out:
# ['afrofuturism',
#  'cool jazz',
#  'electropowerpop',
#  'reggae',
#  'nursery',
#  'k-rap',
#  'pop r&b',
#  'sleaze rock',
#  'singer-songwriter',
#  'atl trap',
#  'classic country pop',
#  'adult standards',
#  'rocksteady',
#  'boy band',
#  'rap',
#  'neo mellow',
#  'ccm',
#  'uk post-punk',
#  'country dawn',
#  'post-disco',
#  'shanty',
#  'memphis blues',
#  'hi-nrg',
#  'disco house',
#  'filter house',
#  'uk dnb',
#  'funk rock',
#  'hyphy',
#  'light music',
#  'old school hip hop',
#  'german soundtrack',
#  'transpop',
#  'orchestral performance',
#  'afro dancehall',
#  'american folk revival',
#  'screamo',
#  'harlem renaissance',
#  'us power metal',
#  'italo dance',
#  'comic',
#  'synth funk',
#  'anarcho-punk',
#  'pop house',
#  'modern alternative pop',
#  'canadian trap',
#  'lilith',
#  'dutch rock',
#  'brass band',
#  'harmonica blues',
#  'album rock',
#  'neo-classical',
#  'electric blues',
#  'canadian country',
#  'punk',
#  'japanese jazz',
#  'christian a cappella',
#  'heartland rock',
#  'classic uk pop',
#  'brostep',
#  'classical performance',
#  'roots reggae',
#  'south african jazz',
#  'viral pop',
#  'afropop',
#  'rap kreyol',
#  'new jack swing',
#  'jazz blues',
#  'boston rock',
#  'piano blues',
#  'chicago soul',
#  'proto-metal',
#  'chicago bop',
#  'disney',
#  'easy listening',
#  'dub',
#  'irish rock',
#  'sad lo-fi',
#  'soft rock',
#  'alternative dance',
#  'puerto rican pop',
#  'vocal jazz',
#  'athens indie',
#  'corrido',
#  'banjo',
#  'country',
#  'southern soul',
#  'memphis hip hop',
#  'canadian blues',
#  'vapor twitch',
#  'ohio hip hop',
#  'jazz trumpet',
#  'space age pop',
#  'argentine hip hop',
#  'german orchestra',
#  'talent show',
#  'trap queen',
#  'neo classical metal',
#  'choral',
#  'reggaeton colombiano',
#  "children's folk",
#  'urban contemporary',
#  'art punk',
#  'experimental hip hop',
#  'bahamian pop',
#  'exotica',
#  'boston hip hop',
#  'classic house',
#  'uk pop',
#  'tempe indie',
#  'mississippi hip hop',
#  'modern alternative rock',
#  'world',
#  'jazz saxophone',
#  'doo-wop',
#  'east coast hip hop',
#  'new orleans rap',
#  'jamaican ska',
#  'progressive bluegrass',
#  'beach music',
#  'comedy rap',
#  'alternative hip hop',
#  'chicago blues',
#  'jazz organ',
#  'synthpop',
#  'acid rock',
#  'skiffle',
#  'eurodance',
#  'tierra caliente',
#  'classic rock',
#  'gangster rap',
#  'nwobhm',
#  'yodeling',
#  'latin jazz',
#  'video game music',
#  'edm',
#  'austin singer-songwriter',
#  'rare groove',
#  'bolero',
#  'ectofolk',
#  'british invasion',
#  'reggae fusion',
#  'florida rap',
#  'irish singer-songwriter',
#  'riddim',
#  'sad rap',
#  'glam punk',
#  'oakland hip hop',
#  'manchester hip hop',
#  'jazz funk',
#  'rockabilly',
#  'battle rap',
#  'dancehall',
#  'london rap',
#  'emo rap',
#  'pop venezolano',
#  'german hard rock',
#  'thai pop',
#  'deep dance pop',
#  'kindie rock',
#  'bubblegum pop',
#  'neue deutsche welle',
#  'seattle indie',
#  'outlaw country',
#  'pop dance',
#  'neon pop punk',
#  'stride',
#  'native american',
#  'nashville sound',
#  'big band',
#  'asian american hip hop',
#  'pop edm',
#  'detroit hip hop',
#  'orchestra',
#  'new age piano',
#  'boogie',
#  'hardcore hip hop',
#  'desi trap',
#  'etherpop',
#  'political hip hop',
#  'canadian indie',
#  'crunk',
#  'nz pop',
#  'british orchestra',
#  'british soul',
#  'deep classic garage rock',
#  'stomp and holler',
#  'native american contemporary',
#  'contemporary vocal jazz',
#  'electronica',
#  'country gospel',
#  'quiet storm',
#  'socal pop punk',
#  'glam rock',
#  'indie r&b',
#  'bboy',
#  'yacht rock',
#  'blues',
#  'afro r&b',
#  'canadian psychedelic',
#  'jam band',
#  'fourth world',
#  'deep adult standards',
#  'tropical house',
#  'garage rock',
#  'nueva musica mexicana',
#  'scottish new wave',
#  'retro soul',
#  'portland hip hop',
#  'glam metal',
#  'alt z',
#  'sacramento indie',
#  'latin worship',
#  'r&b',
#  'swamp rock',
#  'electro',
#  'sophisti-pop',
#  'pub rock',
#  'symphonic rock',
#  'afrobeat',
#  'st louis rap',
#  'post-punk',
#  'pluggnb',
#  'tropical',
#  'azonto',
#  'swamp blues',
#  'futuristic swag',
#  'thrash metal',
#  'alabama rap',
#  'freak folk',
#  'hip pop',
#  'k-pop',
#  'new england americana',
#  'samba-jazz',
#  'eau claire indie',
#  'swedish melodic rock',
#  'uk contemporary r&b',
#  'bossa nova',
#  'flute rock',
#  'bedroom soul',
#  'rap conscient',
#  'bassline',
#  'atl hip hop',
#  'vapor trap',
#  'dream pop',
#  'soul blues',
#  'chamber pop',
#  'house',
#  'cowboy western',
#  'progressive electro house',
#  'canadian latin',
#  'rock keyboard',
#  'pop rock',
#  'candy pop',
#  'detroit trap',
#  'francoton',
#  'mexican pop',
#  'latin pop',
#  "preschool children's music",
#  'underground power pop',
#  'traditional blues',
#  'lullaby',
#  'plugg',
#  'canadian contemporary r&b',
#  'canadian pop',
#  'chillwave',
#  'pop punk',
#  'north carolina hip hop',
#  'rhode island rap',
#  'modern salsa',
#  'indie soul',
#  'australian hip hop',
#  'nu metal',
#  'maine indie',
#  'rap metal',
#  'truck-driving country',
#  'swedish pop',
#  'swing revival',
#  'mambo',
#  'alternative rock',
#  'moombahton',
#  'psychedelic soul',
#  'pittsburgh rap',
#  'dance rock',
#  'celtic',
#  'bounce',
#  "children's music",
#  'salsa',
#  'mellow gold',
#  'rock',
#  'classic girl group',
#  'austropop',
#  'torch song',
#  'glee club',
#  'arkansas country',
#  'synthwave',
#  'nashville indie',
#  'roots rock',
#  'brooklyn drill',
#  'norteno',
#  'r&b argentino',
#  'souldies',
#  'indie pop rap',
#  'australian electropop',
#  'jazz rap',
#  'new orleans blues',
#  'bergen indie',
#  'instrumental soul',
#  'acoustic pop',
#  'traprun',
#  'detroit rock',
#  'swamp pop',
#  'italian adult pop',
#  'colombian pop',
#  'hard rock',
#  'german metal',
#  'trip hop',
#  'danish pop',
#  'scottish rock',
#  'brit funk',
#  'drum and bass',
#  'gospel r&b',
#  'conscious hip hop',
#  'jazz piano',
#  'cowpunk',
#  "man's orchestra",
#  'dutch house',
#  'australian dance',
#  'gothic rock',
#  'christian indie',
#  'compositional ambient',
#  'rap latina',
#  'freakbeat',
#  'irish pub song',
#  'alte',
#  'mariachi',
#  'reggaeton flow',
#  'ambient house',
#  'classic canadian rock',
#  'south carolina hip hop',
#  'old school atlanta hip hop',
#  'west coast rap',
#  'british folk',
#  'cosmic american',
#  'jawaiian',
#  'uk reggae',
#  'redneck',
#  'hip hop',
#  'blues rock',
#  'motown',
#  'popping',
#  'beatlesque',
#  'tennessee hip hop',
#  'cyberpunk',
#  'r&b en espanol',
#  'europop',
#  'melodic rap',
#  'gospel',
#  'modern power pop',
#  'deep underground hip hop',
#  'folk rock',
#  'guyanese pop',
#  'merseybeat',
#  'background piano',
#  'canadian singer-songwriter',
#  'nigerian hip hop',
#  'indie rock',
#  'texas country',
#  'metropopolis',
#  'psychedelic rock',
#  'french dnb',
#  'funk',
#  'dfw rap',
#  'middle earth',
#  'psychedelic folk rock',
#  'norteno-sax',
#  'nigerian pop',
#  'corridos tumbados',
#  'new orleans jazz',
#  'mariachi cristiano',
#  'novelty',
#  'mexican classic rock',
#  'trap soul',
#  'black comedy',
#  'progressive rock',
#  'wu fam',
#  'modern blues rock',
#  'world worship',
#  'progressive house',
#  'grunge',
#  'musica mexicana',
#  'bubblegum dance',
#  'australian indie',
#  'trap',
#  'desi hip hop',
#  'country road',
#  'theme',
#  'jazz',
#  'swing italiano',
#  'pacific islands pop',
#  'birmingham metal',
#  'celtic rock',
#  'jazz guitar',
#  'a cappella',
#  'baroque pop',
#  'deep new americana',
#  'alternative country',
#  'chicago rap',
#  'street band',
#  'uk funky',
#  'indonesian hip hop',
#  'swedish synthpop',
#  'hip house',
#  'brazilian jazz',
#  'vocal house',
#  'swedish hard rock',
#  'southern rock',
#  'hindi hip hop',
#  'country pop',
#  'progressive metal',
#  'barbadian pop',
#  'lo-fi product',
#  'freestyle',
#  'art rock',
#  'folk-pop',
#  'neo-psychedelic',
#  'complextro',
#  'melancholia',
#  'christian music',
#  'michigan indie',
#  'country rock',
#  'zolo',
#  'modern reggae',
#  'psychedelic blues-rock',
#  'modern rock',
#  'girl group',
#  'classic australian country',
#  'bronx hip hop',
#  'hammond organ',
#  'latin christian',
#  'cancion melodica',
#  'folk',
#  'broadway',
#  'pop rap',
#  'indietronica',
#  'punk blues',
#  'vocal harmony group',
#  "women's music",
#  'comedy',
#  'jazz fusion',
#  'classic italian pop',
#  'show tunes',
#  'baton rouge rap',
#  'instrumental funk',
#  'focus beats',
#  'scandipop',
#  'neo soul',
#  'pinoy hip hop',
#  'canadian hip hop',
#  'instrumental surf',
#  'enka',
#  'ska',
#  'jamaican hip hop',
#  'ambient folk',
#  'louisiana blues',
#  'bossa nova jazz',
#  'drill',
#  'modern blues',
#  'jangle pop',
#  'texas latin rap',
#  'comedy rock',
#  'acoustic blues',
#  'pixie',
#  'idol',
#  'modern country rock',
#  'liquid funk',
#  'permanent wave',
#  'miami bass',
#  'jump blues',
#  'australian rock',
#  'hard bop',
#  'new mexico music',
#  'underground hip hop',
#  'indie pop',
#  'k-pop boy group',
#  'contemporary jazz',
#  'dutch prog',
#  'bachata',
#  'deep groove house',
#  'hollywood',
#  'australian r&b',
#  'latin funk',
#  'diva house',
#  'post-screamo',
#  'deep talent show',
#  'scottish singer-songwriter',
#  'double drumming',
#  'chicago drill',
#  'indie folk',
#  'jazz drums',
#  'rock-and-roll',
#  "children's story",
#  'vincy soca',
#  'bebop',
#  'ska revival',
#  'rock drums',
#  'danish electronic',
#  'contemporary country',
#  'surf music',
#  'lovers rock',
#  'electropop',
#  'electro house',
#  'soul jazz',
#  'australian pop',
#  'speedrun',
#  'minneapolis sound',
#  'indiecoustica',
#  'classic soundtrack',
#  'honky tonk',
#  'houston rap',
#  'deep motown',
#  'canadian old school hip hop',
#  'deep soft rock',
#  'miami hip hop',
#  'ranchera',
#  'second line',
#  'country rap',
#  'deep southern trap',
#  'irish folk',
#  'shiver pop',
#  'post-grunge',
#  'brill building pop',
#  'golden age hip hop',
#  'french indie pop',
#  'pop',
#  'new wave',
#  'g funk',
#  'emo',
#  'belgian singer-songwriter',
#  'disco',
#  'viral trap',
#  'classic garage rock',
#  'chicano rap',
#  'smooth jazz',
#  'pop romantico',
#  'delta blues',
#  'dansktop',
#  'dancehall queen',
#  'madchester',
#  'paisley underground',
#  'hard minimal techno',
#  'rock of gibraltar',
#  'indie poptimism',
#  'pop reggaeton',
#  'atlanta bass',
#  'new wave pop',
#  'uk dance',
#  'dmv rap',
#  'dixieland',
#  'ballroom',
#  'canadian metal',
#  'honky-tonk piano',
#  'italo house',
#  'new age',
#  'new americana',
#  'swedish electropop',
#  'new rave',
#  'harlem hip hop',
#  'german pop',
#  'synthesizer',
#  'big room',
#  'melbourne bounce international',
#  'swing',
#  'piano rock',
#  'australian country',
#  'new orleans funk',
#  'sad sierreno',
#  'post-teen pop',
#  'lounge',
#  'melbourne bounce',
#  'dance pop',
#  'nyc rap',
#  'american oi',
#  'viral rap',
#  'gauze pop',
#  'reggaeton',
#  'pop soul',
#  'queens hip hop',
#  'chicano punk',
#  'art pop',
#  'german techno',
#  'metal',
#  'banda',
#  'lo-fi brasileiro',
#  'acid house',
#  'classic dubstep',
#  'trap argentino',
#  'contemporary r&b',
#  'protopunk',
#  'early reggae',
#  'trancecore',
#  'deep euro house',
#  'musical advocacy',
#  'smooth saxophone',
#  'texas blues',
#  'free jazz',
#  'jazz trombone',
#  'funk metal',
#  'traditional country',
#  'nu jazz',
#  'memphis soul',
#  'soca',
#  'classic soul',
#  'kentucky hip hop',
#  'classic swedish pop',
#  'yakut pop',
#  'bow pop',
#  'australian alternative rock',
#  'cali rap',
#  'parody',
#  'movie tunes',
#  'philly soul',
#  'trap latino',
#  'jamgrass',
#  'slap house',
#  'rap rock',
#  'dancefloor dnb',
#  'philly rap',
#  'avant-garde jazz',
#  'grebo',
#  'alternative metal',
#  'chopped and screwed',
#  'korean old school hip hop',
#  'bass trap',
#  'seattle hip hop',
#  'virginia hip hop',
#  'oklahoma country',
#  'lgbtq+ hip hop',
#  'new orleans soul',
#  'supergroup',
#  'nederpop',
#  'worship',
#  'salsa colombiana',
#  'steampunk',
#  'deep house',
#  'old school thrash',
#  'electronic trap',
#  'soul',
#  'toronto rap',
#  'britpop',
#  'pop emo',
#  'power pop',
#  'alternative r&b',
#  'canadian celtic',
#  'old school dancehall',
#  'german rock',
#  'new romantic',
#  'canadian rock',
#  'italian disco',
#  'british blues',
#  'christian alternative rock',
#  'sierreno',
#  'k-pop girl group',
#  'rhythm and blues',
#  'new jersey rap',
#  'sunshine pop',
#  'dirty south rap',
#  'psychedelic folk',
#  'latin hip hop',
#  'latin viral pop',
#  'psychedelic pop',
#  'southern hip hop',
#  'samba',
#  'northern soul',
#  'german dance',
#  'lds youth',
#  'neoperreo',
#  'new beat',
#  'minnesota hip hop',
#  'kiwi rock',
#  'bluegrass',
#  'escape room',
#  'neo-synthpop',
#  'contemporary post-bop']

# %%
pd.Series(all_genres).describe()
# Out:
# count              683
# unique             683
# top       afrofuturism
# freq                 1
# dtype: object

# %%
[genre for genre in all_genres if 'electro' in genre]
# Out:
# ['electropowerpop',
#  'electronica',
#  'electro',
#  'progressive electro house',
#  'australian electropop',
#  'danish electronic',
#  'electropop',
#  'electro house',
#  'swedish electropop',
#  'electronic trap']

# %%
','.join(['hi', 'by'])
# Out:
# 'hi,by'

# %%
GENERIC_GENRES = [ 'jazz', 'hip hop', 'country', 'folk', 'electro', 'latin', 'rock', 'pop']

def get_the_most_generic_genre_possible(artist_array):
    if artist_array:
        match = df_artist_genres[
            df_artist_genres.orig_name == artist_array[0]
        ]
        genres = match.iloc[0].genres
        if genres:
            genres_string = ','.join(genres)
            for generic_genre in GENERIC_GENRES:
                if generic_genre in genres_string:
                    return generic_genre
    return 'uncategorized'

artist_genre_merged_in = songs_that_made_it_above_x.copy()

artist_genre_merged_in['artist_array'] =  artist_genre_merged_in.performer.apply(lambda s: get_array_of_performers(s))

artist_genre_merged_in['generic_genre'] = artist_genre_merged_in.artist_array.apply(lambda a: get_the_most_generic_genre_possible(a))

# %%
artist_genre_merged_in.generic_genre.value_counts()
# Out:
# uncategorized    1730
# rock             1015
# pop               963
# country           460
# hip hop           435
# folk              205
# electro           101
# jazz               99
# latin              58
# Name: generic_genre, dtype: int64

# %%
artist_genre_merged_in
# Out:
#                                                 song_id  chart_position  \
# 0                                   #9 DreamJohn Lennon               9
# 1     '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles               4
# 2                             '65 Love AffairPaul Davis               6
# 3                ('til) I Kissed YouThe Everly Brothers               4
# 4     (Can't Live Without Your) Love And AffectionNe...               1
# ...                                                 ...             ...
# 5061                   everything i wantedBillie Eilish               8
# 5062                      iSpyKYLE Featuring Lil Yachty               4
# 5063                                   interludeJ. Cole               8
# 5064                 my.lifeJ. Cole, 21 Savage & Morray               2
# 5065               pride.is.the.devilJ. Cole & Lil Baby               7
#
#      chart_debut                                          song  \
# 0     1974-12-21                                      #9 Dream
# 1     2002-10-26                            '03 Bonnie & Clyde
# 2     1982-02-27                               '65 Love Affair
# 3     1959-08-15                           ('til) I Kissed You
# 4     1990-07-07  (Can't Live Without Your) Love And Affection
# ...          ...                                           ...
# 5061  2019-11-23                           everything i wanted
# 5062  2017-01-14                                          iSpy
# 5063  2021-05-22                                     interlude
# 5064  2021-05-29                                       my.life
# 5065  2021-05-29                            pride.is.the.devil
#
#                             performer                  artist_array  \
# 0                         John Lennon                 [John Lennon]
# 1     Jay-Z Featuring Beyonce Knowles      [Jay-Z, Beyonce Knowles]
# 2                          Paul Davis                  [Paul Davis]
# 3                 The Everly Brothers         [The Everly Brothers]
# 4                              Nelson                      [Nelson]
# ...                               ...                           ...
# 5061                    Billie Eilish               [Billie Eilish]
# 5062        KYLE Featuring Lil Yachty            [KYLE, Lil Yachty]
# 5063                          J. Cole                     [J. Cole]
# 5064      J. Cole, 21 Savage & Morray  [J. Cole, 21 Savage, Morray]
# 5065               J. Cole & Lil Baby           [J. Cole, Lil Baby]
#
#       generic_genre
# 0              rock
# 1           hip hop
# 2              rock
# 3               pop
# 4             latin
# ...             ...
# 5061        country
# 5062           rock
# 5063  uncategorized
# 5064  uncategorized
# 5065  uncategorized
#
# [5066 rows x 7 columns]

# %%
artist_genre_merged_in[
    artist_genre_merged_in.generic_genre.isna()
]
# Out:
# Empty DataFrame
# Columns: [song_id, chart_position, chart_debut, song, performer, artist_array, generic_genre]
# Index: []

# %% [markdown]
# # 4. Export

# %%
ready_for_export = artist_genre_merged_in

# %%
ready_for_export.to_csv('./data/1 DONE RIGHT OUTPUT unique songs.csv', index=False)

# %%
import pandas as pd
import numpy as np
from IPython.display import Markdown as md
import re

import json
np.__version__
# Out:
# '1.19.5'

# %% [markdown]
# # Load in the Hot 100 data
# Basically, Sean Miller (who made this data.world dataset I used for the prototype) keeps [a super up-do-date list of Hot 100 on GitHub](https://github.com/HipsterVizNinja/random-data/tree/main/Music/hot-100), downloaded through 2022.

# %%
USEFUL_COLUMNS = ['chart_position', 'chart_debut', 'song', 'performer', 'song_id']
hot_100_raw = pd.read_csv('./data/Hot 100 through 2022.csv')[USEFUL_COLUMNS]

# %%
hot_100_raw
# Out:
#         chart_position chart_debut  \
# 0                   84  1990-05-05
# 1                   78  1990-05-05
# 2                   68  1990-05-05
# 3                   60  1990-05-05
# 4                   58  1990-05-05
# ...                ...         ...
# 336290              99  2000-11-04
# 336291              66  1958-12-13
# 336292              53  1958-12-13
# 336293              47  1958-12-13
# 336294              47  1958-12-13
#
#                                                     song           performer  \
# 0                                              "B" Girls  Young And Restless
# 1                                              "B" Girls  Young And Restless
# 2                                              "B" Girls  Young And Restless
# 3                                              "B" Girls  Young And Restless
# 4                                              "B" Girls  Young And Restless
# ...                                                  ...                 ...
# 336290                                        www.memory        Alan Jackson
# 336291  ¿Dònde Està Santa Claus? (Where Is Santa Claus?)          Augie Rios
# 336292  ¿Dònde Està Santa Claus? (Where Is Santa Claus?)          Augie Rios
# 336293  ¿Dònde Està Santa Claus? (Where Is Santa Claus?)          Augie Rios
# 336294  ¿Dònde Està Santa Claus? (Where Is Santa Claus?)          Augie Rios
#
#                                                   song_id
# 0                             "B" GirlsYoung And Restless
# 1                             "B" GirlsYoung And Restless
# 2                             "B" GirlsYoung And Restless
# 3                             "B" GirlsYoung And Restless
# 4                             "B" GirlsYoung And Restless
# ...                                                   ...
# 336290                             www.memoryAlan Jackson
# 336291  ¿Dònde Està Santa Claus? (Where Is Santa Claus...
# 336292  ¿Dònde Està Santa Claus? (Where Is Santa Claus...
# 336293  ¿Dònde Està Santa Claus? (Where Is Santa Claus...
# 336294  ¿Dònde Està Santa Claus? (Where Is Santa Claus...
#
# [336295 rows x 5 columns]

# %%
md(f"## Unique songs available in full dataset: {len(hot_100_raw.drop_duplicates(subset=['song_id']))}")
# Out:
# ## Unique songs available in full dataset: 30444

# %%
SONG_RANKING_FILTER_THRESHOLD = 10

# %%
md(f"# 1. Filter to unique songs that breached the top {SONG_RANKING_FILTER_THRESHOLD}")
# Out:
# # 1. Filter to unique songs that breached the top 10

# %%
temp = hot_100_raw.sort_values('chart_position').groupby(['song_id']).first()
songs_that_made_it_above_x = temp[
    temp['chart_position'] <= SONG_RANKING_FILTER_THRESHOLD
].reset_index()

songs_that_made_it_above_x
# Out:
#                                                 song_id  chart_position  \
# 0                                   #9 DreamJohn Lennon               9
# 1     '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles               4
# 2                             '65 Love AffairPaul Davis               6
# 3                ('til) I Kissed YouThe Everly Brothers               4
# 4     (Can't Live Without Your) Love And AffectionNe...               1
# ...                                                 ...             ...
# 5089                   everything i wantedBillie Eilish               8
# 5090                      iSpyKYLE Featuring Lil Yachty               4
# 5091                                   interludeJ. Cole               8
# 5092                 my.lifeJ. Cole, 21 Savage & Morray               2
# 5093               pride.is.the.devilJ. Cole & Lil Baby               7
#
#      chart_debut                                          song  \
# 0     1974-12-21                                      #9 Dream
# 1     2002-10-26                            '03 Bonnie & Clyde
# 2     1982-02-27                               '65 Love Affair
# 3     1959-08-15                           ('til) I Kissed You
# 4     1990-07-07  (Can't Live Without Your) Love And Affection
# ...          ...                                           ...
# 5089  2019-11-23                           everything i wanted
# 5090  2017-01-14                                          iSpy
# 5091  2021-05-22                                     interlude
# 5092  2021-05-29                                       my.life
# 5093  2021-05-29                            pride.is.the.devil
#
#                             performer
# 0                         John Lennon
# 1     Jay-Z Featuring Beyonce Knowles
# 2                          Paul Davis
# 3                 The Everly Brothers
# 4                              Nelson
# ...                               ...
# 5089                    Billie Eilish
# 5090        KYLE Featuring Lil Yachty
# 5091                          J. Cole
# 5092      J. Cole, 21 Savage & Morray
# 5093               J. Cole & Lil Baby
#
# [5094 rows x 5 columns]

# %%
songs_that_made_it_above_x[
    songs_that_made_it_above_x.chart_debut.str.startswith('2022-11')
]
# Out:
#                                                 song_id  chart_position  \
# 275                               Anti-HeroTaylor Swift               1
# 347                                BackOutsideBoyzDrake               9
# 429                               BejeweledTaylor Swift               6
# 719                         Circo LocoDrake & 21 Savage               8
# 2340                                  KarmaTaylor Swift               9
# 2429                          Lavender HazeTaylor Swift               2
# 2513                                  Lift Me UpRihanna               2
# 2733                Major DistributionDrake & 21 Savage               3
# 2766                                 MaroonTaylor Swift               3
# 2810                          Midnight RainTaylor Swift               5
# 3104                             On BSDrake & 21 Savage               4
# 3321                Privileged RappersDrake & 21 Savage               7
# 3342  Pussy & MillionsDrake & 21 Savage Featuring Tr...               6
# 3353                           Question...?Taylor Swift               7
# 3423                         Rich FlexDrake & 21 Savage               2
# 3780  Snow On The BeachTaylor Swift Featuring Lana D...               4
# 3860                       Spin Bout UDrake & 21 Savage               5
# 4610                         Vigilante ShitTaylor Swift              10
# 5047                You're On Your Own, KidTaylor Swift               8
#
#      chart_debut                     song  \
# 275   2022-11-05                Anti-Hero
# 347   2022-11-19          BackOutsideBoyz
# 429   2022-11-05                Bejeweled
# 719   2022-11-19               Circo Loco
# 2340  2022-11-05                    Karma
# 2429  2022-11-05            Lavender Haze
# 2513  2022-11-12               Lift Me Up
# 2733  2022-11-19       Major Distribution
# 2766  2022-11-05                   Maroon
# 2810  2022-11-05            Midnight Rain
# 3104  2022-11-19                    On BS
# 3321  2022-11-19       Privileged Rappers
# 3342  2022-11-19         Pussy & Millions
# 3353  2022-11-05             Question...?
# 3423  2022-11-19                Rich Flex
# 3780  2022-11-05        Snow On The Beach
# 3860  2022-11-19              Spin Bout U
# 4610  2022-11-05           Vigilante Shit
# 5047  2022-11-05  You're On Your Own, Kid
#
#                                      performer
# 275                               Taylor Swift
# 347                                      Drake
# 429                               Taylor Swift
# 719                          Drake & 21 Savage
# 2340                              Taylor Swift
# 2429                              Taylor Swift
# 2513                                   Rihanna
# 2733                         Drake & 21 Savage
# 2766                              Taylor Swift
# 2810                              Taylor Swift
# 3104                         Drake & 21 Savage
# 3321                         Drake & 21 Savage
# 3342  Drake & 21 Savage Featuring Travis Scott
# 3353                              Taylor Swift
# 3423                         Drake & 21 Savage
# 3780       Taylor Swift Featuring Lana Del Rey
# 3860                         Drake & 21 Savage
# 4610                              Taylor Swift
# 5047                              Taylor Swift

# %% [markdown]
# # 2. Pull genre for songs
#
# Ok, so at this point I think just *using an artist's Spotify genres as a proxy* is best.
#
# Thinking:
# - Spotify has high quality & rich data: the artist's top 5 genres ranked in order
# - Given we're looking at popular hits, it's likely song is in their most well-known genre

# %% [markdown]
# ## A. get a list of unique artists in the dataset
#
# ## 🚧 IMPROVEMENTS:
# - clean the names better (eg remove things like `(...)` or just `)` that might exist)
# - add more splitting instances (especially ` And ` and ` With `), and just handle special cases of bands that use that splitter in their name (ie create a "safe list" of them)
#
# Challenge: we need to deal with things `J. Cole & Lil Baby`. They won't always have identical genres. Likely they have overlap cuz they worked together.

# %%
def split_at(splitter, a):
    b = []
    for x in a:
        b = [
            *b,
            *x.split(splitter)
        ]
    return b

def get_array_of_performers(performer_str):
    a = split_at('&', performer_str.split(','))    
    b = split_at('&', a)
    c = split_at('Featuring', b)
    d = split_at('/', c)
    return [performer.strip() for performer in d]

get_array_of_performers('Jay-Z Featuring Beyonce Knowles')
# Out:
# ['Jay-Z', 'Beyonce Knowles']

# %%
songs_that_made_it_above_x[
    songs_that_made_it_above_x.performer.str.contains('/')
]
# Out:
#                                                 song_id  chart_position  \
# 183           All For LoveBryan Adams/Rod Stewart/Sting               1
# 988   Don't Call Us, We'll Call YouSugarloaf/Jerry C...               9
# 1018  Don't Let The Sun Go Down On MeGeorge Michael/...               1
# 1107  Dueling BanjosDeliverance/Eric Weissberg & Ste...               2
# 1655            Here We GoC+C Music Factory/F. Williams               3
# 1845  I Don't Wanna Live Forever (Fifty Shades Darke...               2
# 2630  Love Is (From "Beverly Hills, 90210")Vanessa W...               3
# 3034  No More Tears (Enough Is Enough)Barbra Streisa...               1
# 3769  Smoke From A Distant FireThe Sanford/Townsend ...               9
# 4181         The EntertainerMarvin Hamlisch/"The Sting"               3
# 4193     The Girl From IpanemaStan Getz/Astrud Gilberto               5
# 4465  Too Much, Too Little, Too LateJohnny Mathis/De...               1
# 4936  XanaduOlivia Newton-John/Electric Light Orchestra               8
#
#      chart_debut                                              song  \
# 183   1993-11-27                                      All For Love
# 988   1974-12-07                     Don't Call Us, We'll Call You
# 1018  1991-12-07                   Don't Let The Sun Go Down On Me
# 1107  1973-01-13                                    Dueling Banjos
# 1655  1991-03-02                                        Here We Go
# 1845  2016-12-31  I Don't Wanna Live Forever (Fifty Shades Darker)
# 2630  1993-01-23             Love Is (From "Beverly Hills, 90210")
# 3034  1979-10-20                  No More Tears (Enough Is Enough)
# 3769  1977-06-18                         Smoke From A Distant Fire
# 4181  1974-03-23                                   The Entertainer
# 4193  1964-06-06                             The Girl From Ipanema
# 4465  1978-04-01                    Too Much, Too Little, Too Late
# 4936  1980-08-09                                            Xanadu
#
#                                         performer
# 183                 Bryan Adams/Rod Stewart/Sting
# 988                      Sugarloaf/Jerry Corbetta
# 1018                    George Michael/Elton John
# 1107   Deliverance/Eric Weissberg & Steve Mandell
# 1655                C+C Music Factory/F. Williams
# 1845                          Zayn / Taylor Swift
# 2630              Vanessa Williams/Brian McKnight
# 3034                Barbra Streisand/Donna Summer
# 3769                    The Sanford/Townsend Band
# 4181                  Marvin Hamlisch/"The Sting"
# 4193                    Stan Getz/Astrud Gilberto
# 4465               Johnny Mathis/Deniece Williams
# 4936  Olivia Newton-John/Electric Light Orchestra

# %%
artist_list = []
def f(s):
    artist_list.extend(get_array_of_performers(s))
    
songs_that_made_it_above_x.performer.apply(lambda s: f(s))
all_artists = list(set(artist_list))
all_artists
# Out:
# ['Rakim',
#  'Toya',
#  'Black Box',
#  'Barry Mann',
#  'Bill Withers',
#  'John Martin',
#  'A Taste Of Honey',
#  'My Chemical Romance',
#  'Edgar Winter Group',
#  'Kelly Rowland',
#  '3OH!3',
#  'Lil Tjay',
#  'Rickie Lee Jones',
#  'Styles P.',
#  'Barbra Streisand',
#  'Natasha Bedingfield',
#  'Pips',
#  'Matthew Santos',
#  'Shadows Of Knight',
#  'Hanson',
#  "Al (He's the King) Hirt",
#  'The Newbeats',
#  'Bell Biv DeVoe',
#  'Juice Newton',
#  'Ne-Yo',
#  'Tom Petty',
#  'Harry Chapin',
#  'The Chakachas',
#  'Ray Parker Jr.',
#  'Jennifer Warnes',
#  'Wanz',
#  'Les Crane',
#  'The New Seekers',
#  'The First Edition',
#  'Boz Scaggs',
#  'Regina Belle',
#  "The O'Jays",
#  'Animotion',
#  'Joe Cocker with Leon Russell',
#  'Chicago',
#  'Michael Bolton',
#  'Van McCoy And The Soul City Symphony',
#  'Mike + The Mechanics',
#  'Tony! Toni! Tone!',
#  'Gary Lewis And The Playboys',
#  'Spin Doctors',
#  'Major Lazer',
#  'Bobby Sherman',
#  "Michel'le",
#  'Nicole Scherzinger',
#  'Skylar Grey',
#  'LL Cool J',
#  'Divine',
#  'Mongo Santamaria Band',
#  'The Young Rascals',
#  'Dodie Stevens',
#  'Scandal',
#  "Lil' Mo",
#  'Missy Elliott',
#  'Smokey Robinson',
#  'Dorothy Moore',
#  'Sean Paul Of The YoungBloodZ',
#  'The Enchanters',
#  'Mike Reno And Ann Wilson',
#  'Drake',
#  "Oran 'Juice' Jones",
#  'James',
#  'The Chipmunks With David Seville',
#  'Hurricane Smith',
#  'Ciara',
#  'Steve Miller',
#  'Cliff Nobles',
#  'Kalin Twins',
#  'Travis',
#  'Naughty By Nature',
#  'J-Kwon',
#  'Deborah Cox With R.L.',
#  'Claudine Clark',
#  'Blood',
#  'B',
#  'Ambrosia',
#  "Lil' Phat",
#  'Yung Joc',
#  'Pablo Cruise',
#  'Brian',
#  'Quavo',
#  "Soulja Boy Tell 'em",
#  'Tears',
#  'Meghan Trainor',
#  'Walter Brennan',
#  'Hank Locklin',
#  "The Lovin' Spoonful",
#  'Freekey Zekey',
#  '? (Question Mark)',
#  'Leighton Meester',
#  'The Elton John Band',
#  'Donell Jones',
#  'His Orchestra',
#  'Kygo x Selena Gomez',
#  'BLACKstreet',
#  'Tammi Terrell',
#  'Ying Yang Twins',
#  'K.W.S.',
#  'Petey Pablo',
#  'Jeannie C. Riley',
#  'Ricardo "RikRok" Ducent',
#  'Lea',
#  "Terence Trent D'Arby",
#  'Regina',
#  'Chris Montez',
#  'George Benson',
#  'Bryson Tiller',
#  'Reunion',
#  'Barenaked Ladies',
#  'Bobby Hart',
#  'Hank Ballard And The Midnighters',
#  'Rivers Cuomo',
#  'Big Bopper',
#  'The Kid LAROI',
#  '4PM',
#  'Frankie J',
#  'The Flying Machine',
#  'Jeffrey Daniels',
#  'James Brown And The Famous Flames',
#  'Billy Preston',
#  'New Kids On The Block',
#  'Keri Hilson',
#  "Lil' Boosie",
#  'Cher',
#  '69 Boyz',
#  'K-Ci',
#  'The New Vaudeville Band',
#  'A Great Big World',
#  'Kenny Rogers And Sheena Easton',
#  'Tim McGraw With Faith Hill',
#  'Nino Tempo',
#  'Maroon 5',
#  'Mike Jones',
#  'Megan Thee Stallion',
#  'Swedish House Mafia',
#  'Brandy',
#  'David Soul',
#  'Marty Robbins',
#  'Melissa Etheridge',
#  'Michael Jackson And Paul McCartney',
#  'Redbone',
#  "Plain White T's",
#  'Syndicate Of Sound',
#  'Peter Frampton',
#  'The Undisputed Truth',
#  'Inez Foxx with Charlie Foxx',
#  'Joey McIntyre',
#  'Prince And The N.P.G.',
#  'Anita Baker',
#  'Mase)',
#  'Keyshia Cole',
#  'B.o.B',
#  'The Browns',
#  'KYLE',
#  'Bebe Rexha',
#  'Jesse McCartney',
#  'Tiffany',
#  'Scorpions',
#  'Peter And Gordon',
#  'D-Mob Introducing Cathy Dennis',
#  'Glass Animals',
#  'J. Weav',
#  'Mauro Castillo',
#  'Yung Berg',
#  'Chesney Hawkes',
#  'The Everly Brothers',
#  'Sixpence None The Richer',
#  'Lil Uzi Vert',
#  'Jaden Smith',
#  'Paul McCoy',
#  'Dem Franchize Boyz',
#  'Maxine Nightingale',
#  'Jessica Simpson',
#  'Bob Welch',
#  'Steam',
#  'Stampeders',
#  'Eve',
#  'Swae Lee',
#  'Idina Menzel',
#  'The Dixie Cups',
#  'Mr. ColliPark',
#  'Tim McGraw',
#  'Hugh Masekela',
#  'Luniz',
#  'The Weeknd',
#  'Barry Gibb',
#  'Sheryl Crow',
#  'Village People',
#  'Loleatta Holloway',
#  'Tracie Spencer',
#  'Raydio',
#  'Total',
#  'Ali',
#  'Dazz Band',
#  'Engelbert Humperdinck',
#  'Nash',
#  'Hot Chelle Rae',
#  'Rod Stewart',
#  'The Grass Roots',
#  'Sue Thompson',
#  'Gary U.S. Bonds',
#  'The Buffalo Springfield',
#  'Alicia Keys',
#  'Meredith Brooks',
#  'Aloe Blacc',
#  'Paul',
#  'Looking Glass',
#  'The Dixiebelles',
#  'WALK THE MOON',
#  'The Highwaymen',
#  'Infamous 2.0',
#  'Soul Survivors',
#  'Talking Heads',
#  'Seduction',
#  'The Surfaris',
#  'Terry Stafford',
#  'Sly',
#  'Timmy Thomas',
#  'The Beach Boys',
#  'Teicher',
#  'Carl Anderson',
#  'Ray Stevens',
#  'The Stylistics',
#  'Hannah Montana',
#  'Rich Boy',
#  'Tracey Ullman',
#  'Blues Traveler',
#  'Culture Club',
#  'Chuck Mangione',
#  'Bobby Womack',
#  'MC Lyte',
#  'The Tommy Dorsey Orchestra',
#  'Laura Branigan',
#  'Don Johnson',
#  'Olivia',
#  'Enrique Iglesias',
#  'Del Shannon',
#  'John Ford Coley',
#  'Joe Frank',
#  'Zedd',
#  'Juelz Santana',
#  'Peaches',
#  'Passenger',
#  'Liam Payne',
#  'Pilot',
#  'Tom Cochrane',
#  'Olivia Rodrigo',
#  'Starship',
#  'Garnet Mimms',
#  'The Brothers Johnson',
#  'Pat Boone',
#  'SSgt Barry Sadler',
#  'Larry Mullen',
#  'The Wanted',
#  'Arcadia',
#  'Meat Loaf',
#  'Silk Sonic (Bruno Mars',
#  'Ace Of Base',
#  'The Clash',
#  'Herb',
#  'Gregory Abbott',
#  'P. Diddy',
#  'Major Lance',
#  'Justin Bieber',
#  'Billy Grammer',
#  'Normani',
#  'Procol Harum',
#  'The Emotions',
#  'Franke',
#  'Stevie B',
#  'Al Wilson',
#  'Bone Thugs-N-Harmony',
#  'The Tony Rich Project',
#  'Lipps',
#  'The Osmonds',
#  'Rare Earth',
#  'The Righteous Brothers',
#  'JoJo',
#  'Barbara Lewis',
#  'Tony Joe White',
#  'Daryl Hall',
#  'Phil Collins and Marilyn Martin',
#  'Night Ranger',
#  'Maureen McGovern',
#  'Walker Hayes',
#  'Janis Joplin',
#  'Tina Turner',
#  'Dan Hartman',
#  'Delbert McClinton',
#  'Peabo Bryson',
#  'Alannah Myles',
#  'The Troggs',
#  'Icona Pop',
#  'NAV',
#  'Don Henley',
#  'Brownsville Station',
#  'Thelma Houston',
#  'D.J. Jazzy Jeff',
#  'Seal',
#  'ABBA',
#  'Bobbie Gentry',
#  'The Casinos',
#  'Artists For Haiti',
#  'Trick Daddy',
#  'The Zodiacs',
#  'The Doors',
#  'Al Green',
#  'The Fabulous Thunderbirds',
#  'Rupert Holmes',
#  'Dan + Shay',
#  'Ke$ha',
#  'The Intruders',
#  'Bradley Cooper',
#  'Albert Hammond',
#  'Portugal. The Man',
#  'BlocBoy JB',
#  'E-40',
#  'Larry Verne',
#  'Dick and DeeDee',
#  'Joey Powers',
#  'Whitney Houston Feat. Faith Evans',
#  'Gordon Lightfoot',
#  'Billy Stewart',
#  'William DeVaughn',
#  'Lonnie Mack',
#  'Garcia',
#  'Climax',
#  'Amerie',
#  'Nena',
#  'Lil Baby',
#  'Monica',
#  'Kelly Clarkson',
#  'Bobby Shmurda',
#  'Fort Minor',
#  'Lou Gramm',
#  'John Fred And The Playboys',
#  'Masked Wolf',
#  'Marky Mark',
#  "Olivia O'Brien",
#  'TLC',
#  'Chuck Berry',
#  'John Legend',
#  'Van Morrison',
#  'Judy Collins',
#  'Evelyn "Champagne" King',
#  'The Knockouts',
#  'Rhenzy Feliz',
#  'The Hondells',
#  'Amy Winehouse',
#  'The Byrds',
#  'Johnny Cash',
#  'John Cafferty',
#  'Tommy James',
#  'Latto',
#  'London Symphony Orchestra',
#  'Len Barry',
#  'Frank Ifield',
#  'Nickelback',
#  'Ann Wilson',
#  'Robert Palmer',
#  'Lil Wayne',
#  'Mary Jane Girls',
#  'Motley Crue',
#  'Dave',
#  'Timbaland',
#  'The Three Degrees',
#  'Jack Wagner',
#  'Jonathan Edwards',
#  'Paul Revere',
#  'Fire with The Emotions',
#  'Cascada',
#  'Billy Joe Royal',
#  'Mocedades',
#  '6ix9ine',
#  'Tommy Boyce',
#  'Kim Petras',
#  'iann dior',
#  'Michael Jackson With Siedah Garrett',
#  'Paul Evans and the Curls',
#  'Kajagoogoo',
#  'Jose Feliciano',
#  'Maxi Priest',
#  'Usher And Alicia Keys',
#  'Social House',
#  'Glee Cast',
#  'Marty Balin',
#  'LFO',
#  'After The Fire',
#  'Aerosmith',
#  'Jordin Sparks Duet With Chris Brown',
#  '2Pac',
#  'Sister Rose',
#  'Wayne Fontana',
#  'Eydie Gorme',
#  'Unk',
#  'Celine Dion And Peabo Bryson',
#  'Mitch Ryder And The Detroit Wheels',
#  'The Tams',
#  'The Family (Feat. The Notorious B.I.G.',
#  'Jimmy Eat World',
#  'Charli Baltimore',
#  'Lorne Greene',
#  'The Oak Ridge Boys',
#  'Tommy Roe',
#  "Go-Go's",
#  'Breathe',
#  'The Caravelles',
#  'Eric Carmen',
#  'Bob Dylan',
#  "The MG's",
#  'SAINt JHN',
#  'Metro Station',
#  'Rocky Burnette',
#  'The Village Stompers',
#  'Kate Bush',
#  'Diplo With Justin Bieber',
#  'The Fendermen',
#  'Bobby Freeman',
#  'Daft Punk',
#  'The 4 Seasons',
#  'Robin S.',
#  'The Sylvers',
#  'Jerry Corbetta',
#  'Bloodstone',
#  'The Left Banke',
#  'The Jets',
#  'Joe Simon',
#  'Merril Bainbridge',
#  'The Free Movement',
#  'The Capris',
#  'The Ventures',
#  'Kenny Ball and his Jazzmen',
#  'Weezer',
#  'Slim Thug',
#  'Richard Marx',
#  'MAGIC!',
#  'Dusty Springfield',
#  'Tory Lanez',
#  'Ronny And The Daytonas',
#  'Carla Thomas',
#  'Connie Stevens',
#  'The Sandpipers',
#  'Polow Da Don',
#  'Johnny And The Hurricanes',
#  'Machine Gun Kelly x Camila Cabello',
#  'Kyu Sakamoto',
#  'Jordan Knight',
#  'Joe Public',
#  'Bruce Springsteen',
#  'Jr. (With Bill Withers)',
#  'Cat Stevens',
#  'Marvin Gaye',
#  'The Coasters',
#  'Ringo Starr',
#  'Sting',
#  'Kid Rock',
#  'The Happenings',
#  'Tony Toni Tone',
#  'Steve Winwood',
#  'Freddie Scott',
#  'Baauer',
#  'Zager',
#  'Information Society',
#  '98 Degrees',
#  'Tevin Campbell',
#  'Harold Melvin And The Blue Notes',
#  'Reg Owen',
#  'The Staple Singers',
#  'Jagged Edge With Nelly',
#  'The Marmalade',
#  'The All-American Rejects',
#  'Starland Vocal Band',
#  'Johnny Lee',
#  'Playboi Carti',
#  'Extreme',
#  'Melanie with The Edwin Hawkins Singers',
#  'Pratt',
#  'Owl City',
#  'The Kingston Trio',
#  'The Miracles',
#  'Kendrick Lamar',
#  'Petula Clark',
#  'Lynyrd Skynyrd',
#  'The Youngbloods',
#  'Jerry Reed',
#  'Christopher Cross',
#  'Wings',
#  'Debelah Morgan',
#  'Jimmie Rodgers',
#  'Tag Team',
#  'The Fray',
#  'Santo',
#  'Patti Austin With James Ingram',
#  'Bruce Channel',
#  "Bill Black's Combo",
#  'Jermaine Jackson',
#  'Blink-182',
#  'Randy',
#  'David Geddes',
#  'Boston',
#  'Paul Anthony',
#  'Dickey Lee',
#  'Blues Image',
#  'The Cookies',
#  'Charlay',
#  'Paul Anka',
#  'Bill Conti',
#  'Berlin',
#  'Blaque',
#  'Tyrese',
#  'D4L',
#  'Tom Clay',
#  'Toni Basil',
#  'Van Halen',
#  'Randy Travis',
#  'The Honey Cone',
#  'OutKast',
#  'D.H.T.',
#  'Mac Davis',
#  'Daniel Caesar',
#  'Arrested Development',
#  'Joe Jonas',
#  'Dickie Goodman',
#  'The Cranberries',
#  'Rick Springfield',
#  'Brendon Urie',
#  'Onyx',
#  'Ini Kamoze',
#  'The Rainbows',
#  'Londonbeat',
#  'Mike Posner',
#  'Huey',
#  'Bobby Brown',
#  'Deee-Lite',
#  'Nitty Gritty Dirt Band',
#  'The Capitols',
#  'Mac Miller',
#  'The Papas',
#  'The McCoys',
#  'Peter Brown With Betty Wright',
#  'Lady Saw',
#  'Napoleon XIV',
#  'Bon Iver',
#  'Lou Bega',
#  'Lonestar',
#  'Kevin Rudolf',
#  'The Little Dippers',
#  'Puff Daddy',
#  'Linear',
#  'Diane Renay',
#  'Barry Manilow',
#  'Prince',
#  'Barbara George',
#  'The Ivy Three',
#  'Tamara',
#  'Martika',
#  'The Brothers Four',
#  'The Allman Brothers Band',
#  'Edward Byrnes',
#  'The Fresh Prince',
#  'Randy Vanwarmer',
#  'Sister Sledge',
#  'Hot Butter',
#  'Kent Jones',
#  "Quad City DJ's",
#  "Manfred Mann's Earth Band",
#  'Donna Fargo',
#  'The Marvelettes',
#  'Faith Evans',
#  'Babyface',
#  'Calloway',
#  'Panic! At The Disco',
#  'The Dells',
#  'Olivia Newton-John',
#  'David Banner',
#  'T.I.',
#  'Bo Donaldson And The Heywoods',
#  'The Impressions',
#  'Paramore',
#  'Garth Brooks as Chris Gaines',
#  'Lewis Capaldi',
#  'ZZ Top',
#  'Aaliyah',
#  'Suzanne Vega',
#  'Kimbra',
#  'Robbie Dupree',
#  'Marshmello',
#  'The Essex',
#  'Rhythm Syndicate',
#  'Timex Social Club',
#  'Jason Derulo',
#  'Patrick Swayze (',
#  'Anita Bryant',
#  'Steve Perry',
#  'Johnny Mathis',
#  'Chad Kroeger',
#  'Will To Power',
#  'Patti Page',
#  'Majid Jordan',
#  'Alive',
#  'Imagine Dragons X JID',
#  'Sarah Vaughan',
#  'Nicki Minaj X Lil Baby',
#  'Phil Collins',
#  'Al Martino',
#  'Henry Gross',
#  'LMFAO',
#  '6LACK',
#  'Dru Hill',
#  'The G-Clefs',
#  'Jessie J',
#  'Bananarama',
#  'Carl Dobkins',
#  'The Blackbyrds',
#  'a-ha',
#  'The Deele',
#  'The Drifters',
#  'Julie Rogers',
#  'Michael W. Smith',
#  "Somethin' For The People",
#  'U.S. Bonds',
#  'Ylvis',
#  'Jim Jones',
#  'Blxst',
#  'Paul Petersen',
#  'Rihanna',
#  'Chic',
#  'Gladys Knight And The Pips',
#  'Zayn',
#  'M.I.A.',
#  'Terry Jacks',
#  'The Silver Bullet Band',
#  'Sylk-E. Fyne',
#  'Johnny Nash',
#  'Donny Hathaway',
#  "Danny O'Keefe",
#  'Bruce Willis',
#  'Daniel Powter',
#  "Force M.D.'s",
#  'Dionne',
#  'The Lettermen',
#  'Prince And The Revolution',
#  'Hozier',
#  'The Beaver Brown Band',
#  'Monifah',
#  'Dawn',
#  'CeCe Winans',
#  'Gallery',
#  'Pretenders',
#  'Miss Toni Fisher',
#  'The Detroit Guitar Band',
#  'Sam The Sham and the Pharaohs',
#  'Ritchie Valens',
#  'Charlie Rich',
#  'Jerry Butler',
#  'The Steve Miller Band',
#  'The Dominos',
#  'Ruben Studdard',
#  'DJ Frank E',
#  'Hayley Williams',
#  'Little Stevie Wonder',
#  'Domino',
#  'Craig David',
#  'The Friends Of Distinction',
#  'Salt-N-Pepa',
#  'Foxes',
#  'Q-Tip',
#  'Lisa Stansfield',
#  'Ronnie Milsap',
#  'French Montana Or Too $hort Or Tyga',
#  'Walter Murphy',
#  'Tove Lo',
#  'Deon Estus With George Michael',
#  '10cc',
#  'Jay Ferguson',
#  'Derek',
#  'Guy Mitchell',
#  'Bellamy Brothers',
#  'The Georgia Satellites',
#  'El DeBarge',
#  'Peter Cetera With Amy Grant',
#  'The Pointer Sisters',
#  'Nirvana',
#  'Kicking',
#  'Doris Troy',
#  'The Outsiders',
#  'Spice Girls',
#  'Ray',
#  'The Funky Bunch',
#  'Jimmy Harnen With Synch',
#  'Heatwave',
#  'The Ray Charles Singers',
#  'Josey Scott',
#  'Envyi',
#  'The Association',
#  'The Monkees',
#  'OMI',
#  'PSY',
#  'fun.',
#  'David Ruffin',
#  'Immature',
#  'Jigsaw',
#  'The Chi-lites',
#  'Roberta Flack With Maxi Priest',
#  'Della Reese',
#  'Stan Getz',
#  'The Ides Of March',
#  'Kings Of Leon',
#  'The All Stars',
#  'The Lumineers',
#  'Stevie Nicks With Don Henley',
#  'Michael McDonald',
#  'Smash Mouth',
#  'Debarge',
#  'Kansas',
#  'Wink Martindale',
#  'The 5 Stairsteps',
#  'Gerardo',
#  'Lil Kim',
#  'Vinz',
#  'Zayion McCall',
#  'Bonnie Tyler',
#  'Green Day',
#  'Richard Harris',
#  'Bill Pursell',
#  'The Tymes',
#  'Edison Lighthouse',
#  'Jane Child',
#  'Sam',
#  'Ketty Lester',
#  'Arthur Conley',
#  'Sheila E.',
#  'Morray',
#  'Jim Messina',
#  'Bobby Fuller Four',
#  'Michael Damian',
#  'Count Five',
#  'Nate Dogg',
#  'Sam Cooke',
#  'Madonna',
#  'Lee Michaels',
#  'Joan Osborne',
#  'Jon Bon Jovi',
#  "Chris Barber's Jazz Band",
#  'The Jelly Beans',
#  'Taylor Dayne',
#  'Carly Rae Jepsen',
#  'Curtis Mayfield',
#  'Tommy Page',
#  'Arizona Zervas',
#  'Lindsey Buckingham',
#  'Willy William',
#  'America',
#  'Frankie Avalon',
#  'Staind',
#  'Rex Smith',
#  'Dave Edmunds',
#  'Fridayy',
#  'Nicolette Larson',
#  'A$AP Rocky',
#  'Crazy Town',
#  'Rascal Flatts',
#  'Goodman',
#  'Young M.C.',
#  'Bo Bice',
#  'Frank Sinatra',
#  'James Darren',
#  'The Olympics',
#  'Merrilee Rush',
#  'Jr. Walker',
#  'Lloyd Banks',
#  'YG',
#  'Blu Cantrell',
#  'Greg Kihn Band',
#  'Sammie',
#  'The Zombies',
#  'Bobby Helms',
#  'Paul McCartney And Michael Jackson',
#  'Wild Cherry',
#  'Daughtry',
#  'Peter Mccann',
#  'The Fireballs',
#  'Gym Class Heroes',
#  'Mariah Carey',
#  'Edward Bear',
#  'Frankie Goes To Hollywood',
#  'The Orlons',
#  'Billy Ocean',
#  'Joe Esposito',
#  'Pretty Poison',
#  'Richard Chamberlain',
#  'Evans',
#  'Lenny Kravitz',
#  'Alex Clare',
#  'The Mindbenders',
#  'Childish Gambino',
#  'The Turtles',
#  'Andrea True Connection',
#  'Sergio Mendes',
#  'The Main Ingredient',
#  'The Irish Rovers',
#  'Clarence Carter',
#  'Cast',
#  'Jay',
#  'The Product G',
#  'Byron MacGregor',
#  'Kardinal Offishall',
#  'Walter Egan',
#  '702',
#  'Eddie Cochran',
#  'Meek Mill',
#  'Gwen McCrae',
#  'The Breakfast Club',
#  'David Bowie',
#  'Bill Anderson',
#  'Freddy Fender',
#  'Evanescence',
#  'Metallica',
#  'The Range',
#  'Sara Bareilles',
#  'The Mamas',
#  'Amanda Reifer',
#  'Steve Lacy',
#  'Vic Dana',
#  'Tommy Edwards',
#  'Bobby Caldwell',
#  'Ray Peterson',
#  'Jimmy Ruffin',
#  'Oliver',
#  'Firefall',
#  'Nelly',
#  'Wham!',
#  'John Lennon',
#  'Alice Cooper',
#  'Irv Gotti Presents The Inc.',
#  'Johnny Bristol',
#  'Jay And The Techniques',
#  'Fetty Wap',
#  'Miami Sound Machine',
#  'Sade',
#  "Alan O'Day",
#  'Sam Smith',
#  'John Cougar Mellencamp',
#  'Kelly Price',
#  'Grey',
#  'Red Hot Chili Peppers',
#  'Stephanie Mills',
#  'Dennis Yost',
#  'The B-52s',
#  'The Verve Pipe',
#  'Adam Lambert',
#  'Jimmy Dean',
#  'Lil Peanut',
#  'John Fogerty',
#  'Hot Chocolate',
#  'The Sanford',
#  'Chante Moore',
#  'Stealers Wheel',
#  'Erykah Badu',
#  'Adassa',
#  '50 Cent',
#  'Del Amitri',
#  'Billy Vera',
#  'Dionne Farris',
#  'Ruby And The Romantics',
#  "Dexy's Midnight Runners",
#  'Jackson Browne',
#  'Lloyd Price and His Orchestra',
#  'Eddie Murphy',
#  'Calvin Harris',
#  'Russell Thompkins',
#  'Tweet',
#  'Dennis DeYoung',
#  'Yael Naim',
#  'The Chainsmokers',
#  'Steppenwolf',
#  'En Vogue',
#  'B.W. Stevenson',
#  'We Five',
#  'Paper Lace',
#  'H-Town',
#  'Rob Thomas',
#  'Helen Reddy',
#  'Train',
#  'The Spinners',
#  'Lisa Lisa And Cult Jam With Full Force',
#  'Mikky Ekko',
#  'Eurythmics',
#  'Claude King',
#  'Tara Kemp',
#  'Xscape',
#  'Victor Lundberg',
#  'Cheap Trick',
#  'Jeanne Black',
#  'Johnny Kemp',
#  'D12',
#  'Simple Minds',
#  'Air Supply',
#  'Keith Sweat',
#  'Remy Boyz',
#  'O-Town',
#  'Go West',
#  'Cassidy',
#  'Run-D.M.C.',
#  'Akon',
#  'Snow Patrol',
#  'Creedence Clearwater Revival',
#  'The Searchers',
#  'Boyz II Men',
#  'The Buckinghams',
#  'Nicky Youre',
#  'Bobby Day',
#  'Shirley Ellis',
#  'Sabi',
#  'The Vandellas',
#  'Levert',
#  'Austin Roberts',
#  'Sweet Sensation',
#  'WizKid',
#  'Mick Jagger',
#  'Cathy Dennis',
#  'Mark Lindsay',
#  'Paul Simon (with The Dixie Hummingbirds)',
#  'Paul Evans',
#  'Big Sean',
#  'Fine Young Cannibals',
#  'Bob Seger',
#  'The Americans',
#  'Kenny Loggins',
#  'Earth',
#  'Crowded House',
#  'B.T. Express',
#  'Nick Lachey',
#  'Snoop Doggy Dogg',
#  'The Tijuana Brass',
#  'Bent Fabric and His Piano',
#  'Silver Convention',
#  'Eric Weissberg',
#  'High School Musical 2 Cast',
#  'Loon',
#  'U2',
#  'Kodak Black',
#  'Dean Martin',
#  'Alicia Bridges',
#  'Rozes',
#  'Percy Faith And His Orchestra',
#  'Static Major',
#  'Wendy Fraser)',
#  'Ariana Grande Feat. Doja Cat',
#  'Paul Mauriat And His Orchestra',
#  'Emilio Pericoli',
#  'Jesus Jones',
#  'The Impalas',
#  'Mary J. Blige',
#  'Roberta Flack With Donny Hathaway',
#  'Co.',
#  'Skrillex',
#  'Argent',
#  'Busta Rhymes',
#  'Phoebe Snow',
#  'Sweat',
#  'David Cassidy',
#  'Jody Watley',
#  'Shop Boyz',
#  'Rockwell',
#  'David Guetta',
#  'Kool',
#  'Edie Brickell',
#  'Royal Philharmonic Orchestra',
#  'Gale Garnett',
#  'Pebbles',
#  'Post Malone',
#  'Major Harris',
#  'INXS',
#  'Wreckx-N-Effect',
#  'the "Sound of Frankie Valli"',
#  'Quiet Riot',
#  'Luther Vandross',
#  'Fat Man Scoop',
#  'Thomas Dolby',
#  'Bonnie Raitt',
#  'Paul McCartney',
#  'Shep And The Limelites',
#  'Dave Loggins',
#  'Elvis Presley',
#  'Joe Cocker And Jennifer Warnes',
#  'Roxette',
#  'Enya',
#  'The Hues Corporation',
#  'Dr. Hook And The Medicine Show',
#  'Daddy Yankee',
#  'Mark Morrison',
#  '42 Dugg',
#  'Friend And Lover',
#  'Jr. with The Mike Curb Congregation',
#  ...]

# %%
[a for a in all_artists if ' And ' in a]
# Out:
# ['Van McCoy And The Soul City Symphony',
#  'Gary Lewis And The Playboys',
#  'Mike Reno And Ann Wilson',
#  'Hank Ballard And The Midnighters',
#  'James Brown And The Famous Flames',
#  'Kenny Rogers And Sheena Easton',
#  'Michael Jackson And Paul McCartney',
#  'Prince And The N.P.G.',
#  'Peter And Gordon',
#  'John Fred And The Playboys',
#  'Usher And Alicia Keys',
#  'Celine Dion And Peabo Bryson',
#  'Mitch Ryder And The Detroit Wheels',
#  'Ronny And The Daytonas',
#  'Johnny And The Hurricanes',
#  'Harold Melvin And The Blue Notes',
#  'Bo Donaldson And The Heywoods',
#  'Gladys Knight And The Pips',
#  'Prince And The Revolution',
#  'Paul McCartney And Michael Jackson',
#  'Jay And The Techniques',
#  'Ruby And The Romantics',
#  'Lisa Lisa And Cult Jam With Full Force',
#  'Percy Faith And His Orchestra',
#  'Paul Mauriat And His Orchestra',
#  'Shep And The Limelites',
#  'Joe Cocker And Jennifer Warnes',
#  'Dr. Hook And The Medicine Show',
#  'Friend And Lover',
#  'Roy Head And The Traits',
#  'Duane Eddy And The Rebels',
#  'Lisa Lisa And Cult Jam',
#  'Duane Eddy His Twangy Guitar And The Rebels',
#  'Perez Prado And His Orchestra',
#  'Eric Clapton And His Band',
#  'Tom Petty And The Heartbreakers',
#  'Louis Armstrong And The All Stars',
#  'Mel And Tim',
#  'Gerry And The Pacemakers',
#  'Bert Kaempfert And His Orchestra',
#  'Little Anthony And The Imperials',
#  'Ray Conniff And The Singers',
#  'Brewer And Shipley',
#  'Lawrence Welk And His Orchestra',
#  'B.J. Thomas And The Triumphs',
#  'Rick Nelson And The Stone Canyon Band',
#  'The Jive Five With Joe Rene And Orchestra',
#  'Prince And The New Power Generation',
#  'Gary Puckett And The Union Gap',
#  'Bobby "Boris" Pickett And The Crypt-Kickers',
#  'Lonnie Donegan And His Skiffle Group',
#  'Roy Orbison And The Candy Men',
#  'Tommy James And The Shondells',
#  'Ollie And Jerry',
#  'Jimmy Clanton And His Rockets',
#  'Stevie Nicks With Tom Petty And The Heartbreakers',
#  'His Orchestra And Chorus',
#  'Ian Whitcomb And Bluesville',
#  'Luther Vandross And Janet Jackson With BBD And Ralph Tresvant',
#  'Julio Iglesias And Willie Nelson',
#  'Diana Ross And The Supremes',
#  'KC And The Sunshine Band',
#  'David Seville And The Chipmunks',
#  'Paul McCartney And Stevie Wonder',
#  'Eric Burdon And War',
#  'Bob B. Soxx And The Blue Jeans',
#  'Spanky And Our Gang',
#  'Henry Mancini And His Orchestra',
#  'Bobby Vee And The Strangers',
#  'Love And Rockets',
#  'Tones And I',
#  'Rosie And The Originals',
#  'Freddie And The Dreamers',
#  'K-Ci And JoJo',
#  'Katrina And The Waves',
#  'Jimmy Gilmer And The Fireballs',
#  'Paul McCartney And Wings']

# %% [markdown]
# ## B. pull from Spotify
#
# Pull my own metadata from [Spotify](https://developer.spotify.com/documentation/web-api/), using [Spotipy](https://spotipy.readthedocs.io/en/2.19.0/).
#
# ### NOTE: unfortunately Spotify doesn't (no longer?) give you genre for a given song. The best you can get is genre for the *artist*. Darn...
#
# ## 🚧 IMPROVEMENTS:
# - ⬆️ using updated artists list, refetch all, but be sure to save `artist ID` this time, in case we need it.
# - inspect artist names that didn't return results, try again with tweaks

# %%
import spotipy
import sys
from spotipy.oauth2 import SpotifyClientCredentials

# spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
#     client_id='8d5441abc3fc486fad784142cadfbeac'
# ))

# %%
def get_name_and_genres_from_spotify(name):
    try: 
        print(name)
        results = spotify.search(q='artist:' + name, type='artist')
        try:
            items = results['artists']['items']
            first_result = items[0]
        except:
            print('NO RESULTS')
            return
        return (
            name,
            first_result['name'],
            first_result['genres'],
        )
    except:
        print(F'API failed: {name}')

# %%
# get_name_and_genres_from_spotify('Rick Nelson And The Stone Canyon Band')

# %% [markdown]
# ### Actual fetch (no need to repeat)

# %%
# artist_metadata = []
# for artist_name in all_artists:
#     artist_metadata.extend(
#         [get_name_and_genres_from_spotify(artist_name)]
#     )

# artist_metadata

# %% [markdown]
# ### Save fetched metadata to disk

# %%
# len(artist_metadata)

# %%
json_file = "./data/artist_metadata.json"
# with open(json_file, "w") as outfile:
#     json.dump(artist_metadata, outfile)

# %%
artist_metadata_from_disk = None
with open(json_file, "r") as outfile:
     artist_metadata_from_disk = json.load(outfile)
        
len(artist_metadata_from_disk)
# Out:
# 2451

# %%
orig_name_col = []
found_name_col = []
genres_col = []
for i in range(len(artist_metadata_from_disk)):
    entry = artist_metadata_from_disk[i]
    if entry:
        orig_name_col.extend([entry[0]])
        found_name_col.extend([entry[1] if entry else None])
        genres_col.extend([entry[2] if (entry and len(entry[2])) else None])

df_artist_genres = pd.DataFrame({'orig_name': orig_name_col, 'found_name': found_name_col, 'genres': genres_col})
df_artist_genres
# Out:
#                        orig_name                found_name  \
# 0                  Jordan Knight             Jordan Knight
# 1                    Eddie Money               Eddie Money
# 2                        Cam'Ron                   Cam’ron
# 3                    The Hollies               The Hollies
# 4                Imagine Dragons           Imagine Dragons
# ...                          ...                       ...
# 2301                   Young Dro                 Young Dro
# 2302                 Roddy Ricch               Roddy Ricch
# 2303                Ugly Kid Joe              Ugly Kid Joe
# 2304  Gladys Knight And The Pips  Gladys Knight & The Pips
# 2305          The String-A-Longs        The String-A-Longs
#
#                                                  genres
# 0                                                  None
# 1     [album rock, classic rock, country rock, folk ...
# 2     [battle rap, east coast hip hop, gangster rap,...
# 3     [album rock, brill building pop, british invas...
# 4                                   [modern rock, rock]
# ...                                                 ...
# 2301  [atl hip hop, crunk, dirty south rap, futurist...
# 2302                           [melodic rap, rap, trap]
# 2303  [funk metal, funk rock, glam metal, hard rock,...
# 2304  [classic soul, disco, funk, motown, quiet stor...
# 2305                                       [surf music]
#
# [2306 rows x 3 columns]

# %%
df_artist_genres[
#     df_artist_genres.orig_name == 'Mariah Carey'
    df_artist_genres.orig_name == df_artist_genres.found_name
#     df_artist_genres.found_name == 'Mariah Carey'
]
# Out:
#                orig_name          found_name  \
# 0          Jordan Knight       Jordan Knight
# 1            Eddie Money         Eddie Money
# 3            The Hollies         The Hollies
# 4        Imagine Dragons     Imagine Dragons
# 5           Jon Bon Jovi        Jon Bon Jovi
# ...                  ...                 ...
# 2299       Danny O'Keefe       Danny O'Keefe
# 2301           Young Dro           Young Dro
# 2302         Roddy Ricch         Roddy Ricch
# 2303        Ugly Kid Joe        Ugly Kid Joe
# 2305  The String-A-Longs  The String-A-Longs
#
#                                                  genres
# 0                                                  None
# 1     [album rock, classic rock, country rock, folk ...
# 3     [album rock, brill building pop, british invas...
# 4                                   [modern rock, rock]
# 5                               [glam metal, hard rock]
# ...                                                 ...
# 2299                  [country rock, singer-songwriter]
# 2301  [atl hip hop, crunk, dirty south rap, futurist...
# 2302                           [melodic rap, rap, trap]
# 2303  [funk metal, funk rock, glam metal, hard rock,...
# 2305                                       [surf music]
#
# [1768 rows x 3 columns]

# %% [markdown]
# #### Notable: spotify found some more "official names" from our (imperfect) attempt at splitting out names:

# %%
df_artist_genres[
    (df_artist_genres.orig_name.str.lower() != df_artist_genres.found_name.str.lower()) &
    df_artist_genres.found_name.notna()
]
# Out:
#                              orig_name                     found_name  \
# 2                              Cam'Ron                        Cam’ron
# 6                                 Loon                          LOONA
# 8                                 Rome                   Romeo Santos
# 12                            Dr. Dre)                        Dr. Dre
# 16                             'N Sync                         *NSYNC
# ...                                ...                            ...
# 2287         Johnny And The Hurricanes        Johnny & The Hurricanes
# 2288                            Climax              Climax Blues Band
# 2292  Billy J. Kramer With The Dakotas  Billy J. Kramer & The Dakotas
# 2300                              Sole                        Solence
# 2304        Gladys Knight And The Pips       Gladys Knight & The Pips
#
#                                                  genres
# 2     [battle rap, east coast hip hop, gangster rap,...
# 6                             [k-pop, k-pop girl group]
# 8                                             [bachata]
# 12    [g funk, gangster rap, hip hop, rap, west coas...
# 16                 [boy band, dance pop, post-teen pop]
# ...                                                 ...
# 2287  [brill building pop, merseybeat, rock-and-roll...
# 2288  [blues rock, british blues, classic rock, coun...
# 2292                                       [merseybeat]
# 2300                                     [post-screamo]
# 2304  [classic soul, disco, funk, motown, quiet stor...
#
# [497 rows x 3 columns]

# %% [markdown]
# # 3. Merge genre into the dataset
#
# ## THE CHALLENGE OF WORKING WITH ARTSITS IN THIS DATASET:
#
# *Ideal world*: we're given data with an ARRAY of performers for each song. We can just get metadata about each.
#
# *Real world*: `performers` col has just strings, with (sometimes) multiple artist in them, seperated by stuff like `","` or `"&"` or `" and "` (and sometimes `" and "` is just part of the performer name!!)
#
# *My current chosen path forward*:
#
# 1. try splitting stuff into individual names as best as I can (imperfect method)
# 2. try fetching genres for those names (imperfect: some don't have genres, some aren't properly split into individual names from step 1)
# 3. re-assign genre to the original dataset.
# 4. PROBLEM: we have ~500 genres to chose. *ideal approach* is to tag every single genre to a meta genre (likely `pop, rock, jazz, hip hop, country/folk, electornic, latin` and the `misc` for things that can't be shoved into those bins well). *solution I'm going to go with now*: I'll shove them into some rough categories based on *sub-string* match (imperfect, I know), & just one of the original genre if I can't make it work.
#
# ## 🚧  IMPROVEMENTS: tag every single genre to a meta genre (eg `pop, rock, jazz, hip hop, country/folk, electornic, latin`) by hand, with the help of basically trying to keyword search to make things faster.

# %%
genre_list = []
def merge_genres(genres):
    genres and genre_list.extend(genres)
    
df_artist_genres.genres.apply(lambda genres: merge_genres(genres))
all_genres = list(set(genre_list))
all_genres
# Out:
# ['scottish new wave',
#  'pub rock',
#  'second line',
#  'american folk revival',
#  'tennessee hip hop',
#  'country',
#  'instrumental funk',
#  'pixie',
#  'pop emo',
#  'sierreno',
#  'acoustic blues',
#  'italian adult pop',
#  'indietronica',
#  'riddim',
#  'gauze pop',
#  'quiet storm',
#  'classic rock',
#  'rockabilly',
#  'philly rap',
#  'truck-driving country',
#  'alt z',
#  'jazz drums',
#  'chicago bop',
#  'hip pop',
#  'classical performance',
#  'socal pop punk',
#  'country rap',
#  'steampunk',
#  'modern blues rock',
#  'rap metal',
#  'west coast rap',
#  'underground power pop',
#  'german hard rock',
#  'classic dubstep',
#  'parody',
#  'nederpop',
#  'rap kreyol',
#  'north carolina hip hop',
#  'texas blues',
#  'uk contemporary r&b',
#  'screamo',
#  'conscious hip hop',
#  'retro soul',
#  'pop house',
#  'kiwi rock',
#  'psychedelic folk',
#  'post-disco',
#  'texas country',
#  'candy pop',
#  'ohio hip hop',
#  'christian indie',
#  'musica mexicana',
#  'sad sierreno',
#  'classic italian pop',
#  'irish rock',
#  'classic canadian rock',
#  'indie poptimism',
#  'hi-nrg',
#  'idol',
#  'free jazz',
#  'french dnb',
#  'austropop',
#  'melbourne bounce international',
#  'trap',
#  'pinoy hip hop',
#  'metal',
#  'mellow gold',
#  'liquid funk',
#  'neo-psychedelic',
#  'hindi hip hop',
#  'pop edm',
#  'hip hop',
#  'classic soul',
#  'colombian pop',
#  'memphis soul',
#  'country pop',
#  'arkansas country',
#  "preschool children's music",
#  'southern soul',
#  'world worship',
#  'lovers rock',
#  'smooth jazz',
#  'boy band',
#  'early reggae',
#  'country dawn',
#  'salsa',
#  'minneapolis sound',
#  'maine indie',
#  'neoperreo',
#  'modern rock',
#  'sophisti-pop',
#  'outlaw country',
#  'swamp rock',
#  'guyanese pop',
#  'deep talent show',
#  'harmonica blues',
#  'lo-fi brasileiro',
#  'chicago drill',
#  'afropop',
#  'barbadian pop',
#  'american oi',
#  'popping',
#  'australian country',
#  'pop dance',
#  'alternative country',
#  'brazilian jazz',
#  'rap conscient',
#  'orchestral performance',
#  'melodic rap',
#  'k-rap',
#  'background piano',
#  'northern soul',
#  'pittsburgh rap',
#  'big room',
#  'bachata',
#  'christian a cappella',
#  'classic uk pop',
#  'puerto rican pop',
#  'neon pop punk',
#  'speedrun',
#  'country rock',
#  'south african jazz',
#  'reggaeton colombiano',
#  'nashville sound',
#  'yodeling',
#  'piano blues',
#  'transpop',
#  'mexican pop',
#  'hip house',
#  'grebo',
#  'reggaeton flow',
#  'pop reggaeton',
#  'emo',
#  'glam metal',
#  'rap rock',
#  'samba-jazz',
#  'canadian metal',
#  'desi hip hop',
#  "children's music",
#  'soul jazz',
#  'uk dnb',
#  'nu jazz',
#  'swedish synthpop',
#  'jazz organ',
#  'neo mellow',
#  'progressive rock',
#  'diva house',
#  'mexican classic rock',
#  'redneck',
#  'new wave',
#  'ectofolk',
#  'progressive house',
#  'cool jazz',
#  'protopunk',
#  'cancion melodica',
#  'dancehall queen',
#  'disco',
#  'honky tonk',
#  'metropopolis',
#  'classic swedish pop',
#  'florida rap',
#  'r&b en espanol',
#  'manchester hip hop',
#  'desi trap',
#  'pop rap',
#  'deep groove house',
#  'jawaiian',
#  'pop rock',
#  'instrumental surf',
#  'classic girl group',
#  'boston rock',
#  'old school thrash',
#  'old school hip hop',
#  'lilith',
#  "children's story",
#  'pop venezolano',
#  'drum and bass',
#  'houston rap',
#  'souldies',
#  'bluegrass',
#  'old school atlanta hip hop',
#  'post-punk',
#  'worship',
#  'freestyle',
#  'lgbtq+ hip hop',
#  'us power metal',
#  'contemporary post-bop',
#  'cosmic american',
#  'british invasion',
#  'filter house',
#  'neue deutsche welle',
#  'latin viral pop',
#  'new romantic',
#  'synthpop',
#  'nueva musica mexicana',
#  'battle rap',
#  'new jersey rap',
#  'sunshine pop',
#  'latin jazz',
#  'bolero',
#  'electronic trap',
#  'new orleans funk',
#  'jangle pop',
#  'detroit rock',
#  'rare groove',
#  'modern alternative rock',
#  'deep house',
#  'minnesota hip hop',
#  'funk rock',
#  'canadian pop',
#  'indie pop rap',
#  'melancholia',
#  'cali rap',
#  'british blues',
#  'modern power pop',
#  'skiffle',
#  'instrumental soul',
#  'sacramento indie',
#  'thrash metal',
#  'k-pop',
#  'shanty',
#  'nz pop',
#  'fourth world',
#  'portland hip hop',
#  'ccm',
#  'oklahoma country',
#  'christian music',
#  'movie tunes',
#  'novelty',
#  'australian pop',
#  'swing revival',
#  'afrobeat',
#  'german orchestra',
#  'modern salsa',
#  'alternative rock',
#  'reggae fusion',
#  'glam punk',
#  'post-grunge',
#  'deep motown',
#  'jazz fusion',
#  'trap queen',
#  'show tunes',
#  'bedroom soul',
#  'soul',
#  'korean old school hip hop',
#  'rock-and-roll',
#  'uk dance',
#  'middle earth',
#  'classic country pop',
#  'canadian rock',
#  'southern rock',
#  'dub',
#  'dmv rap',
#  'dutch prog',
#  'folk',
#  'tempe indie',
#  'focus beats',
#  'zolo',
#  'harlem hip hop',
#  'disney',
#  'bassline',
#  'delta blues',
#  'comedy',
#  'folk-pop',
#  'canadian indie',
#  'ska revival',
#  'street band',
#  'deep classic garage rock',
#  'indonesian hip hop',
#  'stride',
#  'punk blues',
#  'canadian latin',
#  'britpop',
#  'dutch house',
#  'tropical',
#  'deep dance pop',
#  'swing',
#  'jazz rap',
#  'east coast hip hop',
#  'kindie rock',
#  'banda',
#  'deep southern trap',
#  'lullaby',
#  'glam rock',
#  'sleaze rock',
#  'jazz trumpet',
#  'dream pop',
#  'tierra caliente',
#  'escape room',
#  'indie folk',
#  'bow pop',
#  'toronto rap',
#  'athens indie',
#  'australian rock',
#  'psychedelic folk rock',
#  'canadian celtic',
#  'vapor twitch',
#  'house',
#  'r&b argentino',
#  'french indie pop',
#  'dfw rap',
#  'sad lo-fi',
#  'harlem renaissance',
#  'pop punk',
#  'synthesizer',
#  'dancehall',
#  'indie r&b',
#  'neo classical metal',
#  'hard bop',
#  'old school dancehall',
#  'melbourne bounce',
#  'nursery',
#  'psychedelic rock',
#  'talent show',
#  'swamp blues',
#  'gothic rock',
#  'electro house',
#  'post-teen pop',
#  'boston hip hop',
#  'new orleans rap',
#  'freak folk',
#  'wu fam',
#  'seattle hip hop',
#  'electropowerpop',
#  'anarcho-punk',
#  'emo rap',
#  'contemporary r&b',
#  'jamaican hip hop',
#  'stomp and holler',
#  'cowpunk',
#  'art pop',
#  'nu metal',
#  'electro',
#  'blues rock',
#  'louisiana blues',
#  'folk rock',
#  'progressive electro house',
#  'indie pop',
#  'ambient folk',
#  'italo dance',
#  'nwobhm',
#  'comic',
#  'singer-songwriter',
#  'london rap',
#  'merseybeat',
#  'new england americana',
#  'jamaican ska',
#  'space age pop',
#  'gangster rap',
#  'hard rock',
#  'atlanta bass',
#  'christian alternative rock',
#  'compositional ambient',
#  'deep new americana',
#  'birmingham metal',
#  'scottish rock',
#  'baton rouge rap',
#  'classic house',
#  'new orleans soul',
#  'smooth saxophone',
#  'canadian trap',
#  'rock keyboard',
#  'cowboy western',
#  'mariachi cristiano',
#  'ska',
#  'deep soft rock',
#  'new americana',
#  'alternative dance',
#  'alternative r&b',
#  'deep euro house',
#  'rock',
#  'pop romantico',
#  'canadian contemporary r&b',
#  'yakut pop',
#  'enka',
#  'latin worship',
#  'reggaeton',
#  'bahamian pop',
#  'disco house',
#  'dance pop',
#  'danish electronic',
#  'roots reggae',
#  'heartland rock',
#  'traprun',
#  'psychedelic blues-rock',
#  'deep underground hip hop',
#  'flute rock',
#  'samba',
#  'latin pop',
#  'pop',
#  'futuristic swag',
#  'jump blues',
#  'slap house',
#  'rhode island rap',
#  'eau claire indie',
#  'underground hip hop',
#  'classic soundtrack',
#  'nigerian pop',
#  'new beat',
#  'canadian singer-songwriter',
#  'acoustic pop',
#  'madchester',
#  'virginia hip hop',
#  'uk reggae',
#  'banjo',
#  'uk pop',
#  'proto-metal',
#  'dirty south rap',
#  'symphonic rock',
#  'jazz piano',
#  'brass band',
#  'philly soul',
#  'oakland hip hop',
#  'chopped and screwed',
#  'australian electropop',
#  'jazz funk',
#  'canadian psychedelic',
#  'post-screamo',
#  'german rock',
#  'acid house',
#  'r&b',
#  'choral',
#  'viral rap',
#  'vincy soca',
#  'doo-wop',
#  'edm',
#  'reggae',
#  'corridos tumbados',
#  'norteno-sax',
#  'jazz blues',
#  'urban contemporary',
#  'detroit hip hop',
#  'british orchestra',
#  "women's music",
#  'paisley underground',
#  'lo-fi product',
#  'punk',
#  'ambient house',
#  'trap soul',
#  'german techno',
#  'ranchera',
#  'michigan indie',
#  'bossa nova',
#  'uk funky',
#  'supergroup',
#  'brostep',
#  'austin singer-songwriter',
#  'crunk',
#  'chillwave',
#  'avant-garde jazz',
#  'asian american hip hop',
#  'alabama rap',
#  'chicago soul',
#  'queens hip hop',
#  'electropop',
#  'honky-tonk piano',
#  'modern blues',
#  'blues',
#  'progressive bluegrass',
#  'chicago rap',
#  'cyberpunk',
#  'bubblegum dance',
#  'azonto',
#  'alternative metal',
#  'viral pop',
#  'jazz saxophone',
#  'jazz',
#  'psychedelic soul',
#  'dansktop',
#  'australian alternative rock',
#  'pluggnb',
#  'salsa colombiana',
#  'etherpop',
#  'deep adult standards',
#  'danish pop',
#  'german pop',
#  'italo house',
#  'st louis rap',
#  'complextro',
#  'trip hop',
#  'psychedelic pop',
#  'memphis hip hop',
#  'ballroom',
#  'argentine hip hop',
#  'lds youth',
#  'brit funk',
#  'electronica',
#  'native american contemporary',
#  'k-pop girl group',
#  'world',
#  'corrido',
#  'seattle indie',
#  'garage rock',
#  'francoton',
#  'indiecoustica',
#  'alte',
#  'bounce',
#  'chicago blues',
#  'rock of gibraltar',
#  'neo soul',
#  'belgian singer-songwriter',
#  'bubblegum pop',
#  'hard minimal techno',
#  'nigerian hip hop',
#  'bebop',
#  'latin funk',
#  'mississippi hip hop',
#  'jazz trombone',
#  'afro r&b',
#  'canadian hip hop',
#  'australian indie',
#  'drill',
#  'modern alternative pop',
#  "children's folk",
#  'contemporary vocal jazz',
#  'nyc rap',
#  'brill building pop',
#  'celtic',
#  'canadian blues',
#  'double drumming',
#  'atl hip hop',
#  'sad rap',
#  'swedish electropop',
#  'rhythm and blues',
#  'contemporary country',
#  'afrofuturism',
#  'traditional blues',
#  'trap latino',
#  'neo-classical',
#  'theme',
#  'british soul',
#  'norteno',
#  'electric blues',
#  "man's orchestra",
#  'permanent wave',
#  'atl trap',
#  'plugg',
#  'nashville indie',
#  'synth funk',
#  'new orleans blues',
#  'moombahton',
#  'latin hip hop',
#  'exotica',
#  'chicano punk',
#  'roots rock',
#  'comedy rock',
#  'baroque pop',
#  'pop r&b',
#  'swedish hard rock',
#  'german soundtrack',
#  'australian r&b',
#  'tropical house',
#  'light music',
#  'irish pub song',
#  'modern reggae',
#  'irish singer-songwriter',
#  'dancefloor dnb',
#  'country gospel',
#  'shiver pop',
#  'jamgrass',
#  'latin christian',
#  'big band',
#  'neo-synthpop',
#  'easy listening',
#  'soft rock',
#  'afro dancehall',
#  'texas latin rap',
#  'experimental hip hop',
#  'adult standards',
#  'canadian country',
#  'traditional country',
#  'vapor trap',
#  'german dance',
#  'italian disco',
#  'progressive metal',
#  'jazz guitar',
#  'classic australian country',
#  'freakbeat',
#  'g funk',
#  'golden age hip hop',
#  'irish folk',
#  'trap argentino',
#  'trancecore',
#  'native american',
#  'boogie',
#  'south carolina hip hop',
#  'classic garage rock',
#  'modern country rock',
#  'funk',
#  'soca',
#  'synthwave',
#  'eurodance',
#  'dixieland',
#  'thai pop',
#  'art rock',
#  'swedish melodic rock',
#  'british folk',
#  'beach music',
#  'vocal harmony group',
#  'kentucky hip hop',
#  'celtic rock',
#  'rap',
#  'comedy rap',
#  'girl group',
#  'rap latina',
#  'indie soul',
#  'new rave',
#  'contemporary jazz',
#  'indie rock',
#  'vocal house',
#  'broadway',
#  'soul blues',
#  'a cappella',
#  'scandipop',
#  'bronx hip hop',
#  'gospel',
#  'scottish singer-songwriter',
#  'canadian old school hip hop',
#  'southern hip hop',
#  'hollywood',
#  'miami bass',
#  'gospel r&b',
#  'hardcore hip hop',
#  'dance rock',
#  'swing italiano',
#  'detroit trap',
#  'black comedy',
#  'miami hip hop',
#  'rocksteady',
#  'country road',
#  'acid rock',
#  'musical advocacy',
#  'german metal',
#  'swamp pop',
#  'dutch rock',
#  'new jack swing',
#  'pacific islands pop',
#  'new age piano',
#  'funk metal',
#  'grunge',
#  'japanese jazz',
#  'new wave pop',
#  'new mexico music',
#  'memphis blues',
#  'alternative hip hop',
#  'chicano rap',
#  'beatlesque',
#  'bass trap',
#  'motown',
#  'video game music',
#  'surf music',
#  'australian hip hop',
#  'political hip hop',
#  'mambo',
#  'vocal jazz',
#  'lounge',
#  'uk post-punk',
#  'piano rock',
#  'yacht rock',
#  'pop soul',
#  'new age',
#  'orchestra',
#  'bboy',
#  'mariachi',
#  'australian dance',
#  'album rock',
#  'torch song',
#  'hammond organ',
#  'k-pop boy group',
#  'brooklyn drill',
#  'hyphy',
#  'viral trap',
#  'europop',
#  'art punk',
#  'bergen indie',
#  'power pop',
#  'rock drums',
#  'glee club',
#  'bossa nova jazz',
#  'new orleans jazz',
#  'chamber pop',
#  'swedish pop',
#  'jam band']

# %%
pd.Series(all_genres).describe()
# Out:
# count                   683
# unique                  683
# top       scottish new wave
# freq                      1
# dtype: object

# %%
POP = [
    'hip pop',
 'classic swedish pop',
 'chamber pop',
 'metropopolis',
 'post-teen pop',
 'dance pop',
 'bahamian pop',
 'psychedelic pop',
 'thai pop',
 'underground power pop',
 'pop romantico',
 'guyanese pop',
 'nz pop',
 'britpop',
 'mexican pop',
 'europop',
 'swamp pop',
 'german pop',
 'neo-synthpop',
 'italian adult pop',
 'sophisti-pop',
 'popping',
 'power pop',
 'synthpop',
 'deep dance pop',
 'transpop',
 'uk pop',
 'pop punk',
 'modern alternative pop',
 'nederpop',
 'classic uk pop',
 'swedish synthpop',
 'k-pop boy group',
 'yakut pop',
 'classic italian pop',
 'bow pop',
 'acoustic pop',
 'indie poptimism',
 'modern power pop',
 'scandipop',
 'socal pop punk',
 'brill building pop',
 'dream pop',
 'pop',
 'danish pop',
 'new wave pop',
 'indie pop',
 'baroque pop',
 'k-pop',
 'canadian pop',
 'sunshine pop',
 'jangle pop',
 'pop dance',
 'swedish pop',
 'puerto rican pop',
 'neon pop punk',
 'afropop',
 'etherpop',
 'candy pop',
 'pop r&b',
 'space age pop',
 'french indie pop',
 'viral pop',
 'pacific islands pop',
 'shiver pop',
 'pop soul',
 'pop emo',
 'art pop',
 'austropop',
 'gauze pop',
 'colombian pop',
 'k-pop girl group',
 'australian pop',
 'nigerian pop',
 'bubblegum pop',
 'barbadian pop',
]
ROCK = [
    'progressive rock',
 'christian alternative rock',
 'comedy rock',
 'rock',
 'classic garage rock',
 'psychedelic rock',
 'rock drums',
 'classic rock',
 'boston rock',
 'canadian rock',
 'detroit rock',
 'pub rock',
 'rock keyboard',
 'piano rock',
 'irish rock',
 'rock of gibraltar',
 'art rock',
 'pop rock',
 'roots rock',
 'australian rock',
 'alternative rock',
 'german rock',
 'yacht rock',
 'soft rock',
 'swedish hard rock',
 'swamp rock',
 'deep soft rock',
 'rock-and-roll',
 'hard rock',
 'mexican classic rock',
 'dance rock',
 'rockabilly',
 'swedish melodic rock',
 'garage rock',
 'modern alternative rock',
 'flute rock',
 'kindie rock',
 'rocksteady',
 'indie rock',
 'southern rock',
 'acid rock',
 'german hard rock',
 'sleaze rock',
 'album rock',
 'gothic rock',
 'modern rock',
 'deep classic garage rock',
 'lovers rock',
 'glam rock',
 'scottish rock',
 'dutch rock',
 'classic canadian rock',
 'heartland rock',
 'kiwi rock',
 'celtic rock',
 'symphonic rock',
 'australian alternative rock',
    # indie
 'michigan indie',
 'athens indie',
 'indiecoustica',
 'maine indie',
 'bergen indie',
 'nashville indie',
 'australian indie',
 'canadian indie',
 'eau claire indie',
 'christian indie',
 'tempe indie',
 'sacramento indie',
 'seattle indie',
    # punk
 'uk post-punk',
 'protopunk',
 'anarcho-punk',
 'post-punk',
 'cyberpunk',
 'steampunk',
 'art punk',
 'chicano punk',
 'glam punk',
 'punk',
    # metal
 'progressive metal',
 'alternative metal',
 'glam metal',
 'canadian metal',
 'neo classical metal',
 'birmingham metal',
 'nu metal',
 'us power metal',
 'thrash metal',
 'proto-metal',
 'german metal',
 'metal',
    
 'british invasion',
]
LATIN = [
   'latin worship',
 'latin christian',
 'latin pop',
 'canadian latin',
 'latin viral pop',
    # reggeaton
    'pop reggaeton',
 'reggaeton flow',
 'reggaeton',
    # salsa
    'salsa', 'modern salsa', 'salsa colombiana',
    # pop
     'pop venezolano',
    
 'nueva musica mexicana', 'banda', 'norteno', 
 'tierra caliente', 'ranchera', 'samba', 'bolero', 'bachata',
]
ELECTRO = [
    # electro
    'electropowerpop',
 'electronica',
 'electro',
 'progressive electro house',
 'australian electropop',
 'danish electronic',
 'electropop',
 'electro house',
 'swedish electropop',
 'electronic trap',
    'indietronica',
    'synthesizer',
    # house
    'disco house',
 'filter house',
 'pop house',
 'classic house',
 'tropical house',
 'house',
 'dutch house',
 'ambient house',
 'progressive house',
 'hip house',
 'vocal house',
 'deep groove house',
 'diva house',
 'italo house',
 'acid house',
 'deep euro house',
 'slap house',
 'deep house',
    # dance
    'eurodance',
 'australian dance',
 'german dance',
 'italo dance',

 'alternative dance',
 'uk dance',
 'bubblegum dance',
    # disco
    'italian disco', 'post-disco', 'disco',
    # dnb
    'french dnb', 'uk dnb', 'dancefloor dnb',
    # edm
    'edm', 'pop edm',
    'dub', 'classic dubstep',
    'brostep',
    # techno
    'german techno',
    'hard minimal techno',
]
COUNTRY = [
    #country
    'classic country pop',
 'country dawn',
 'canadian country',
 'country',
 'outlaw country',
 'country gospel',
 'truck-driving country',
 'arkansas country',
 'texas country',
 'country road',
 'alternative country',
 'country pop',
 'country rock',
 'classic australian country',
 'modern country rock',
 'contemporary country',
 'country rap',
 'australian country',
 'traditional country',
 'oklahoma country',
 
 'cowpunk',
]
FOLK = [
    'american folk revival',
 "children's folk",
 'ectofolk',
 'freak folk',
 'british folk',
 'folk rock',
 'psychedelic folk rock',
 'folk-pop',
 'folk',
 'ambient folk',
 'indie folk',
 'irish folk',
 'psychedelic folk',
    'bluegrass',
    'banjo',
    # americana
    'new americana', 'deep new americana', 'new england americana',
]
HIP_HOP = [
 'canadian hip hop',
 'oakland hip hop',
 'kentucky hip hop',
 'deep underground hip hop',
 'southern hip hop',
 'canadian old school hip hop',
 'detroit hip hop',
 'hardcore hip hop',
 'miami hip hop',
 'harlem hip hop',
 'virginia hip hop',
 'lgbtq+ hip hop',
 'memphis hip hop',
 'ohio hip hop',
 'underground hip hop',
 'minnesota hip hop',
 'bronx hip hop',
 'old school atlanta hip hop',
 'alternative hip hop',
 'hip hop',
 'boston hip hop',
 'asian american hip hop',
 'north carolina hip hop',
 'seattle hip hop',
 'indonesian hip hop',
 'tennessee hip hop',
 'atl hip hop',
 'south carolina hip hop',
 'portland hip hop',
 'korean old school hip hop',
 'experimental hip hop',
 'desi hip hop',
 'latin hip hop',
 'argentine hip hop',
 'queens hip hop',
 'mississippi hip hop',
 'australian hip hop',
 'nigerian hip hop',
 'conscious hip hop',
 'east coast hip hop',
 'golden age hip hop',
 'manchester hip hop',
 'political hip hop',
 'old school hip hop',
 'hindi hip hop',
 'jamaican hip hop',
 'pinoy hip hop',
    # rap
    'dmv rap',
 'comedy rap',
 'deep southern trap',
 'pittsburgh rap',
 'trap soul',
 'trap latino',
 'dirty south rap',
 'melodic rap',
 'rhode island rap',
 'alabama rap',
 'emo rap',
 'rap kreyol',
 'desi trap',
 'rap latina',
 'indie pop rap',
 'bass trap',
 'trap queen',
 'traprun',
 'houston rap',
 'canadian trap',
 'chicano rap',
 'viral rap',
 'trap argentino',
 'st louis rap',
 'vapor trap',
 'k-rap',
 'viral trap',
 'texas latin rap',
 'rap conscient',
 'gangster rap',
 'philly rap',
 'trap',
 'dfw rap',
 'cali rap',
 'west coast rap',
 'atl trap',
 'new jersey rap',
 'rap metal',
 'battle rap',
 'rap',
 'sad rap',
 'detroit trap',
 'baton rouge rap',
 'new orleans rap',
 'nyc rap',
 'toronto rap',
 'pop rap',
 'florida rap',
 'chicago rap',
 'rap rock',
 'london rap',
    'chicago bop',
    
    'afro dancehall',
]
JAZZ_INFLUENCED = [
    # jazz
    'cool jazz',
 'japanese jazz',
 'south african jazz',
 'jazz blues',
 'vocal jazz',
 'jazz trumpet',
 'jazz saxophone',
 'jazz organ',
 'latin jazz',
 'jazz funk',
 'contemporary vocal jazz',
 'samba-jazz',
 'jazz rap',
 'jazz piano',
 'new orleans jazz',
 'jazz',
 'jazz guitar',
 'brazilian jazz',
 'jazz fusion',
 'bossa nova jazz',
 'contemporary jazz',
 'jazz drums',
 'soul jazz',
 'smooth jazz',
 'free jazz',
 'jazz trombone',
 'nu jazz',
 'avant-garde jazz',
 'dixieland',
    'hard bop', 'bebop', 'contemporary post-bop',
    # blues
    'memphis blues',
 'harmonica blues',
 'electric blues',
 'piano blues',
 'canadian blues',
 'chicago blues',
 'blues',
 'swamp blues',
 'soul blues',
 'traditional blues',
 'new orleans blues',
 'blues rock',
 'modern blues rock',
 'psychedelic blues-rock',
 'punk blues',
 'louisiana blues',
 'modern blues',
 'acoustic blues',
 'jump blues',
 'delta blues',
 'texas blues',
 'british blues',
 'rhythm and blues',
 'deep motown', 
    # soul
 'philly soul',
 'soul',
 'retro soul',
 'bedroom soul',
 'classic soul',
 'memphis soul',
 'souldies',
 'instrumental soul',
 'new orleans soul',
 'indie soul',
 'chicago soul',
 'psychedelic soul',
 'northern soul',
 'british soul',
 'neo soul',
 'southern soul',
    # r&b
    'gospel r&b',
 'contemporary r&b',
 'canadian contemporary r&b',
 'r&b argentino',
 'r&b en espanol',
 'uk contemporary r&b',
 'afro r&b',
 'indie r&b',
 'r&b',
 'alternative r&b',
 'australian r&b',
    'afrofuturism', 'afrobeat',
    'gospel',
    # swing
    'new jack swing', 'swing revival', 'swing italiano', 'swing',
    'harlem renaissance',
    
    'bboy',
]
REGGAE = [
    # ska
    'ska',
    'jamaican ska',
    'ska revival',
    
    'modern reggae',
 'uk reggae',
 'reggae',
 'reggae fusion',
 'reggaeton colombiano',
 'early reggae',
 'roots reggae',
    # dancehall
    'old school dancehall', 'dancehall', 'dancehall queen',
    
]
FUNK = ['funk rock',
 'synth funk',
 'brit funk',
 'funk',
 'uk funky',
 'instrumental funk',
 'liquid funk',
 'latin funk',
 'g funk',
 'new orleans funk',
 'funk metal']


# MISC?
CLASSIFIED_GENRES = [*POP, *ROCK, *LATIN, *ELECTRO, *COUNTRY, *FOLK, *HIP_HOP, *JAZZ_INFLUENCED, *REGGAE, *FUNK]

unclassified_genres = [genre for genre in all_genres if genre not in CLASSIFIED_GENRES]

[genre for genre in unclassified_genres if '' in genre]
unclassified_genres
# Out:
# ['scottish new wave',
#  'second line',
#  'pixie',
#  'sierreno',
#  'riddim',
#  'quiet storm',
#  'alt z',
#  'classical performance',
#  'parody',
#  'screamo',
#  'musica mexicana',
#  'sad sierreno',
#  'hi-nrg',
#  'idol',
#  'melbourne bounce international',
#  'mellow gold',
#  'neo-psychedelic',
#  "preschool children's music",
#  'world worship',
#  'boy band',
#  'minneapolis sound',
#  'neoperreo',
#  'deep talent show',
#  'lo-fi brasileiro',
#  'chicago drill',
#  'american oi',
#  'orchestral performance',
#  'background piano',
#  'big room',
#  'christian a cappella',
#  'speedrun',
#  'nashville sound',
#  'yodeling',
#  'grebo',
#  'emo',
#  "children's music",
#  'neo mellow',
#  'redneck',
#  'new wave',
#  'cancion melodica',
#  'honky tonk',
#  'jawaiian',
#  'instrumental surf',
#  'classic girl group',
#  'old school thrash',
#  'lilith',
#  "children's story",
#  'drum and bass',
#  'worship',
#  'freestyle',
#  'cosmic american',
#  'neue deutsche welle',
#  'new romantic',
#  'rare groove',
#  'melancholia',
#  'skiffle',
#  'shanty',
#  'fourth world',
#  'ccm',
#  'christian music',
#  'movie tunes',
#  'novelty',
#  'german orchestra',
#  'post-grunge',
#  'show tunes',
#  'middle earth',
#  'dutch prog',
#  'focus beats',
#  'zolo',
#  'disney',
#  'bassline',
#  'comedy',
#  'street band',
#  'stride',
#  'tropical',
#  'lullaby',
#  'escape room',
#  'canadian celtic',
#  'vapor twitch',
#  'sad lo-fi',
#  'melbourne bounce',
#  'nursery',
#  'talent show',
#  'wu fam',
#  'stomp and holler',
#  'nwobhm',
#  'comic',
#  'singer-songwriter',
#  'merseybeat',
#  'atlanta bass',
#  'compositional ambient',
#  'smooth saxophone',
#  'cowboy western',
#  'mariachi cristiano',
#  'enka',
#  'futuristic swag',
#  'classic soundtrack',
#  'new beat',
#  'canadian singer-songwriter',
#  'madchester',
#  'brass band',
#  'chopped and screwed',
#  'canadian psychedelic',
#  'post-screamo',
#  'choral',
#  'vincy soca',
#  'doo-wop',
#  'corridos tumbados',
#  'norteno-sax',
#  'urban contemporary',
#  'british orchestra',
#  "women's music",
#  'paisley underground',
#  'lo-fi product',
#  'bossa nova',
#  'supergroup',
#  'austin singer-songwriter',
#  'crunk',
#  'chillwave',
#  'honky-tonk piano',
#  'progressive bluegrass',
#  'azonto',
#  'dansktop',
#  'pluggnb',
#  'deep adult standards',
#  'complextro',
#  'trip hop',
#  'ballroom',
#  'lds youth',
#  'native american contemporary',
#  'world',
#  'corrido',
#  'francoton',
#  'alte',
#  'bounce',
#  'belgian singer-songwriter',
#  'drill',
#  'celtic',
#  'double drumming',
#  'neo-classical',
#  'theme',
#  "man's orchestra",
#  'permanent wave',
#  'plugg',
#  'moombahton',
#  'exotica',
#  'german soundtrack',
#  'light music',
#  'irish pub song',
#  'irish singer-songwriter',
#  'jamgrass',
#  'big band',
#  'easy listening',
#  'adult standards',
#  'freakbeat',
#  'trancecore',
#  'native american',
#  'boogie',
#  'soca',
#  'synthwave',
#  'beach music',
#  'vocal harmony group',
#  'girl group',
#  'new rave',
#  'broadway',
#  'a cappella',
#  'scottish singer-songwriter',
#  'hollywood',
#  'miami bass',
#  'black comedy',
#  'musical advocacy',
#  'new age piano',
#  'grunge',
#  'new mexico music',
#  'beatlesque',
#  'motown',
#  'video game music',
#  'surf music',
#  'mambo',
#  'lounge',
#  'new age',
#  'orchestra',
#  'mariachi',
#  'torch song',
#  'hammond organ',
#  'brooklyn drill',
#  'hyphy',
#  'glee club',
#  'jam band']

# %%
GENERIC_GENRES = {
'LATIN': LATIN, 
'ELECTRO': ELECTRO, 
'COUNTRY': COUNTRY, 
'FOLK': FOLK, 
'HIP_HOP': HIP_HOP, 
'JAZZ_INFLUENCED': JAZZ_INFLUENCED, 
'REGGAE': REGGAE, 
'FUNK': FUNK, 
'POP': POP, 
'ROCK': ROCK,
'UNCATEGORIZED': unclassified_genres
}

def get_genre_category(genre):
    for generic_genre in GENERIC_GENRES.keys():
        if genre in GENERIC_GENRES[generic_genre]:
            return generic_genre

get_genre_category('deep house')
# Out:
# 'ELECTRO'

# %%
def get_the_most_generic_genre_possible(artist_array):
    if artist_array:
        match = df_artist_genres[
            df_artist_genres.orig_name == artist_array[0]
        ]
        try:
            genres = match.iloc[0].genres
            if genres:
                found_genre = get_genre_category(genres[0])
                if found_genre is 'UNCATEGORIZED':
                    found_genre = get_genre_category(genres[1])
                    if found_genre is 'UNCATEGORIZED':
                        found_genre = get_genre_category(genres[2])
                return found_genre or 'UNCATEGORIZED'
        except:
            pass
            
    return 'UNCATEGORIZED'

artist_genre_merged_in = songs_that_made_it_above_x.copy()

artist_genre_merged_in['artist_array'] =  artist_genre_merged_in.performer.apply(lambda s: get_array_of_performers(s))

artist_genre_merged_in['generic_genre'] = artist_genre_merged_in.artist_array.apply(lambda a: get_the_most_generic_genre_possible(a))

# %%
artist_genre_merged_in.generic_genre.value_counts()
# Out:
# POP                1879
# ROCK               1087
# UNCATEGORIZED       575
# JAZZ_INFLUENCED     555
# HIP_HOP             423
# ELECTRO             260
# COUNTRY             136
# FUNK                 81
# LATIN                45
# FOLK                 42
# REGGAE               11
# Name: generic_genre, dtype: int64

# %%
artist_genre_merged_in[
    artist_genre_merged_in.generic_genre.isna()
]
# Out:
# Empty DataFrame
# Columns: [song_id, chart_position, chart_debut, song, performer, artist_array, generic_genre]
# Index: []

# %%
artist_genre_merged_in
# Out:
#                                                 song_id  chart_position  \
# 0                                   #9 DreamJohn Lennon               9
# 1     '03 Bonnie & ClydeJay-Z Featuring Beyonce Knowles               4
# 2                             '65 Love AffairPaul Davis               6
# 3                ('til) I Kissed YouThe Everly Brothers               4
# 4     (Can't Live Without Your) Love And AffectionNe...               1
# ...                                                 ...             ...
# 5089                   everything i wantedBillie Eilish               8
# 5090                      iSpyKYLE Featuring Lil Yachty               4
# 5091                                   interludeJ. Cole               8
# 5092                 my.lifeJ. Cole, 21 Savage & Morray               2
# 5093               pride.is.the.devilJ. Cole & Lil Baby               7
#
#      chart_debut                                          song  \
# 0     1974-12-21                                      #9 Dream
# 1     2002-10-26                            '03 Bonnie & Clyde
# 2     1982-02-27                               '65 Love Affair
# 3     1959-08-15                           ('til) I Kissed You
# 4     1990-07-07  (Can't Live Without Your) Love And Affection
# ...          ...                                           ...
# 5089  2019-11-23                           everything i wanted
# 5090  2017-01-14                                          iSpy
# 5091  2021-05-22                                     interlude
# 5092  2021-05-29                                       my.life
# 5093  2021-05-29                            pride.is.the.devil
#
#                             performer                  artist_array  \
# 0                         John Lennon                 [John Lennon]
# 1     Jay-Z Featuring Beyonce Knowles      [Jay-Z, Beyonce Knowles]
# 2                          Paul Davis                  [Paul Davis]
# 3                 The Everly Brothers         [The Everly Brothers]
# 4                              Nelson                      [Nelson]
# ...                               ...                           ...
# 5089                    Billie Eilish               [Billie Eilish]
# 5090        KYLE Featuring Lil Yachty            [KYLE, Lil Yachty]
# 5091                          J. Cole                     [J. Cole]
# 5092      J. Cole, 21 Savage & Morray  [J. Cole, 21 Savage, Morray]
# 5093               J. Cole & Lil Baby           [J. Cole, Lil Baby]
#
#      generic_genre
# 0             ROCK
# 1          HIP_HOP
# 2             ROCK
# 3              POP
# 4          COUNTRY
# ...            ...
# 5089           POP
# 5090           POP
# 5091       HIP_HOP
# 5092       HIP_HOP
# 5093       HIP_HOP
#
# [5094 rows x 7 columns]

# %% [markdown]
# # 4. Export

# %%
ready_for_export = artist_genre_merged_in

# %%
ready_for_export.to_csv('./data/1 DONE RIGHT OUTPUT unique songs.csv', index=False)
